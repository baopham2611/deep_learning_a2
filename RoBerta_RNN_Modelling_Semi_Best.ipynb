# %%
# !pip install plotly
# !pip install seaborn
# !pip install matplotlib
# !pip install transformers
# !pip install tokenizers
# !pip install scikit-learn
# !pip install tensorflow
# !pip install pandas
# !pip install numpy
# !pip install keras_tuner


# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# #
# <a id="data-prep"></a>
# <div style="background-color: #000D5B; color: white; text-align: center; padding: 6px 0 22px 0">
#     <h3 style="background-color: #000D5B; color: white; text-align: left">RMIT School of Computer Science and Technology</h3>
#     <br/>
#     <h1>COSC3007: Deep Learning</h1>
#     <h2>Assignment 2: Stance Twitter Sentiment Analysis and Detection </h2>
#     <h2> [2] MODELLING AND MODEL EVALUATIONS </h2>
#
# </div>

# %% [markdown]
# # Import Libs

# %%
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, BatchNormalization, Bidirectional, Flatten
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers.legacy import Adam
from sklearn.metrics import classification_report
import numpy as np

import numpy as np

# %% [markdown]
# # [1] Load Data

# %%
train_df = pd.read_csv("./drive/MyDrive/Colab Notebooks/StanceDataset/processed_train.csv", encoding = "ISO-8859-1", engine="python").drop(columns=['Unnamed: 0'])
train_df = train_df.sample(frac=1, random_state=42).reset_index(drop=True)
train_ori = train_df.copy()

test_df = pd.read_csv("./drive/MyDrive/Colab Notebooks/StanceDataset/processed_test.csv", encoding = "ISO-8859-1", engine="python").drop(columns=['Unnamed: 0'])

# %%
print(len(train_ori))
print(len(test_df))
# Out:
# 2914
# 1956

# %% [markdown]
# # [2] Prepare label and fit data

# %% [markdown]
# ## Split test and val

# %%
train_df, val_df = train_test_split(train_df, test_size=0.2, random_state=42, shuffle=True)

# %% [markdown]
# ## Tweets

# %%
from transformers import TFRobertaModel, RobertaTokenizer
import numpy as np

# Initialize the BERT tokenizer
MAX_LENGTH = 512
tokenizer = RobertaTokenizer.from_pretrained('roberta-base')
roberta_model = TFRobertaModel.from_pretrained('roberta-base')

# Assuming train_texts, val_texts, test_texts are your datasets
train_processed_tweets = train_df['Tweet'].tolist()
val_processed_tweets = val_df['Tweet'].tolist()
test_processed_tweets = test_df['Tweet'].tolist()

all_processed_tweets = train_processed_tweets + val_processed_tweets + test_processed_tweets
tokenized_tweets = [tokenizer.encode(tweet, add_special_tokens=True) for tweet in all_processed_tweets]
MAX_LENGTH = max(len(tweet) for tweet in tokenized_tweets)
MAX_LENGTH = 128

print("Maximum length across all datasets:", MAX_LENGTH)

target_names = {
    0: "Hillary Clinton",
    1: "Legalization of Abortion",
    2: "Atheism",
    3: "Climate Change is a Real Concern",
    4: "Feminist Movement",
    5: "Donald Trump",
    6: "Joe Biden",
    7: "Barack Obama",
    8: "Kamala Harris",
    9: "Bernie Sanders",
    10: "Vu",
}

def bert_tokenize(texts, targets, max_length=MAX_LENGTH):
    input_ids = []
    attention_masks = []

    for idx, text in enumerate(texts):
        targetID = targets[idx]
        target_name = target_names.get(targetID, "")
        formatted_text = f"<s> {target_name} </s></s> {text} </s>"
        encoded = tokenizer.encode_plus(
            formatted_text,
            add_special_tokens=True,
            max_length=max_length,
            truncation=True,
            padding='max_length',
            return_attention_mask=True,
            return_tensors='tf',
        )

        # Flatten the tensors and remove the extra dimension
        input_ids.append(tf.squeeze(encoded['input_ids'], axis=0))
        attention_masks.append(tf.squeeze(encoded['attention_mask'], axis=0))

    return np.array(input_ids), np.array(attention_masks)

# Assuming you have lists of preprocessed texts for training, validation, and test sets
train_input_ids, train_attention_masks = bert_tokenize(train_df['Tweet'],  train_df['Target'].to_list())
val_input_ids, val_attention_masks = bert_tokenize(val_df['Tweet'], val_df['Target'].to_list())
test_input_ids, test_attention_masks = bert_tokenize(test_df['Tweet'], test_df['Target'].to_list())

print(train_input_ids.shape)
print(val_input_ids.shape)
print(test_input_ids.shape)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:72: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFRobertaModel: ['lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'roberta.embeddings.position_ids', 'lm_head.bias', 'lm_head.dense.bias', 'lm_head.dense.weight']
# - This IS expected if you are initializing TFRobertaModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFRobertaModel were not initialized from the PyTorch model and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Maximum length across all datasets: 128
# (2331, 128)
# (583, 128)
# (1956, 128)

# %% [markdown]
# ## Stances

# %%
def categorized_label(df, label_name):
    label_encoder = LabelEncoder()
    encoded_labels = label_encoder.fit_transform(df[label_name])
    categorical_labels = to_categorical(encoded_labels)
    return categorical_labels

# %%
train_labels = categorized_label(train_df, "Stance")
test_labels = categorized_label(test_df, "Stance")
val_labels = categorized_label(val_df, "Stance")

# %% [markdown]
# # [3] Create Model

# %%
from keras import backend as K
from tensorflow.keras.optimizers.legacy import Adam
from hyperopt import hp
from hyperopt import hp, fmin, tpe, STATUS_OK, Trials
# import keras_tuner as kt

# %%
def f1_score_class(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))

    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    return 2 * ((precision * recall) / (precision + recall + K.epsilon()))

def f1_score(y_true, y_pred):
    # Convert predictions to one-hot format
    y_pred_one_hot = K.one_hot(K.argmax(y_pred), num_classes=3)

    # Calculate F1 score for each class
    f1s = [f1_score_class(y_true[:, i], y_pred_one_hot[:, i]) for i in range(3)]

    # Average F1 scores across all classes
    return K.mean(K.stack(f1s), axis=0)

# %% [markdown]
# Set up call backs and learning rates

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint


# Define the EarlyStopping and ReduceLROnPlateau callbacks
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=10,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=5,
    min_lr=1e-5,
    verbose=1,
)

# Define the ModelCheckpoint callback
checkpoint_path = "roberta_best_model.h5"
model_checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_path,
    save_weights_only=True,    # Only save a model if 'val_loss' has improved
    monitor='val_loss',     # Monitor 'val_loss' during training
    mode='min',             # The model is saved when 'val_loss' is minimized
    verbose=1)

# Combine all callbacks in a list
callbacks = [
    early_stopping,
    lr_scheduler,
    model_checkpoint_callback
]

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, BatchNormalization, Bidirectional, Flatten, Input, GlobalMaxPooling1D
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers.legacy import Adam
# import keras_tuner as kt
from transformers import TFRobertaModel

def build_model(drop, regr, lr):
    bert_model = TFRobertaModel.from_pretrained('roberta-base')
    bert_model.trainable = False

    # Define model input (BERT expects two inputs: input_ids and attention_mask)
    input_ids = Input(shape=(MAX_LENGTH,), dtype=tf.int32, name='input_ids')
    attention_mask = Input(shape=(MAX_LENGTH,), dtype=tf.int32, name='attention_mask')

    # Get BERT embeddings
    bert_output = bert_model(input_ids, attention_mask=attention_mask)[0]  # Use the pooled output here

    # Tuning the number of units in the first biLSTM layer
    x = Bidirectional(LSTM(units=64,  dropout=drop, recurrent_dropout=drop,return_sequences=True,kernel_regularizer=tf.keras.regularizers.l2(regr))) (bert_output)

    # x = Bidirectional(LSTM(units=64,  dropout=drop, return_sequences=True,kernel_regularizer=tf.keras.regularizers.l2(regr))) (bert_output)

    x = GlobalMaxPooling1D()(x)

    # Dense layer with tunable units
    x = Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(regr)) (x)

    # Tunable dropout rate for the second layer
    x = Dropout(drop)(x)

    # Final Layer
    x = Dense(3, activation='softmax')(x)

    # Tuning the learning rate for the optimizer
    optimizer = Adam(learning_rate=lr)
    model = Model(inputs=[input_ids, attention_mask], outputs=x)
    model.compile(loss='CategoricalCrossentropy', optimizer=optimizer, metrics=['categorical_accuracy',f1_score])
    model.summary()

    return model

# %% [markdown]
# Recreate the best model with more training time

# %%
history = {}
inital_model = build_model(0.8, 0.0005, 0.001)
history['tuned_stance_model_custom'] = inital_model.fit([train_input_ids, train_attention_masks], train_labels,
                    epochs=100,
                    validation_data=([val_input_ids, val_attention_masks], val_labels),
                    batch_size=128,
                    callbacks=callbacks,
                    shuffle = True)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:72: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFRobertaModel: ['lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'roberta.embeddings.position_ids', 'lm_head.bias', 'lm_head.dense.bias', 'lm_head.dense.weight']
# - This IS expected if you are initializing TFRobertaModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFRobertaModel were not initialized from the PyTorch model and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_ids (InputLayer)      [(None, 128)]                0         []
#
#  attention_mask (InputLayer  [(None, 128)]                0         []
#  )
#
#  tf_roberta_model_1 (TFRobe  TFBaseModelOutputWithPooli   1246456   ['input_ids[0][0]',
#  rtaModel)                   ngAndCrossAttentions(last_   32         'attention_mask[0][0]']
#                              hidden_state=(None, 128, 7
#                              68),
#                               pooler_output=(None, 768)
#                              , past_key_values=None, hi
#                              dden_states=None, attentio
#                              ns=None, cross_attentions=
#                              None)
#
#  bidirectional (Bidirection  (None, 128, 128)             426496    ['tf_roberta_model_1[0][0]']
#  al)
#
#  global_max_pooling1d (Glob  (None, 128)                  0         ['bidirectional[0][0]']
#  alMaxPooling1D)
#
#  dense (Dense)               (None, 128)                  16512     ['global_max_pooling1d[0][0]']
#
#  dropout_74 (Dropout)        (None, 128)                  0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 3)                    387       ['dropout_74[0][0]']
#
# ==================================================================================================
# Total params: 125089027 (477.18 MB)
# Trainable params: 443395 (1.69 MB)
# Non-trainable params: 124645632 (475.49 MB)
# __________________________________________________________________________________________________
# Epoch 1/100
# 19/19 [==============================] - ETA: 0s - loss: 1.6529 - categorical_accuracy: 0.3947 - f1_score: 0.2941
# Epoch 1: saving model to roberta_best_model.h5
# 19/19 [==============================] - 58s 2s/step - loss: 1.6529 - categorical_accuracy: 0.3947 - f1_score: 0.2941 - val_loss: 1.4768 - val_categorical_accuracy: 0.4768 - val_f1_score: 0.2144 - lr: 0.0010
# Epoch 2/100
# 19/19 [==============================] - ETA: 0s - loss: 1.4821 - categorical_accuracy: 0.4462 - f1_score: 0.2929
# Epoch 2: saving model to roberta_best_model.h5
# 19/19 [==============================] - 27s 1s/step - loss: 1.4821 - categorical_accuracy: 0.4462 - f1_score: 0.2929 - val_loss: 1.4460 - val_categorical_accuracy: 0.4768 - val_f1_score: 0.2144 - lr: 0.0010
# Epoch 3/100
# 19/19 [==============================] - ETA: 0s - loss: 1.4433 - categorical_accuracy: 0.4766 - f1_score: 0.2308
# Epoch 3: saving model to roberta_best_model.h5
# 19/19 [==============================] - 27s 1s/step - loss: 1.4433 - categorical_accuracy: 0.4766 - f1_score: 0.2308 - val_loss: 1.4145 - val_categorical_accuracy: 0.4768 - val_f1_score: 0.2144 - lr: 0.0010
# Epoch 4/100
# 19/19 [==============================] - ETA: 0s - loss: 1.4012 - categorical_accuracy: 0.4805 - f1_score: 0.2331
# Epoch 4: saving model to roberta_best_model.h5
# 19/19 [==============================] - 27s 1s/step - loss: 1.4012 - categorical_accuracy: 0.4805 - f1_score: 0.2331 - val_loss: 1.3725 - val_categorical_accuracy: 0.4768 - val_f1_score: 0.2144 - lr: 0.0010
# Epoch 5/100
# 19/19 [==============================] - ETA: 0s - loss: 1.3661 - categorical_accuracy: 0.4788 - f1_score: 0.2311
# Epoch 5: saving model to roberta_best_model.h5
# 19/19 [==============================] - 33s 2s/step - loss: 1.3661 - categorical_accuracy: 0.4788 - f1_score: 0.2311 - val_loss: 1.3403 - val_categorical_accuracy: 0.4768 - val_f1_score: 0.2144 - lr: 0.0010
# Epoch 6/100
# 19/19 [==============================] - ETA: 0s - loss: 1.3305 - categorical_accuracy: 0.4822 - f1_score: 0.2510
# Epoch 6: saving model to roberta_best_model.h5
# 19/19 [==============================] - 26s 1s/step - loss: 1.3305 - categorical_accuracy: 0.4822 - f1_score: 0.2510 - val_loss: 1.3085 - val_categorical_accuracy: 0.4768 - val_f1_score: 0.2144 - lr: 0.0010
# Epoch 7/100
# 19/19 [==============================] - ETA: 0s - loss: 1.3041 - categorical_accuracy: 0.4818 - f1_score: 0.2629
# Epoch 7: saving model to roberta_best_model.h5
# 19/19 [==============================] - 27s 1s/step - loss: 1.3041 - categorical_accuracy: 0.4818 - f1_score: 0.2629 - val_loss: 1.2818 - val_categorical_accuracy: 0.4768 - val_f1_score: 0.2144 - lr: 0.0010
# Epoch 8/100
# 19/19 [==============================] - ETA: 0s - loss: 1.2766 - categorical_accuracy: 0.4942 - f1_score: 0.2678
# Epoch 8: saving model to roberta_best_model.h5
# 19/19 [==============================] - 31s 2s/step - loss: 1.2766 - categorical_accuracy: 0.4942 - f1_score: 0.2678 - val_loss: 1.2531 - val_categorical_accuracy: 0.4854 - val_f1_score: 0.2462 - lr: 0.0010
# Epoch 9/100
# 19/19 [==============================] - ETA: 0s - loss: 1.2462 - categorical_accuracy: 0.4903 - f1_score: 0.2958
# Epoch 9: saving model to roberta_best_model.h5
# 19/19 [==============================] - 28s 2s/step - loss: 1.2462 - categorical_accuracy: 0.4903 - f1_score: 0.2958 - val_loss: 1.2216 - val_categorical_accuracy: 0.5420 - val_f1_score: 0.3727 - lr: 0.0010
# Epoch 10/100
# 19/19 [==============================] - ETA: 0s - loss: 1.2125 - categorical_accuracy: 0.5079 - f1_score: 0.3125
# Epoch 10: saving model to roberta_best_model.h5
# 19/19 [==============================] - 28s 1s/step - loss: 1.2125 - categorical_accuracy: 0.5079 - f1_score: 0.3125 - val_loss: 1.2009 - val_categorical_accuracy: 0.5455 - val_f1_score: 0.3526 - lr: 0.0010
# Epoch 11/100
# 19/19 [==============================] - ETA: 0s - loss: 1.1924 - categorical_accuracy: 0.5105 - f1_score: 0.3324
# Epoch 11: saving model to roberta_best_model.h5
# 19/19 [==============================] - 27s 1s/step - loss: 1.1924 - categorical_accuracy: 0.5105 - f1_score: 0.3324 - val_loss: 1.1717 - val_categorical_accuracy: 0.5334 - val_f1_score: 0.4303 - lr: 0.0010
# Epoch 12/100
# 19/19 [==============================] - ETA: 0s - loss: 1.1659 - categorical_accuracy: 0.5217 - f1_score: 0.3841
# Epoch 12: saving model to roberta_best_model.h5
# 19/19 [==============================] - 26s 1s/step - loss: 1.1659 - categorical_accuracy: 0.5217 - f1_score: 0.3841 - val_loss: 1.1514 - val_categorical_accuracy: 0.5386 - val_f1_score: 0.4033 - lr: 0.0010
# Epoch 13/100
# 19/19 [==============================] - ETA: 0s - loss: 1.1422 - categorical_accuracy: 0.5281 - f1_score: 0.3785
# Epoch 13: saving model to roberta_best_model.h5
# 19/19 [==============================] - 76s 4s/step - loss: 1.1422 - categorical_accuracy: 0.5281 - f1_score: 0.3785 - val_loss: 1.1185 - val_categorical_accuracy: 0.5472 - val_f1_score: 0.4131 - lr: 0.0010
# Epoch 14/100
# 19/19 [==============================] - ETA: 0s - loss: 1.1232 - categorical_accuracy: 0.5508 - f1_score: 0.4444
# Epoch 14: saving model to roberta_best_model.h5
# 19/19 [==============================] - 28s 2s/step - loss: 1.1232 - categorical_accuracy: 0.5508 - f1_score: 0.4444 - val_loss: 1.1056 - val_categorical_accuracy: 0.5523 - val_f1_score: 0.3986 - lr: 0.0010
# Epoch 15/100
# 19/19 [==============================] - ETA: 0s - loss: 1.1131 - categorical_accuracy: 0.5397 - f1_score: 0.4085
# Epoch 15: saving model to roberta_best_model.h5
# 19/19 [==============================] - 27s 1s/step - loss: 1.1131 - categorical_accuracy: 0.5397 - f1_score: 0.4085 - val_loss: 1.1093 - val_categorical_accuracy: 0.5420 - val_f1_score: 0.4477 - lr: 0.0010
# Epoch 16/100
# 19/19 [==============================] - ETA: 0s - loss: 1.1047 - categorical_accuracy: 0.5530 - f1_score: 0.4462
# Epoch 16: saving model to roberta_best_model.h5
# 19/19 [==============================] - 27s 1s/step - loss: 1.1047 - categorical_accuracy: 0.5530 - f1_score: 0.4462 - val_loss: 1.0869 - val_categorical_accuracy: 0.5523 - val_f1_score: 0.4215 - lr: 0.0010
# Epoch 17/100
# 19/19 [==============================] - ETA: 0s - loss: 1.0831 - categorical_accuracy: 0.5650 - f1_score: 0.4405
# Epoch 17: saving model to roberta_best_model.h5
# 19/19 [==============================] - 27s 1s/step - loss: 1.0831 - categorical_accuracy: 0.5650 - f1_score: 0.4405 - val_loss: 1.0782 - val_categorical_accuracy: 0.5472 - val_f1_score: 0.3919 - lr: 0.0010
# Epoch 18/100
# 19/19 [==============================] - ETA: 0s - loss: 1.0770 - categorical_accuracy: 0.5581 - f1_score: 0.4550
# Epoch 18: saving model to roberta_best_model.h5
# 19/19 [==============================] - 29s 2s/step - loss: 1.0770 - categorical_accuracy: 0.5581 - f1_score: 0.4550 - val_loss: 1.0741 - val_categorical_accuracy: 0.5592 - val_f1_score: 0.4710 - lr: 0.0010
# Epoch 19/100
# 19/19 [==============================] - ETA: 0s - loss: 1.0564 - categorical_accuracy: 0.5693 - f1_score: 0.4796
# Epoch 19: saving model to roberta_best_model.h5
# 19/19 [==============================] - 28s 1s/step - loss: 1.0564 - categorical_accuracy: 0.5693 - f1_score: 0.4796 - val_loss: 1.0748 - val_categorical_accuracy: 0.5506 - val_f1_score: 0.4578 - lr: 0.0010
# Epoch 20/100
# 19/19 [==============================] - ETA: 0s - loss: 1.0397 - categorical_accuracy: 0.5770 - f1_score: 0.4954
# Epoch 20: saving model to roberta_best_model.h5
# 19/19 [==============================] - 28s 1s/step - loss: 1.0397 - categorical_accuracy: 0.5770 - f1_score: 0.4954 - val_loss: 1.0737 - val_categorical_accuracy: 0.5592 - val_f1_score: 0.4393 - lr: 0.0010
# Epoch 21/100
# 19/19 [==============================] - ETA: 0s - loss: 1.0298 - categorical_accuracy: 0.5864 - f1_score: 0.4885
# Epoch 21: saving model to roberta_best_model.h5
# 19/19 [==============================] - 27s 1s/step - loss: 1.0298 - categorical_accuracy: 0.5864 - f1_score: 0.4885 - val_loss: 1.0667 - val_categorical_accuracy: 0.5712 - val_f1_score: 0.4691 - lr: 0.0010
# Epoch 22/100
# 19/19 [==============================] - ETA: 0s - loss: 1.0172 - categorical_accuracy: 0.5852 - f1_score: 0.5060
# Epoch 22: saving model to roberta_best_model.h5
# 19/19 [==============================] - 26s 1s/step - loss: 1.0172 - categorical_accuracy: 0.5852 - f1_score: 0.5060 - val_loss: 1.0604 - val_categorical_accuracy: 0.5557 - val_f1_score: 0.4161 - lr: 0.0010
# Epoch 23/100
# 19/19 [==============================] - ETA: 0s - loss: 1.0485 - categorical_accuracy: 0.5873 - f1_score: 0.4912
# Epoch 23: saving model to roberta_best_model.h5
# 19/19 [==============================] - 27s 1s/step - loss: 1.0485 - categorical_accuracy: 0.5873 - f1_score: 0.4912 - val_loss: 1.0417 - val_categorical_accuracy: 0.5712 - val_f1_score: 0.4663 - lr: 0.0010
# Epoch 24/100
# 19/19 [==============================] - ETA: 0s - loss: 1.0006 - categorical_accuracy: 0.6023 - f1_score: 0.5247
# Epoch 24: saving model to roberta_best_model.h5
# 19/19 [==============================] - 27s 1s/step - loss: 1.0006 - categorical_accuracy: 0.6023 - f1_score: 0.5247 - val_loss: 1.0459 - val_categorical_accuracy: 0.5660 - val_f1_score: 0.4603 - lr: 0.0010
# Epoch 25/100
# 19/19 [==============================] - ETA: 0s - loss: 0.9964 - categorical_accuracy: 0.6040 - f1_score: 0.5425
# Epoch 25: saving model to roberta_best_model.h5
# 19/19 [==============================] - 27s 1s/step - loss: 0.9964 - categorical_accuracy: 0.6040 - f1_score: 0.5425 - val_loss: 1.0299 - val_categorical_accuracy: 0.5746 - val_f1_score: 0.4713 - lr: 0.0010
# Epoch 26/100
# 19/19 [==============================] - ETA: 0s - loss: 0.9881 - categorical_accuracy: 0.6118 - f1_score: 0.5434
# Epoch 26: saving model to roberta_best_model.h5
# 19/19 [==============================] - 27s 1s/step - loss: 0.9881 - categorical_accuracy: 0.6118 - f1_score: 0.5434 - val_loss: 1.0131 - val_categorical_accuracy: 0.5849 - val_f1_score: 0.5429 - lr: 0.0010
# Epoch 27/100
# 19/19 [==============================] - ETA: 0s - loss: 0.9838 - categorical_accuracy: 0.6070 - f1_score: 0.5394
# Epoch 27: saving model to roberta_best_model.h5
# 19/19 [==============================] - 27s 1s/step - loss: 0.9838 - categorical_accuracy: 0.6070 - f1_score: 0.5394 - val_loss: 1.0050 - val_categorical_accuracy: 0.6021 - val_f1_score: 0.5460 - lr: 0.0010
# Epoch 28/100
# 19/19 [==============================] - ETA: 0s - loss: 0.9819 - categorical_accuracy: 0.6221 - f1_score: 0.5585
# Epoch 28: saving model to roberta_best_model.h5
# 19/19 [==============================] - 30s 2s/step - loss: 0.9819 - categorical_accuracy: 0.6221 - f1_score: 0.5585 - val_loss: 1.0131 - val_categorical_accuracy: 0.5969 - val_f1_score: 0.5731 - lr: 0.0010
# Epoch 29/100
# 19/19 [==============================] - ETA: 0s - loss: 0.9591 - categorical_accuracy: 0.6238 - f1_score: 0.5638
# Epoch 29: saving model to roberta_best_model.h5
# 19/19 [==============================] - 27s 1s/step - loss: 0.9591 - categorical_accuracy: 0.6238 - f1_score: 0.5638 - val_loss: 0.9933 - val_categorical_accuracy: 0.6141 - val_f1_score: 0.5937 - lr: 0.0010
# Epoch 30/100
# 19/19 [==============================] - ETA: 0s - loss: 0.9440 - categorical_accuracy: 0.6396 - f1_score: 0.5775
# Epoch 30: saving model to roberta_best_model.h5
# 19/19 [==============================] - 28s 1s/step - loss: 0.9440 - categorical_accuracy: 0.6396 - f1_score: 0.5775 - val_loss: 0.9876 - val_categorical_accuracy: 0.6123 - val_f1_score: 0.5846 - lr: 0.0010
# Epoch 31/100
# 19/19 [==============================] - ETA: 0s - loss: 0.9393 - categorical_accuracy: 0.6311 - f1_score: 0.5741
# Epoch 31: saving model to roberta_best_model.h5
# 19/19 [==============================] - 27s 1s/step - loss: 0.9393 - categorical_accuracy: 0.6311 - f1_score: 0.5741 - val_loss: 1.0254 - val_categorical_accuracy: 0.5918 - val_f1_score: 0.5841 - lr: 0.0010
# Epoch 32/100
# 19/19 [==============================] - ETA: 0s - loss: 0.9444 - categorical_accuracy: 0.6422 - f1_score: 0.5891
# Epoch 32: saving model to roberta_best_model.h5
# 19/19 [==============================] - 27s 1s/step - loss: 0.9444 - categorical_accuracy: 0.6422 - f1_score: 0.5891 - val_loss: 0.9651 - val_categorical_accuracy: 0.6312 - val_f1_score: 0.5998 - lr: 0.0010
# Epoch 33/100
# 19/19 [==============================] - ETA: 0s - loss: 0.9205 - categorical_accuracy: 0.6619 - f1_score: 0.6180
# Epoch 33: saving model to roberta_best_model.h5
# 19/19 [==============================] - 25s 1s/step - loss: 0.9205 - categorical_accuracy: 0.6619 - f1_score: 0.6180 - val_loss: 0.9964 - val_categorical_accuracy: 0.6072 - val_f1_score: 0.5943 - lr: 0.0010
# Epoch 34/100
# 19/19 [==============================] - ETA: 0s - loss: 0.9095 - categorical_accuracy: 0.6542 - f1_score: 0.6010
# Epoch 34: saving model to roberta_best_model.h5
# 19/19 [==============================] - 26s 1s/step - loss: 0.9095 - categorical_accuracy: 0.6542 - f1_score: 0.6010 - val_loss: 0.9848 - val_categorical_accuracy: 0.6072 - val_f1_score: 0.5986 - lr: 0.0010
# Epoch 35/100
# 19/19 [==============================] - ETA: 0s - loss: 0.9290 - categorical_accuracy: 0.6349 - f1_score: 0.5823
# Epoch 35: saving model to roberta_best_model.h5
# 19/19 [==============================] - 28s 1s/step - loss: 0.9290 - categorical_accuracy: 0.6349 - f1_score: 0.5823 - val_loss: 0.9729 - val_categorical_accuracy: 0.6261 - val_f1_score: 0.5805 - lr: 0.0010
# Epoch 36/100
# 19/19 [==============================] - ETA: 0s - loss: 0.9146 - categorical_accuracy: 0.6654 - f1_score: 0.5970
# Epoch 36: saving model to roberta_best_model.h5
# 19/19 [==============================] - 28s 1s/step - loss: 0.9146 - categorical_accuracy: 0.6654 - f1_score: 0.5970 - val_loss: 1.0168 - val_categorical_accuracy: 0.5729 - val_f1_score: 0.5235 - lr: 0.0010
# Epoch 37/100
# 19/19 [==============================] - ETA: 0s - loss: 0.9248 - categorical_accuracy: 0.6547 - f1_score: 0.6018
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 37: saving model to roberta_best_model.h5
# 19/19 [==============================] - 26s 1s/step - loss: 0.9248 - categorical_accuracy: 0.6547 - f1_score: 0.6018 - val_loss: 0.9670 - val_categorical_accuracy: 0.6175 - val_f1_score: 0.5761 - lr: 0.0010
# Epoch 38/100
# 19/19 [==============================] - ETA: 0s - loss: 0.8942 - categorical_accuracy: 0.6628 - f1_score: 0.6205
# Epoch 38: saving model to roberta_best_model.h5
# 19/19 [==============================] - 26s 1s/step - loss: 0.8942 - categorical_accuracy: 0.6628 - f1_score: 0.6205 - val_loss: 0.9562 - val_categorical_accuracy: 0.6329 - val_f1_score: 0.5998 - lr: 2.0000e-04
# Epoch 39/100
# 19/19 [==============================] - ETA: 0s - loss: 0.8748 - categorical_accuracy: 0.6761 - f1_score: 0.6172
# Epoch 39: saving model to roberta_best_model.h5
# 19/19 [==============================] - 27s 1s/step - loss: 0.8748 - categorical_accuracy: 0.6761 - f1_score: 0.6172 - val_loss: 0.9576 - val_categorical_accuracy: 0.6244 - val_f1_score: 0.6020 - lr: 2.0000e-04
# Epoch 40/100
# 19/19 [==============================] - ETA: 0s - loss: 0.8940 - categorical_accuracy: 0.6722 - f1_score: 0.6405
# Epoch 40: saving model to roberta_best_model.h5
# 19/19 [==============================] - 27s 1s/step - loss: 0.8940 - categorical_accuracy: 0.6722 - f1_score: 0.6405 - val_loss: 0.9645 - val_categorical_accuracy: 0.6364 - val_f1_score: 0.6051 - lr: 2.0000e-04
# Epoch 41/100
# 19/19 [==============================] - ETA: 0s - loss: 0.8826 - categorical_accuracy: 0.6658 - f1_score: 0.6244
# Epoch 41: saving model to roberta_best_model.h5
# 19/19 [==============================] - 70s 4s/step - loss: 0.8826 - categorical_accuracy: 0.6658 - f1_score: 0.6244 - val_loss: 0.9652 - val_categorical_accuracy: 0.6329 - val_f1_score: 0.6115 - lr: 2.0000e-04
# Epoch 42/100
# 19/19 [==============================] - ETA: 0s - loss: 0.8748 - categorical_accuracy: 0.6847 - f1_score: 0.6355
# Epoch 42: saving model to roberta_best_model.h5
# 19/19 [==============================] - 28s 1s/step - loss: 0.8748 - categorical_accuracy: 0.6847 - f1_score: 0.6355 - val_loss: 0.9688 - val_categorical_accuracy: 0.6244 - val_f1_score: 0.6055 - lr: 2.0000e-04
# Epoch 43/100
# 19/19 [==============================] - ETA: 0s - loss: 0.8739 - categorical_accuracy: 0.6825 - f1_score: 0.6437
# Epoch 43: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 43: saving model to roberta_best_model.h5
# 19/19 [==============================] - 26s 1s/step - loss: 0.8739 - categorical_accuracy: 0.6825 - f1_score: 0.6437 - val_loss: 0.9780 - val_categorical_accuracy: 0.6261 - val_f1_score: 0.5883 - lr: 2.0000e-04
# Epoch 44/100
# 19/19 [==============================] - ETA: 0s - loss: 0.8700 - categorical_accuracy: 0.6838 - f1_score: 0.6438
# Epoch 44: saving model to roberta_best_model.h5
# 19/19 [==============================] - 26s 1s/step - loss: 0.8700 - categorical_accuracy: 0.6838 - f1_score: 0.6438 - val_loss: 0.9579 - val_categorical_accuracy: 0.6329 - val_f1_score: 0.6024 - lr: 4.0000e-05
# Epoch 45/100
# 19/19 [==============================] - ETA: 0s - loss: 0.8702 - categorical_accuracy: 0.6843 - f1_score: 0.6344
# Epoch 45: saving model to roberta_best_model.h5
# 19/19 [==============================] - 27s 1s/step - loss: 0.8702 - categorical_accuracy: 0.6843 - f1_score: 0.6344 - val_loss: 0.9538 - val_categorical_accuracy: 0.6364 - val_f1_score: 0.6141 - lr: 4.0000e-05
# Epoch 46/100
# 19/19 [==============================] - ETA: 0s - loss: 0.8694 - categorical_accuracy: 0.6885 - f1_score: 0.6536
# Epoch 46: saving model to roberta_best_model.h5
# 19/19 [==============================] - 32s 2s/step - loss: 0.8694 - categorical_accuracy: 0.6885 - f1_score: 0.6536 - val_loss: 0.9585 - val_categorical_accuracy: 0.6295 - val_f1_score: 0.6026 - lr: 4.0000e-05
# Epoch 47/100
# 19/19 [==============================] - ETA: 0s - loss: 0.8549 - categorical_accuracy: 0.6855 - f1_score: 0.6396
# Epoch 47: saving model to roberta_best_model.h5
# 19/19 [==============================] - 59s 3s/step - loss: 0.8549 - categorical_accuracy: 0.6855 - f1_score: 0.6396 - val_loss: 0.9567 - val_categorical_accuracy: 0.6346 - val_f1_score: 0.6113 - lr: 4.0000e-05
# Epoch 48/100
# 19/19 [==============================] - ETA: 0s - loss: 0.8566 - categorical_accuracy: 0.6851 - f1_score: 0.6484
# Epoch 48: saving model to roberta_best_model.h5
# 19/19 [==============================] - 26s 1s/step - loss: 0.8566 - categorical_accuracy: 0.6851 - f1_score: 0.6484 - val_loss: 0.9610 - val_categorical_accuracy: 0.6278 - val_f1_score: 0.6040 - lr: 4.0000e-05
# Epoch 49/100
# 19/19 [==============================] - ETA: 0s - loss: 0.8581 - categorical_accuracy: 0.6855 - f1_score: 0.6519
# Epoch 49: saving model to roberta_best_model.h5
# 19/19 [==============================] - 26s 1s/step - loss: 0.8581 - categorical_accuracy: 0.6855 - f1_score: 0.6519 - val_loss: 0.9612 - val_categorical_accuracy: 0.6278 - val_f1_score: 0.6055 - lr: 4.0000e-05
# Epoch 50/100
# 19/19 [==============================] - ETA: 0s - loss: 0.8557 - categorical_accuracy: 0.6920 - f1_score: 0.6606
# Epoch 50: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 50: saving model to roberta_best_model.h5
# 19/19 [==============================] - 28s 1s/step - loss: 0.8557 - categorical_accuracy: 0.6920 - f1_score: 0.6606 - val_loss: 0.9608 - val_categorical_accuracy: 0.6244 - val_f1_score: 0.6046 - lr: 4.0000e-05
# Epoch 51/100
# 19/19 [==============================] - ETA: 0s - loss: 0.8537 - categorical_accuracy: 0.6898 - f1_score: 0.6586
# Epoch 51: saving model to roberta_best_model.h5
# 19/19 [==============================] - 28s 1s/step - loss: 0.8537 - categorical_accuracy: 0.6898 - f1_score: 0.6586 - val_loss: 0.9616 - val_categorical_accuracy: 0.6244 - val_f1_score: 0.6047 - lr: 1.0000e-05
# Epoch 52/100
# 19/19 [==============================] - ETA: 0s - loss: 0.8651 - categorical_accuracy: 0.6765 - f1_score: 0.6352
# Epoch 52: saving model to roberta_best_model.h5
# 19/19 [==============================] - 32s 2s/step - loss: 0.8651 - categorical_accuracy: 0.6765 - f1_score: 0.6352 - val_loss: 0.9625 - val_categorical_accuracy: 0.6244 - val_f1_score: 0.6041 - lr: 1.0000e-05
# Epoch 53/100
# 19/19 [==============================] - ETA: 0s - loss: 0.8606 - categorical_accuracy: 0.6813 - f1_score: 0.6462
# Epoch 53: saving model to roberta_best_model.h5
# 19/19 [==============================] - 37s 2s/step - loss: 0.8606 - categorical_accuracy: 0.6813 - f1_score: 0.6462 - val_loss: 0.9624 - val_categorical_accuracy: 0.6226 - val_f1_score: 0.6026 - lr: 1.0000e-05
# Epoch 54/100
# 19/19 [==============================] - ETA: 0s - loss: 0.8608 - categorical_accuracy: 0.6941 - f1_score: 0.6593
# Epoch 54: saving model to roberta_best_model.h5
# 19/19 [==============================] - 36s 2s/step - loss: 0.8608 - categorical_accuracy: 0.6941 - f1_score: 0.6593 - val_loss: 0.9616 - val_categorical_accuracy: 0.6226 - val_f1_score: 0.6028 - lr: 1.0000e-05
# Epoch 55/100
# 19/19 [==============================] - ETA: 0s - loss: 0.8741 - categorical_accuracy: 0.6744 - f1_score: 0.6428Restoring model weights from the end of the best epoch: 45.
#
# Epoch 55: saving model to roberta_best_model.h5
# 19/19 [==============================] - 34s 2s/step - loss: 0.8741 - categorical_accuracy: 0.6744 - f1_score: 0.6428 - val_loss: 0.9606 - val_categorical_accuracy: 0.6244 - val_f1_score: 0.6042 - lr: 1.0000e-05
# Epoch 55: early stopping

# %%
results = inital_model.evaluate([test_input_ids, test_attention_masks], test_labels)
print('Test accuracy:', results)
# Out:
# 62/62 [==============================] - 11s 180ms/step - loss: 1.0290 - categorical_accuracy: 0.5608 - f1_score: 0.3956
# Test accuracy: [1.0290485620498657, 0.5608384609222412, 0.3956450819969177]

# %%
# Get model predictions
predictions = inital_model.predict([test_input_ids, test_attention_masks])

# Convert predictions to class labels
predicted_labels = np.argmax(predictions, axis=1)

# Assuming test_labels are one-hot encoded, convert them to class labels
true_labels = np.argmax(test_labels, axis=1)

# Generate classification report
report = classification_report(true_labels, predicted_labels)
print(report)
# Out:
# 62/62 [==============================] - 15s 187ms/step
#               precision    recall  f1-score   support
#
#            0       0.73      0.55      0.63      1014
#            1       0.58      0.37      0.45       452
#            2       0.41      0.77      0.54       490
#
#     accuracy                           0.56      1956
#    macro avg       0.58      0.56      0.54      1956
# weighted avg       0.62      0.56      0.56      1956

# %%
def load_classification_rp_per_target(model):
    targets = test_df.Target.unique()
    metrics_df = pd.DataFrame()
    for target in targets:
        extracted_df = test_df[test_df['Target'] == target]
        input_ids, attention_masks = bert_tokenize(extracted_df['processed_tweet'], extracted_df['Target'].to_list())
        labels = categorized_label(extracted_df, "Stance")

        # Convert one-hot encoded labels to single integer class labels
        true_labels = np.argmax(labels, axis=1)

        # Get model predictions
        predictions = model.predict([input_ids, attention_masks])

        # Convert predictions to class labels
        predicted_labels = np.argmax(predictions, axis=1)

        # Generate a classification report
        report = classification_report(true_labels, predicted_labels, target_names=['AGAINST', 'FAVOR', 'NONE'])
        target_name = ""
        if target == 0:
            target_name = "Hillary Clinton"
        if target == 1:
            target_name = "Legalization of Abortion"
        if target == 2:
            target_name = "Atheism"
        if target == 3:
            target_name = "Climate Change is a Real Concern"
        if target == 4:
            target_name = "Feminist Movement"
        if target == 5:
            target_name = "Donald Trump"

        print('Target: ', target_name)
        print(report)
        print("-----------------------------------------", "\n")

        # Flatten the report into a single row and add target name
        report = classification_report(true_labels, predicted_labels, target_names=['AGAINST', 'FAVOR', 'NONE'], output_dict=True)

        # Extract weighted f1, macro f1, and accuracy
        report_data = {
            'Target': target_name,
            'Weighted F1': report['weighted avg']['f1-score'],
            'Macro F1': report['macro avg']['f1-score'],
            'Accuracy': report['accuracy']
        }

        # Append to the DataFrame
        metrics_df = metrics_df.append(report_data, ignore_index=True)
    metrics_df.set_index('Target', inplace=True)

    return metrics_df

# %%
# Use the function to get the metrics DataFrame
model_metrics_df = load_classification_rp_per_target(inital_model)
model_metrics_df
# Out:
# 7/7 [==============================] - 1s 174ms/step
# Target:  Atheism
#               precision    recall  f1-score   support
#
#      AGAINST       0.83      0.47      0.60       160
#        FAVOR       1.00      0.03      0.06        32
#         NONE       0.19      0.89      0.32        28
#
#     accuracy                           0.46       220
#    macro avg       0.68      0.46      0.33       220
# weighted avg       0.78      0.46      0.49       220
#
# -----------------------------------------
# <ipython-input-16-7822421f7f5a>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 6/6 [==============================] - 1s 164ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# <ipython-input-16-7822421f7f5a>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# Target:  Climate Change is a Real Concern
#               precision    recall  f1-score   support
#
#      AGAINST       0.00      0.00      0.00        11
#        FAVOR       0.90      0.77      0.83       123
#         NONE       0.48      0.86      0.61        35
#
#     accuracy                           0.74       169
#    macro avg       0.46      0.54      0.48       169
# weighted avg       0.75      0.74      0.73       169
#
# -----------------------------------------
#
# 9/9 [==============================] - 2s 178ms/step
# Target:  Feminist Movement
#               precision    recall  f1-score   support
#
#      AGAINST       0.74      0.34      0.46       183
#        FAVOR       0.29      0.38      0.33        58
#         NONE       0.25      0.70      0.36        44
#
#     accuracy                           0.40       285
#    macro avg       0.43      0.47      0.39       285
# weighted avg       0.57      0.40      0.42       285
#
# -----------------------------------------
# <ipython-input-16-7822421f7f5a>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 10/10 [==============================] - 2s 178ms/step
# Target:  Hillary Clinton
#               precision    recall  f1-score   support
#
#      AGAINST       0.74      0.52      0.61       172
#        FAVOR       0.26      0.18      0.21        45
#         NONE       0.36      0.65      0.46        78
#
#     accuracy                           0.51       295
#    macro avg       0.45      0.45      0.43       295
# weighted avg       0.56      0.51      0.51       295
#
# -----------------------------------------
# <ipython-input-16-7822421f7f5a>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 9/9 [==============================] - 2s 225ms/step
# Target:  Legalization of Abortion
#               precision    recall  f1-score   support
#
#      AGAINST       0.82      0.35      0.49       189
#        FAVOR       0.48      0.33      0.39        46
#         NONE       0.25      0.96      0.40        45
#
#     accuracy                           0.44       280
#    macro avg       0.52      0.54      0.43       280
# weighted avg       0.68      0.44      0.46       280
#
# -----------------------------------------
# <ipython-input-16-7822421f7f5a>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 23/23 [==============================] - 4s 172ms/step
# Target:  Donald Trump
#               precision    recall  f1-score   support
#
#      AGAINST       0.33      0.02      0.03       299
#        FAVOR       0.00      0.00      0.00       148
#         NONE       0.36      0.96      0.52       260
#
#     accuracy                           0.36       707
#    macro avg       0.23      0.32      0.19       707
# weighted avg       0.27      0.36      0.21       707
#
# -----------------------------------------
# <ipython-input-16-7822421f7f5a>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
#                                   Weighted F1  Macro F1  Accuracy
# Target
# Atheism                              0.485712  0.326359  0.459091
# Climate Change is a Real Concern     0.730657  0.480646  0.739645
# Feminist Movement                    0.421838  0.386651  0.403509
# Hillary Clinton                      0.511673  0.428803  0.505085
# Legalization of Abortion             0.459820  0.427395  0.442857
# Donald Trump                         0.206248  0.185353  0.359264

# %% [markdown]
# [4] Fine Tune

# %%
for layer in inital_model.layers:
    layer.trainable = True
   # Tuning the learning rate for the optimizer
inital_model.compile(optimizer=tf.keras.optimizers.legacy.Adam(1e-5),
                  loss='categorical_crossentropy',
                  metrics=['categorical_accuracy', f1_score])

history['fine_tuned_bert'] = inital_model.fit([train_input_ids, train_attention_masks], train_labels,
                    epochs=30,
                    validation_data=([val_input_ids, val_attention_masks], val_labels),
                    batch_size=32,
                    callbacks=callbacks,
                    shuffle = True)
# Out:
# Epoch 1/30
# WARNING:tensorflow:Gradients do not exist for variables ['tf_roberta_model_1/roberta/pooler/dense/kernel:0', 'tf_roberta_model_1/roberta/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['tf_roberta_model_1/roberta/pooler/dense/kernel:0', 'tf_roberta_model_1/roberta/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 73/73 [==============================] - ETA: 0s - loss: 0.9330 - categorical_accuracy: 0.6418 - f1_score: 0.5701
# Epoch 1: saving model to roberta_best_model.h5
# 73/73 [==============================] - 123s 1s/step - loss: 0.9330 - categorical_accuracy: 0.6418 - f1_score: 0.5701 - val_loss: 0.9411 - val_categorical_accuracy: 0.6415 - val_f1_score: 0.5986 - lr: 1.0000e-05
# Epoch 2/30
# 73/73 [==============================] - ETA: 0s - loss: 0.8083 - categorical_accuracy: 0.7177 - f1_score: 0.6762
# Epoch 2: saving model to roberta_best_model.h5
# 73/73 [==============================] - 92s 1s/step - loss: 0.8083 - categorical_accuracy: 0.7177 - f1_score: 0.6762 - val_loss: 0.9092 - val_categorical_accuracy: 0.6758 - val_f1_score: 0.6393 - lr: 1.0000e-05
# Epoch 3/30
# 73/73 [==============================] - ETA: 0s - loss: 0.7310 - categorical_accuracy: 0.7538 - f1_score: 0.7213
# Epoch 3: saving model to roberta_best_model.h5
# 73/73 [==============================] - 91s 1s/step - loss: 0.7310 - categorical_accuracy: 0.7538 - f1_score: 0.7213 - val_loss: 0.9229 - val_categorical_accuracy: 0.6964 - val_f1_score: 0.6560 - lr: 1.0000e-05
# Epoch 4/30
# 73/73 [==============================] - ETA: 0s - loss: 0.6675 - categorical_accuracy: 0.7782 - f1_score: 0.7507
# Epoch 4: saving model to roberta_best_model.h5
# 73/73 [==============================] - 98s 1s/step - loss: 0.6675 - categorical_accuracy: 0.7782 - f1_score: 0.7507 - val_loss: 0.8905 - val_categorical_accuracy: 0.7170 - val_f1_score: 0.6854 - lr: 1.0000e-05
# Epoch 5/30
# 73/73 [==============================] - ETA: 0s - loss: 0.6271 - categorical_accuracy: 0.8082 - f1_score: 0.7814
# Epoch 5: saving model to roberta_best_model.h5
# 73/73 [==============================] - 93s 1s/step - loss: 0.6271 - categorical_accuracy: 0.8082 - f1_score: 0.7814 - val_loss: 0.9275 - val_categorical_accuracy: 0.6844 - val_f1_score: 0.6735 - lr: 1.0000e-05
# Epoch 6/30
# 73/73 [==============================] - ETA: 0s - loss: 0.5792 - categorical_accuracy: 0.8366 - f1_score: 0.8156
# Epoch 6: saving model to roberta_best_model.h5
# 73/73 [==============================] - 91s 1s/step - loss: 0.5792 - categorical_accuracy: 0.8366 - f1_score: 0.8156 - val_loss: 0.9473 - val_categorical_accuracy: 0.6981 - val_f1_score: 0.6747 - lr: 1.0000e-05
# Epoch 7/30
# 73/73 [==============================] - ETA: 0s - loss: 0.5286 - categorical_accuracy: 0.8511 - f1_score: 0.8334
# Epoch 7: saving model to roberta_best_model.h5
# 73/73 [==============================] - 99s 1s/step - loss: 0.5286 - categorical_accuracy: 0.8511 - f1_score: 0.8334 - val_loss: 0.9537 - val_categorical_accuracy: 0.7204 - val_f1_score: 0.6876 - lr: 1.0000e-05
# Epoch 8/30
# 73/73 [==============================] - ETA: 0s - loss: 0.4714 - categorical_accuracy: 0.8786 - f1_score: 0.8644
# Epoch 8: saving model to roberta_best_model.h5
# 73/73 [==============================] - 91s 1s/step - loss: 0.4714 - categorical_accuracy: 0.8786 - f1_score: 0.8644 - val_loss: 1.0253 - val_categorical_accuracy: 0.7118 - val_f1_score: 0.6838 - lr: 1.0000e-05
# Epoch 9/30
# 73/73 [==============================] - ETA: 0s - loss: 0.4119 - categorical_accuracy: 0.9060 - f1_score: 0.8902
# Epoch 9: saving model to roberta_best_model.h5
# 73/73 [==============================] - 92s 1s/step - loss: 0.4119 - categorical_accuracy: 0.9060 - f1_score: 0.8902 - val_loss: 1.0715 - val_categorical_accuracy: 0.7204 - val_f1_score: 0.6902 - lr: 1.0000e-05
# Epoch 10/30
# 73/73 [==============================] - ETA: 0s - loss: 0.3652 - categorical_accuracy: 0.9288 - f1_score: 0.9205
# Epoch 10: saving model to roberta_best_model.h5
# 73/73 [==============================] - 93s 1s/step - loss: 0.3652 - categorical_accuracy: 0.9288 - f1_score: 0.9205 - val_loss: 1.1030 - val_categorical_accuracy: 0.6998 - val_f1_score: 0.6672 - lr: 1.0000e-05
# Epoch 11/30
# 73/73 [==============================] - ETA: 0s - loss: 0.3317 - categorical_accuracy: 0.9447 - f1_score: 0.9351
# Epoch 11: saving model to roberta_best_model.h5
# 73/73 [==============================] - 91s 1s/step - loss: 0.3317 - categorical_accuracy: 0.9447 - f1_score: 0.9351 - val_loss: 1.1328 - val_categorical_accuracy: 0.7187 - val_f1_score: 0.6946 - lr: 1.0000e-05
# Epoch 12/30
# 73/73 [==============================] - ETA: 0s - loss: 0.3191 - categorical_accuracy: 0.9451 - f1_score: 0.9362
# Epoch 12: saving model to roberta_best_model.h5
# 73/73 [==============================] - 93s 1s/step - loss: 0.3191 - categorical_accuracy: 0.9451 - f1_score: 0.9362 - val_loss: 1.2578 - val_categorical_accuracy: 0.7050 - val_f1_score: 0.6773 - lr: 1.0000e-05
# Epoch 13/30
# 73/73 [==============================] - ETA: 0s - loss: 0.2911 - categorical_accuracy: 0.9524 - f1_score: 0.9481
# Epoch 13: saving model to roberta_best_model.h5
# 73/73 [==============================] - 92s 1s/step - loss: 0.2911 - categorical_accuracy: 0.9524 - f1_score: 0.9481 - val_loss: 1.0917 - val_categorical_accuracy: 0.7324 - val_f1_score: 0.7023 - lr: 1.0000e-05
# Epoch 14/30
# 73/73 [==============================] - ETA: 0s - loss: 0.2761 - categorical_accuracy: 0.9618 - f1_score: 0.9560Restoring model weights from the end of the best epoch: 4.
#
# Epoch 14: saving model to roberta_best_model.h5
# 73/73 [==============================] - 97s 1s/step - loss: 0.2761 - categorical_accuracy: 0.9618 - f1_score: 0.9560 - val_loss: 1.1961 - val_categorical_accuracy: 0.7187 - val_f1_score: 0.6853 - lr: 1.0000e-05
# Epoch 14: early stopping

# %%
# Use the function to get the metrics DataFrame
model_metrics_df = load_classification_rp_per_target(inital_model)
model_metrics_df
# Out:
# 7/7 [==============================] - 6s 223ms/step
# Target:  Atheism
#               precision    recall  f1-score   support
#
#      AGAINST       0.89      0.54      0.67       160
#        FAVOR       0.29      0.34      0.31        32
#         NONE       0.29      0.89      0.44        28
#
#     accuracy                           0.55       220
#    macro avg       0.49      0.59      0.48       220
# weighted avg       0.72      0.55      0.59       220
#
# -----------------------------------------
# <ipython-input-16-7822421f7f5a>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 6/6 [==============================] - 1s 158ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# <ipython-input-16-7822421f7f5a>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# Target:  Climate Change is a Real Concern
#               precision    recall  f1-score   support
#
#      AGAINST       0.00      0.00      0.00        11
#        FAVOR       0.88      0.87      0.87       123
#         NONE       0.64      0.86      0.73        35
#
#     accuracy                           0.81       169
#    macro avg       0.51      0.58      0.54       169
# weighted avg       0.77      0.81      0.79       169
#
# -----------------------------------------
#
# 9/9 [==============================] - 2s 169ms/step
# Target:  Feminist Movement
#               precision    recall  f1-score   support
#
#      AGAINST       0.78      0.49      0.60       183
#        FAVOR       0.33      0.47      0.39        58
#         NONE       0.41      0.82      0.55        44
#
#     accuracy                           0.54       285
#    macro avg       0.51      0.59      0.51       285
# weighted avg       0.63      0.54      0.55       285
#
# -----------------------------------------
# <ipython-input-16-7822421f7f5a>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 10/10 [==============================] - 2s 167ms/step
# Target:  Hillary Clinton
#               precision    recall  f1-score   support
#
#      AGAINST       0.80      0.47      0.59       172
#        FAVOR       0.38      0.18      0.24        45
#         NONE       0.39      0.86      0.53        78
#
#     accuracy                           0.53       295
#    macro avg       0.52      0.50      0.46       295
# weighted avg       0.63      0.53      0.52       295
#
# -----------------------------------------
# <ipython-input-16-7822421f7f5a>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 9/9 [==============================] - 2s 169ms/step
# Target:  Legalization of Abortion
#               precision    recall  f1-score   support
#
#      AGAINST       0.85      0.48      0.61       189
#        FAVOR       0.34      0.59      0.43        46
#         NONE       0.42      0.87      0.57        45
#
#     accuracy                           0.56       280
#    macro avg       0.54      0.65      0.54       280
# weighted avg       0.70      0.56      0.58       280
#
# -----------------------------------------
# <ipython-input-16-7822421f7f5a>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 23/23 [==============================] - 5s 217ms/step
# Target:  Donald Trump
#               precision    recall  f1-score   support
#
#      AGAINST       0.46      0.06      0.10       299
#        FAVOR       0.50      0.05      0.10       148
#         NONE       0.37      0.94      0.53       260
#
#     accuracy                           0.38       707
#    macro avg       0.44      0.35      0.24       707
# weighted avg       0.44      0.38      0.26       707
#
# -----------------------------------------
# <ipython-input-16-7822421f7f5a>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
#                                   Weighted F1  Macro F1  Accuracy
# Target
# Atheism                              0.588765  0.475341  0.554545
# Climate Change is a Real Concern     0.787257  0.535059  0.810651
# Feminist Movement                    0.549823  0.511983  0.536842
# Hillary Clinton                      0.524124  0.456565  0.528814
# Legalization of Abortion             0.576280  0.536218  0.560714
# Donald Trump                         0.259566  0.244223  0.380481

# %%
# Get model predictions
predictions = inital_model.predict([test_input_ids, test_attention_masks])

# Convert predictions to class labels
predicted_labels = np.argmax(predictions, axis=1)

# Assuming test_labels are one-hot encoded, convert them to class labels
true_labels = np.argmax(test_labels, axis=1)

# Generate classification report
report = classification_report(true_labels, predicted_labels)
print(report)
# Out:
# 62/62 [==============================] - 11s 174ms/step
#               precision    recall  f1-score   support
#
#            0       0.77      0.52      0.62      1014
#            1       0.54      0.61      0.57       452
#            2       0.49      0.76      0.59       490
#
#     accuracy                           0.60      1956
#    macro avg       0.60      0.63      0.59      1956
# weighted avg       0.64      0.60      0.60      1956

# %%
inital_model.save('roberta_model_3.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
