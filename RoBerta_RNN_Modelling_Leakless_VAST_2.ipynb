# %%
# !pip install plotly
# !pip install seaborn
# !pip install matplotlib
# !pip install transformers
# !pip install tokenizers
# !pip install scikit-learn
# !pip install tensorflow
# !pip install pandas
# !pip install numpy
# !pip install keras_tuner


# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# #
# <a id="data-prep"></a>
# <div style="background-color: #000D5B; color: white; text-align: center; padding: 6px 0 22px 0">
#     <h3 style="background-color: #000D5B; color: white; text-align: left">RMIT School of Computer Science and Technology</h3>
#     <br/>
#     <h1>COSC3007: Deep Learning</h1>
#     <h2>Assignment 2: Stance Twitter Sentiment Analysis and Detection </h2>
#     <h2> [2] MODELLING AND MODEL EVALUATIONS </h2>
#
# </div>

# %% [markdown]
# # Import Libs

# %%
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, BatchNormalization, Bidirectional, Flatten
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers.legacy import Adam
from sklearn.metrics import classification_report
import numpy as np

import numpy as np

# %% [markdown]
# # [1] Load Data

# %%
train_df = pd.read_csv("./drive/MyDrive/Colab Notebooks/StanceDataset/processed_train_augumented_vast.csv", encoding = "ISO-8859-1", engine="python").drop(columns=['Unnamed: 0'])
train_df = train_df.sample(frac=1, random_state=42).reset_index(drop=True)
train_ori = train_df.copy()

test_df = pd.read_csv("./drive/MyDrive/Colab Notebooks/StanceDataset/processed_test_augumented_vast.csv", encoding = "ISO-8859-1", engine="python").drop(columns=['Unnamed: 0'])

# %%
print(len(train_ori))
print(len(test_df))
# Out:
# 16391
# 1956

# %% [markdown]
# # [2] Prepare label and fit data

# %% [markdown]
# ## Split test and val

# %%
train_df, val_df = train_test_split(train_df, test_size=0.2, random_state=42, stratify=train_df['Stance'])

# %% [markdown]
# ## Tweets

# %%
from transformers import TFRobertaModel, RobertaTokenizer
import numpy as np

# Initialize the BERT tokenizer
MAX_LENGTH = 512
tokenizer = RobertaTokenizer.from_pretrained('roberta-base')
roberta_model = TFRobertaModel.from_pretrained('roberta-base')

# Assuming train_texts, val_texts, test_texts are your datasets
train_processed_tweets = train_df['Tweet'].tolist()
val_processed_tweets = val_df['Tweet'].tolist()
test_processed_tweets = test_df['Tweet'].tolist()

all_processed_tweets = train_processed_tweets + val_processed_tweets + test_processed_tweets
tokenized_tweets = [tokenizer.encode(tweet, add_special_tokens=True) for tweet in all_processed_tweets]
MAX_LENGTH = max(len(tweet) for tweet in tokenized_tweets)
MAX_LENGTH = 128

print("Maximum length across all datasets:", MAX_LENGTH)

target_names = {
    0: "Hillary Clinton",
    1: "Legalization of Abortion",
    2: "Atheism",
    3: "Climate Change is a Real Concern",
    4: "Feminist Movement",
    5: "Donald Trump",
    6: "Joe Biden",
    7: "Barack Obama",
    8: "Kamala Harris",
    9: "Bernie Sanders",
    10: "Vu",
}

def bert_tokenize(texts, targets, max_length=MAX_LENGTH):
    input_ids = []
    attention_masks = []

    for idx, text in enumerate(texts):
        target_name = targets[idx]
        # target_name = target_names.get(targetID, "")
        formatted_text = f"<s> {target_name} </s></s> {text} </s>"
        encoded = tokenizer.encode_plus(
            formatted_text,
            add_special_tokens=True,
            max_length=max_length,
            truncation=True,
            padding='max_length',
            return_attention_mask=True,
            return_tensors='tf',
        )

        # Flatten the tensors and remove the extra dimension
        input_ids.append(tf.squeeze(encoded['input_ids'], axis=0))
        attention_masks.append(tf.squeeze(encoded['attention_mask'], axis=0))

    return np.array(input_ids), np.array(attention_masks)

# Assuming you have lists of preprocessed texts for training, validation, and test sets
train_input_ids, train_attention_masks = bert_tokenize(train_df['Tweet'],  train_df['Target'].to_list())
val_input_ids, val_attention_masks = bert_tokenize(val_df['Tweet'], val_df['Target'].to_list())
test_input_ids, test_attention_masks = bert_tokenize(test_df['Tweet'], test_df['Target'].to_list())

print(train_input_ids.shape)
print(val_input_ids.shape)
print(test_input_ids.shape)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/481 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFRobertaModel: ['lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.layer_norm.bias', 'roberta.embeddings.position_ids', 'lm_head.dense.weight']
# - This IS expected if you are initializing TFRobertaModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFRobertaModel were not initialized from the PyTorch model and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Maximum length across all datasets: 128
# (13112, 128)
# (3279, 128)
# (1956, 128)

# %% [markdown]
# ## Stances

# %%
def categorized_label(df, label_name):
    label_encoder = LabelEncoder()
    encoded_labels = label_encoder.fit_transform(df[label_name])
    categorical_labels = to_categorical(encoded_labels)
    return categorical_labels

# %%
train_labels = categorized_label(train_df, "Stance")
test_labels = categorized_label(test_df, "Stance")
val_labels = categorized_label(val_df, "Stance")

# %% [markdown]
# # [3] Create Model

# %%
from keras import backend as K
from tensorflow.keras.optimizers.legacy import Adam
from hyperopt import hp
from hyperopt import hp, fmin, tpe, STATUS_OK, Trials
# import keras_tuner as kt

# %%
def f1_score_class(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))

    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    return 2 * ((precision * recall) / (precision + recall + K.epsilon()))

def f1_score(y_true, y_pred):
    # Convert predictions to one-hot format
    y_pred_one_hot = K.one_hot(K.argmax(y_pred), num_classes=3)

    # Calculate F1 score for each class
    f1s = [f1_score_class(y_true[:, i], y_pred_one_hot[:, i]) for i in range(3)]

    # Average F1 scores across all classes
    return K.mean(K.stack(f1s), axis=0)

# %% [markdown]
# Set up call backs and learning rates

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint


# Define the EarlyStopping and ReduceLROnPlateau callbacks
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=10,
    verbose=1,
    restore_best_weights=True,
)

early_stopping2 = EarlyStopping(
    monitor='val_loss',
    patience=5,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=5,
    min_lr=1e-5,
    verbose=1,
)

# Define the ModelCheckpoint callback
checkpoint_path = "roberta_best_model.h5"
model_checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_path,
    save_weights_only=True,    # Only save a model if 'val_loss' has improved
    monitor='val_loss',     # Monitor 'val_loss' during training
    mode='min',             # The model is saved when 'val_loss' is minimized
    verbose=1)

# Combine all callbacks in a list
callbacks = [
    early_stopping,
    lr_scheduler,
    model_checkpoint_callback
]

# Combine all callbacks in a list
callbacks2 = [
    early_stopping2,
    lr_scheduler,
    model_checkpoint_callback
]

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, BatchNormalization, Bidirectional, Flatten, Input, GlobalMaxPooling1D
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers.legacy import Adam
# import keras_tuner as kt
from transformers import TFRobertaModel

def build_model(drop, regr, lr):
    bert_model = TFRobertaModel.from_pretrained('roberta-base')
    bert_model.trainable = False

    # Define model input (BERT expects two inputs: input_ids and attention_mask)
    input_ids = Input(shape=(MAX_LENGTH,), dtype=tf.int32, name='input_ids')
    attention_mask = Input(shape=(MAX_LENGTH,), dtype=tf.int32, name='attention_mask')

    # Get BERT embeddings
    bert_output = bert_model(input_ids, attention_mask=attention_mask)[0]  # Use the pooled output here

    # Tuning the number of units in the first biLSTM layer
    x = Bidirectional(LSTM(units=64,  dropout=drop, recurrent_dropout=drop,return_sequences=True,kernel_regularizer=tf.keras.regularizers.l2(regr))) (bert_output)

    x = GlobalMaxPooling1D()(x)

    # Dense layer with tunable units
    x = Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(regr)) (x)

    # Tunable dropout rate for the second layer
    x = Dropout(drop)(x)

    # Final Layer
    x = Dense(3, activation='softmax')(x)

    # Tuning the learning rate for the optimizer
    optimizer = Adam(learning_rate=lr)
    model = Model(inputs=[input_ids, attention_mask], outputs=x)
    model.compile(loss='CategoricalCrossentropy', optimizer=optimizer, metrics=['categorical_accuracy',f1_score])
    model.summary()

    return model

# %% [markdown]
# Recreate the best model with more training time

# %%
history = {}
inital_model = build_model(0.8, 0.0005, 0.001)
history['tuned_stance_model_custom'] = inital_model.fit([train_input_ids, train_attention_masks], train_labels,
                    epochs=1000,
                    validation_data=([val_input_ids, val_attention_masks], val_labels),
                    batch_size=256,
                    callbacks=callbacks)
# Out:
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFRobertaModel: ['lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.layer_norm.bias', 'roberta.embeddings.position_ids', 'lm_head.dense.weight']
# - This IS expected if you are initializing TFRobertaModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFRobertaModel were not initialized from the PyTorch model and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_ids (InputLayer)      [(None, 128)]                0         []
#
#  attention_mask (InputLayer  [(None, 128)]                0         []
#  )
#
#  tf_roberta_model_1 (TFRobe  TFBaseModelOutputWithPooli   1246456   ['input_ids[0][0]',
#  rtaModel)                   ngAndCrossAttentions(last_   32         'attention_mask[0][0]']
#                              hidden_state=(None, 128, 7
#                              68),
#                               pooler_output=(None, 768)
#                              , past_key_values=None, hi
#                              dden_states=None, attentio
#                              ns=None, cross_attentions=
#                              None)
#
#  bidirectional (Bidirection  (None, 128, 128)             426496    ['tf_roberta_model_1[0][0]']
#  al)
#
#  global_max_pooling1d (Glob  (None, 128)                  0         ['bidirectional[0][0]']
#  alMaxPooling1D)
#
#  dense (Dense)               (None, 128)                  16512     ['global_max_pooling1d[0][0]']
#
#  dropout_74 (Dropout)        (None, 128)                  0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 3)                    387       ['dropout_74[0][0]']
#
# ==================================================================================================
# Total params: 125089027 (477.18 MB)
# Trainable params: 443395 (1.69 MB)
# Non-trainable params: 124645632 (475.49 MB)
# __________________________________________________________________________________________________
# Epoch 1/1000
# 52/52 [==============================] - ETA: 0s - loss: 1.5264 - categorical_accuracy: 0.4043 - f1_score: 0.2993
# Epoch 1: saving model to roberta_best_model.h5
# 52/52 [==============================] - 85s 1s/step - loss: 1.5264 - categorical_accuracy: 0.4043 - f1_score: 0.2993 - val_loss: 1.4077 - val_categorical_accuracy: 0.4346 - val_f1_score: 0.2341 - lr: 0.0010
# Epoch 2/1000
# 52/52 [==============================] - ETA: 0s - loss: 1.3586 - categorical_accuracy: 0.4256 - f1_score: 0.2897
# Epoch 2: saving model to roberta_best_model.h5
# 52/52 [==============================] - 61s 1s/step - loss: 1.3586 - categorical_accuracy: 0.4256 - f1_score: 0.2897 - val_loss: 1.3156 - val_categorical_accuracy: 0.4263 - val_f1_score: 0.1985 - lr: 0.0010
# Epoch 3/1000
# 52/52 [==============================] - ETA: 0s - loss: 1.2701 - categorical_accuracy: 0.4353 - f1_score: 0.3057
# Epoch 3: saving model to roberta_best_model.h5
# 52/52 [==============================] - 61s 1s/step - loss: 1.2701 - categorical_accuracy: 0.4353 - f1_score: 0.3057 - val_loss: 1.2438 - val_categorical_accuracy: 0.4422 - val_f1_score: 0.2358 - lr: 0.0010
# Epoch 4/1000
# 52/52 [==============================] - ETA: 0s - loss: 1.2161 - categorical_accuracy: 0.4458 - f1_score: 0.3134
# Epoch 4: saving model to roberta_best_model.h5
# 52/52 [==============================] - 61s 1s/step - loss: 1.2161 - categorical_accuracy: 0.4458 - f1_score: 0.3134 - val_loss: 1.1980 - val_categorical_accuracy: 0.4401 - val_f1_score: 0.2335 - lr: 0.0010
# Epoch 5/1000
# 52/52 [==============================] - ETA: 0s - loss: 1.1764 - categorical_accuracy: 0.4522 - f1_score: 0.3170
# Epoch 5: saving model to roberta_best_model.h5
# 52/52 [==============================] - 61s 1s/step - loss: 1.1764 - categorical_accuracy: 0.4522 - f1_score: 0.3170 - val_loss: 1.1638 - val_categorical_accuracy: 0.4681 - val_f1_score: 0.3060 - lr: 0.0010
# Epoch 6/1000
# 52/52 [==============================] - ETA: 0s - loss: 1.1480 - categorical_accuracy: 0.4747 - f1_score: 0.3394
# Epoch 6: saving model to roberta_best_model.h5
# 52/52 [==============================] - 61s 1s/step - loss: 1.1480 - categorical_accuracy: 0.4747 - f1_score: 0.3394 - val_loss: 1.1359 - val_categorical_accuracy: 0.5026 - val_f1_score: 0.3519 - lr: 0.0010
# Epoch 7/1000
# 52/52 [==============================] - ETA: 0s - loss: 1.1282 - categorical_accuracy: 0.4773 - f1_score: 0.3406
# Epoch 7: saving model to roberta_best_model.h5
# 52/52 [==============================] - 61s 1s/step - loss: 1.1282 - categorical_accuracy: 0.4773 - f1_score: 0.3406 - val_loss: 1.1053 - val_categorical_accuracy: 0.5099 - val_f1_score: 0.3733 - lr: 0.0010
# Epoch 8/1000
# 52/52 [==============================] - ETA: 0s - loss: 1.1059 - categorical_accuracy: 0.4964 - f1_score: 0.3603
# Epoch 8: saving model to roberta_best_model.h5
# 52/52 [==============================] - 60s 1s/step - loss: 1.1059 - categorical_accuracy: 0.4964 - f1_score: 0.3603 - val_loss: 1.0863 - val_categorical_accuracy: 0.5221 - val_f1_score: 0.3836 - lr: 0.0010
# Epoch 9/1000
# 52/52 [==============================] - ETA: 0s - loss: 1.0951 - categorical_accuracy: 0.5014 - f1_score: 0.3613
# Epoch 9: saving model to roberta_best_model.h5
# 52/52 [==============================] - 61s 1s/step - loss: 1.0951 - categorical_accuracy: 0.5014 - f1_score: 0.3613 - val_loss: 1.0735 - val_categorical_accuracy: 0.5285 - val_f1_score: 0.3760 - lr: 0.0010
# Epoch 10/1000
# 52/52 [==============================] - ETA: 0s - loss: 1.0780 - categorical_accuracy: 0.5057 - f1_score: 0.3650
# Epoch 10: saving model to roberta_best_model.h5
# 52/52 [==============================] - 61s 1s/step - loss: 1.0780 - categorical_accuracy: 0.5057 - f1_score: 0.3650 - val_loss: 1.0521 - val_categorical_accuracy: 0.5325 - val_f1_score: 0.3845 - lr: 0.0010
# Epoch 11/1000
# 52/52 [==============================] - ETA: 0s - loss: 1.0654 - categorical_accuracy: 0.5071 - f1_score: 0.3646
# Epoch 11: saving model to roberta_best_model.h5
# 52/52 [==============================] - 61s 1s/step - loss: 1.0654 - categorical_accuracy: 0.5071 - f1_score: 0.3646 - val_loss: 1.0427 - val_categorical_accuracy: 0.5303 - val_f1_score: 0.3861 - lr: 0.0010
# Epoch 12/1000
# 52/52 [==============================] - ETA: 0s - loss: 1.0479 - categorical_accuracy: 0.5110 - f1_score: 0.3763
# Epoch 12: saving model to roberta_best_model.h5
# 52/52 [==============================] - 60s 1s/step - loss: 1.0479 - categorical_accuracy: 0.5110 - f1_score: 0.3763 - val_loss: 1.0269 - val_categorical_accuracy: 0.5432 - val_f1_score: 0.3980 - lr: 0.0010
# Epoch 13/1000
# 52/52 [==============================] - ETA: 0s - loss: 1.0387 - categorical_accuracy: 0.5077 - f1_score: 0.3855
# Epoch 13: saving model to roberta_best_model.h5
# 52/52 [==============================] - 61s 1s/step - loss: 1.0387 - categorical_accuracy: 0.5077 - f1_score: 0.3855 - val_loss: 1.0104 - val_categorical_accuracy: 0.5371 - val_f1_score: 0.3952 - lr: 0.0010
# Epoch 14/1000
# 52/52 [==============================] - ETA: 0s - loss: 1.0342 - categorical_accuracy: 0.5169 - f1_score: 0.4058
# Epoch 14: saving model to roberta_best_model.h5
# 52/52 [==============================] - 60s 1s/step - loss: 1.0342 - categorical_accuracy: 0.5169 - f1_score: 0.4058 - val_loss: 1.0185 - val_categorical_accuracy: 0.5203 - val_f1_score: 0.4091 - lr: 0.0010
# Epoch 15/1000
# 52/52 [==============================] - ETA: 0s - loss: 1.0243 - categorical_accuracy: 0.5171 - f1_score: 0.4247
# Epoch 15: saving model to roberta_best_model.h5
# 52/52 [==============================] - 60s 1s/step - loss: 1.0243 - categorical_accuracy: 0.5171 - f1_score: 0.4247 - val_loss: 0.9986 - val_categorical_accuracy: 0.5358 - val_f1_score: 0.5093 - lr: 0.0010
# Epoch 16/1000
# 52/52 [==============================] - ETA: 0s - loss: 1.0096 - categorical_accuracy: 0.5338 - f1_score: 0.4710
# Epoch 16: saving model to roberta_best_model.h5
# 52/52 [==============================] - 61s 1s/step - loss: 1.0096 - categorical_accuracy: 0.5338 - f1_score: 0.4710 - val_loss: 1.0024 - val_categorical_accuracy: 0.5306 - val_f1_score: 0.4547 - lr: 0.0010
# Epoch 17/1000
# 52/52 [==============================] - ETA: 0s - loss: 1.0011 - categorical_accuracy: 0.5345 - f1_score: 0.4620
# Epoch 17: saving model to roberta_best_model.h5
# 52/52 [==============================] - 61s 1s/step - loss: 1.0011 - categorical_accuracy: 0.5345 - f1_score: 0.4620 - val_loss: 0.9576 - val_categorical_accuracy: 0.5624 - val_f1_score: 0.5152 - lr: 0.0010
# Epoch 18/1000
# 52/52 [==============================] - ETA: 0s - loss: 1.0036 - categorical_accuracy: 0.5331 - f1_score: 0.4698
# Epoch 18: saving model to roberta_best_model.h5
# 52/52 [==============================] - 60s 1s/step - loss: 1.0036 - categorical_accuracy: 0.5331 - f1_score: 0.4698 - val_loss: 0.9606 - val_categorical_accuracy: 0.5791 - val_f1_score: 0.5469 - lr: 0.0010
# Epoch 19/1000
# 52/52 [==============================] - ETA: 0s - loss: 0.9824 - categorical_accuracy: 0.5436 - f1_score: 0.4923
# Epoch 19: saving model to roberta_best_model.h5
# 52/52 [==============================] - 60s 1s/step - loss: 0.9824 - categorical_accuracy: 0.5436 - f1_score: 0.4923 - val_loss: 0.9590 - val_categorical_accuracy: 0.5797 - val_f1_score: 0.5479 - lr: 0.0010
# Epoch 20/1000
# 52/52 [==============================] - ETA: 0s - loss: 0.9834 - categorical_accuracy: 0.5432 - f1_score: 0.4931
# Epoch 20: saving model to roberta_best_model.h5
# 52/52 [==============================] - 60s 1s/step - loss: 0.9834 - categorical_accuracy: 0.5432 - f1_score: 0.4931 - val_loss: 0.9601 - val_categorical_accuracy: 0.5660 - val_f1_score: 0.5599 - lr: 0.0010
# Epoch 21/1000
# 52/52 [==============================] - ETA: 0s - loss: 0.9864 - categorical_accuracy: 0.5474 - f1_score: 0.4984
# Epoch 21: saving model to roberta_best_model.h5
# 52/52 [==============================] - 61s 1s/step - loss: 0.9864 - categorical_accuracy: 0.5474 - f1_score: 0.4984 - val_loss: 0.9574 - val_categorical_accuracy: 0.5840 - val_f1_score: 0.5678 - lr: 0.0010
# Epoch 22/1000
# 52/52 [==============================] - ETA: 0s - loss: 0.9843 - categorical_accuracy: 0.5501 - f1_score: 0.5095
# Epoch 22: saving model to roberta_best_model.h5
# 52/52 [==============================] - 61s 1s/step - loss: 0.9843 - categorical_accuracy: 0.5501 - f1_score: 0.5095 - val_loss: 0.9413 - val_categorical_accuracy: 0.5865 - val_f1_score: 0.5737 - lr: 0.0010
# Epoch 23/1000
# 52/52 [==============================] - ETA: 0s - loss: 0.9678 - categorical_accuracy: 0.5612 - f1_score: 0.5191
# Epoch 23: saving model to roberta_best_model.h5
# 52/52 [==============================] - 60s 1s/step - loss: 0.9678 - categorical_accuracy: 0.5612 - f1_score: 0.5191 - val_loss: 0.9462 - val_categorical_accuracy: 0.5868 - val_f1_score: 0.5729 - lr: 0.0010
# Epoch 24/1000
# 52/52 [==============================] - ETA: 0s - loss: 0.9662 - categorical_accuracy: 0.5630 - f1_score: 0.5236
# Epoch 24: saving model to roberta_best_model.h5
# 52/52 [==============================] - 60s 1s/step - loss: 0.9662 - categorical_accuracy: 0.5630 - f1_score: 0.5236 - val_loss: 0.9463 - val_categorical_accuracy: 0.5761 - val_f1_score: 0.5567 - lr: 0.0010
# Epoch 25/1000
# 52/52 [==============================] - ETA: 0s - loss: 0.9696 - categorical_accuracy: 0.5593 - f1_score: 0.5216
# Epoch 25: saving model to roberta_best_model.h5
# 52/52 [==============================] - 60s 1s/step - loss: 0.9696 - categorical_accuracy: 0.5593 - f1_score: 0.5216 - val_loss: 0.9506 - val_categorical_accuracy: 0.5642 - val_f1_score: 0.5588 - lr: 0.0010
# Epoch 26/1000
# 52/52 [==============================] - ETA: 0s - loss: 0.9615 - categorical_accuracy: 0.5647 - f1_score: 0.5271
# Epoch 26: saving model to roberta_best_model.h5
# 52/52 [==============================] - 60s 1s/step - loss: 0.9615 - categorical_accuracy: 0.5647 - f1_score: 0.5271 - val_loss: 0.9289 - val_categorical_accuracy: 0.5810 - val_f1_score: 0.5702 - lr: 0.0010
# Epoch 27/1000
# 52/52 [==============================] - ETA: 0s - loss: 0.9622 - categorical_accuracy: 0.5656 - f1_score: 0.5294
# Epoch 27: saving model to roberta_best_model.h5
# 52/52 [==============================] - 60s 1s/step - loss: 0.9622 - categorical_accuracy: 0.5656 - f1_score: 0.5294 - val_loss: 0.9311 - val_categorical_accuracy: 0.5877 - val_f1_score: 0.5756 - lr: 0.0010
# Epoch 28/1000
# 52/52 [==============================] - ETA: 0s - loss: 0.9502 - categorical_accuracy: 0.5766 - f1_score: 0.5441
# Epoch 28: saving model to roberta_best_model.h5
# 52/52 [==============================] - 60s 1s/step - loss: 0.9502 - categorical_accuracy: 0.5766 - f1_score: 0.5441 - val_loss: 0.9453 - val_categorical_accuracy: 0.5852 - val_f1_score: 0.5797 - lr: 0.0010
# Epoch 29/1000
# 52/52 [==============================] - ETA: 0s - loss: 0.9541 - categorical_accuracy: 0.5693 - f1_score: 0.5332
# Epoch 29: saving model to roberta_best_model.h5
# 52/52 [==============================] - 61s 1s/step - loss: 0.9541 - categorical_accuracy: 0.5693 - f1_score: 0.5332 - val_loss: 0.9187 - val_categorical_accuracy: 0.5889 - val_f1_score: 0.5790 - lr: 0.0010
# Epoch 30/1000
# 52/52 [==============================] - ETA: 0s - loss: 0.9470 - categorical_accuracy: 0.5705 - f1_score: 0.5338
# Epoch 30: saving model to roberta_best_model.h5
# 52/52 [==============================] - 61s 1s/step - loss: 0.9470 - categorical_accuracy: 0.5705 - f1_score: 0.5338 - val_loss: 0.9161 - val_categorical_accuracy: 0.5959 - val_f1_score: 0.5785 - lr: 0.0010
# Epoch 31/1000
# 52/52 [==============================] - ETA: 0s - loss: 0.9411 - categorical_accuracy: 0.5792 - f1_score: 0.5492
# Epoch 31: saving model to roberta_best_model.h5
# 52/52 [==============================] - 61s 1s/step - loss: 0.9411 - categorical_accuracy: 0.5792 - f1_score: 0.5492 - val_loss: 0.9392 - val_categorical_accuracy: 0.5740 - val_f1_score: 0.5508 - lr: 0.0010
# Epoch 32/1000
# 52/52 [==============================] - ETA: 0s - loss: 0.9389 - categorical_accuracy: 0.5842 - f1_score: 0.5535
# Epoch 32: saving model to roberta_best_model.h5
# 52/52 [==============================] - 60s 1s/step - loss: 0.9389 - categorical_accuracy: 0.5842 - f1_score: 0.5535 - val_loss: 0.9288 - val_categorical_accuracy: 0.5791 - val_f1_score: 0.5737 - lr: 0.0010
# Epoch 33/1000
# 52/52 [==============================] - ETA: 0s - loss: 0.9358 - categorical_accuracy: 0.5847 - f1_score: 0.5563
# Epoch 33: saving model to roberta_best_model.h5
# 52/52 [==============================] - 60s 1s/step - loss: 0.9358 - categorical_accuracy: 0.5847 - f1_score: 0.5563 - val_loss: 0.9099 - val_categorical_accuracy: 0.5910 - val_f1_score: 0.5779 - lr: 0.0010
# Epoch 34/1000
# 52/52 [==============================] - ETA: 0s - loss: 0.9406 - categorical_accuracy: 0.5847 - f1_score: 0.5575
# Epoch 34: saving model to roberta_best_model.h5
# 52/52 [==============================] - 61s 1s/step - loss: 0.9406 - categorical_accuracy: 0.5847 - f1_score: 0.5575 - val_loss: 0.8901 - val_categorical_accuracy: 0.6179 - val_f1_score: 0.6117 - lr: 0.0010
# Epoch 35/1000
# 52/52 [==============================] - ETA: 0s - loss: 0.9299 - categorical_accuracy: 0.5867 - f1_score: 0.5568
# Epoch 35: saving model to roberta_best_model.h5
# 52/52 [==============================] - 60s 1s/step - loss: 0.9299 - categorical_accuracy: 0.5867 - f1_score: 0.5568 - val_loss: 0.9040 - val_categorical_accuracy: 0.5984 - val_f1_score: 0.5831 - lr: 0.0010
# Epoch 36/1000
# 52/52 [==============================] - ETA: 0s - loss: 0.9323 - categorical_accuracy: 0.5910 - f1_score: 0.5666
# Epoch 36: saving model to roberta_best_model.h5
# 52/52 [==============================] - 61s 1s/step - loss: 0.9323 - categorical_accuracy: 0.5910 - f1_score: 0.5666 - val_loss: 0.8893 - val_categorical_accuracy: 0.6081 - val_f1_score: 0.5922 - lr: 0.0010
# Epoch 37/1000
# 52/52 [==============================] - ETA: 0s - loss: 0.9288 - categorical_accuracy: 0.5946 - f1_score: 0.5697
# Epoch 37: saving model to roberta_best_model.h5
# 52/52 [==============================] - 60s 1s/step - loss: 0.9288 - categorical_accuracy: 0.5946 - f1_score: 0.5697 - val_loss: 0.8960 - val_categorical_accuracy: 0.6063 - val_f1_score: 0.5966 - lr: 0.0010
# Epoch 38/1000
# 52/52 [==============================] - ETA: 0s - loss: 0.9330 - categorical_accuracy: 0.5872 - f1_score: 0.5631
# Epoch 38: saving model to roberta_best_model.h5
# 52/52 [==============================] - 61s 1s/step - loss: 0.9330 - categorical_accuracy: 0.5872 - f1_score: 0.5631 - val_loss: 0.8812 - val_categorical_accuracy: 0.6145 - val_f1_score: 0.6018 - lr: 0.0010
# Epoch 39/1000
# 52/52 [==============================] - ETA: 0s - loss: 0.9256 - categorical_accuracy: 0.5924 - f1_score: 0.5690
# Epoch 39: saving model to roberta_best_model.h5
# 52/52 [==============================] - 60s 1s/step - loss: 0.9256 - categorical_accuracy: 0.5924 - f1_score: 0.5690 - val_loss: 0.9169 - val_categorical_accuracy: 0.5862 - val_f1_score: 0.5693 - lr: 0.0010
# Epoch 40/1000
# 52/52 [==============================] - ETA: 0s - loss: 0.9263 - categorical_accuracy: 0.5955 - f1_score: 0.5734
# Epoch 40: saving model to roberta_best_model.h5
# 52/52 [==============================] - 61s 1s/step - loss: 0.9263 - categorical_accuracy: 0.5955 - f1_score: 0.5734 - val_loss: 0.9285 - val_categorical_accuracy: 0.5746 - val_f1_score: 0.5458 - lr: 0.0010
# Epoch 41/1000
# 52/52 [==============================] - ETA: 0s - loss: 0.9244 - categorical_accuracy: 0.5958 - f1_score: 0.5726
# Epoch 41: saving model to roberta_best_model.h5
# 52/52 [==============================] - 60s 1s/step - loss: 0.9244 - categorical_accuracy: 0.5958 - f1_score: 0.5726 - val_loss: 0.9071 - val_categorical_accuracy: 0.5950 - val_f1_score: 0.5822 - lr: 0.0010
# Epoch 42/1000
# 52/52 [==============================] - ETA: 0s - loss: 0.9185 - categorical_accuracy: 0.5980 - f1_score: 0.5787
# Epoch 42: saving model to roberta_best_model.h5
# 52/52 [==============================] - 60s 1s/step - loss: 0.9185 - categorical_accuracy: 0.5980 - f1_score: 0.5787 - val_loss: 0.9048 - val_categorical_accuracy: 0.5883 - val_f1_score: 0.5787 - lr: 0.0010
# Epoch 43/1000
# 52/52 [==============================] - ETA: 0s - loss: 0.9226 - categorical_accuracy: 0.5956 - f1_score: 0.5735
# Epoch 43: saving model to roberta_best_model.h5
# 52/52 [==============================] - 61s 1s/step - loss: 0.9226 - categorical_accuracy: 0.5956 - f1_score: 0.5735 - val_loss: 0.8808 - val_categorical_accuracy: 0.6032 - val_f1_score: 0.5953 - lr: 0.0010
# Epoch 44/1000
# 52/52 [==============================] - ETA: 0s - loss: 0.9155 - categorical_accuracy: 0.6012 - f1_score: 0.5814
# Epoch 44: saving model to roberta_best_model.h5
# 52/52 [==============================] - 60s 1s/step - loss: 0.9155 - categorical_accuracy: 0.6012 - f1_score: 0.5814 - val_loss: 0.9173 - val_categorical_accuracy: 0.5779 - val_f1_score: 0.5672 - lr: 0.0010
# Epoch 45/1000
# 52/52 [==============================] - ETA: 0s - loss: 0.9128 - categorical_accuracy: 0.6103 - f1_score: 0.5913
# Epoch 45: saving model to roberta_best_model.h5
# 52/52 [==============================] - 61s 1s/step - loss: 0.9128 - categorical_accuracy: 0.6103 - f1_score: 0.5913 - val_loss: 0.8612 - val_categorical_accuracy: 0.6298 - val_f1_score: 0.6246 - lr: 0.0010
# Epoch 46/1000
# 52/52 [==============================] - ETA: 0s - loss: 0.9233 - categorical_accuracy: 0.5970 - f1_score: 0.5715
# Epoch 46: saving model to roberta_best_model.h5
# 52/52 [==============================] - 61s 1s/step - loss: 0.9233 - categorical_accuracy: 0.5970 - f1_score: 0.5715 - val_loss: 0.9187 - val_categorical_accuracy: 0.5956 - val_f1_score: 0.5837 - lr: 0.0010
# Epoch 47/1000
# 52/52 [==============================] - ETA: 0s - loss: 0.9143 - categorical_accuracy: 0.6033 - f1_score: 0.5815
# Epoch 47: saving model to roberta_best_model.h5
# 52/52 [==============================] - 60s 1s/step - loss: 0.9143 - categorical_accuracy: 0.6033 - f1_score: 0.5815 - val_loss: 0.8802 - val_categorical_accuracy: 0.6109 - val_f1_score: 0.6073 - lr: 0.0010
# Epoch 48/1000
# 52/52 [==============================] - ETA: 0s - loss: 0.9112 - categorical_accuracy: 0.6081 - f1_score: 0.5874
# Epoch 48: saving model to roberta_best_model.h5
# 52/52 [==============================] - 60s 1s/step - loss: 0.9112 - categorical_accuracy: 0.6081 - f1_score: 0.5874 - val_loss: 0.8819 - val_categorical_accuracy: 0.6002 - val_f1_score: 0.5880 - lr: 0.0010
# Epoch 49/1000
# 52/52 [==============================] - ETA: 0s - loss: 0.9109 - categorical_accuracy: 0.6059 - f1_score: 0.5879
# Epoch 49: saving model to roberta_best_model.h5
# 52/52 [==============================] - 60s 1s/step - loss: 0.9109 - categorical_accuracy: 0.6059 - f1_score: 0.5879 - val_loss: 0.8791 - val_categorical_accuracy: 0.6087 - val_f1_score: 0.6002 - lr: 0.0010
# Epoch 50/1000
# 52/52 [==============================] - ETA: 0s - loss: 0.9054 - categorical_accuracy: 0.6088 - f1_score: 0.5870
# Epoch 50: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 50: saving model to roberta_best_model.h5
# 52/52 [==============================] - 61s 1s/step - loss: 0.9054 - categorical_accuracy: 0.6088 - f1_score: 0.5870 - val_loss: 0.8982 - val_categorical_accuracy: 0.5950 - val_f1_score: 0.5677 - lr: 0.0010
# Epoch 51/1000
# 52/52 [==============================] - ETA: 0s - loss: 0.8990 - categorical_accuracy: 0.6123 - f1_score: 0.5905
# Epoch 51: saving model to roberta_best_model.h5
# 52/52 [==============================] - 60s 1s/step - loss: 0.8990 - categorical_accuracy: 0.6123 - f1_score: 0.5905 - val_loss: 0.8744 - val_categorical_accuracy: 0.6173 - val_f1_score: 0.6058 - lr: 2.0000e-04
# Epoch 52/1000
# 52/52 [==============================] - ETA: 0s - loss: 0.8869 - categorical_accuracy: 0.6211 - f1_score: 0.6026
# Epoch 52: saving model to roberta_best_model.h5
# 52/52 [==============================] - 61s 1s/step - loss: 0.8869 - categorical_accuracy: 0.6211 - f1_score: 0.6026 - val_loss: 0.8536 - val_categorical_accuracy: 0.6234 - val_f1_score: 0.6154 - lr: 2.0000e-04
# Epoch 53/1000
# 52/52 [==============================] - ETA: 0s - loss: 0.8940 - categorical_accuracy: 0.6171 - f1_score: 0.6018
# Epoch 53: saving model to roberta_best_model.h5
# 52/52 [==============================] - 60s 1s/step - loss: 0.8940 - categorical_accuracy: 0.6171 - f1_score: 0.6018 - val_loss: 0.8615 - val_categorical_accuracy: 0.6173 - val_f1_score: 0.6067 - lr: 2.0000e-04
# Epoch 54/1000
# 52/52 [==============================] - ETA: 0s - loss: 0.8829 - categorical_accuracy: 0.6235 - f1_score: 0.6057
# Epoch 54: saving model to roberta_best_model.h5
# 52/52 [==============================] - 61s 1s/step - loss: 0.8829 - categorical_accuracy: 0.6235 - f1_score: 0.6057 - val_loss: 0.8410 - val_categorical_accuracy: 0.6285 - val_f1_score: 0.6210 - lr: 2.0000e-04
# Epoch 55/1000
# 52/52 [==============================] - ETA: 0s - loss: 0.8818 - categorical_accuracy: 0.6216 - f1_score: 0.6041
# Epoch 55: saving model to roberta_best_model.h5
# 52/52 [==============================] - 60s 1s/step - loss: 0.8818 - categorical_accuracy: 0.6216 - f1_score: 0.6041 - val_loss: 0.8591 - val_categorical_accuracy: 0.6182 - val_f1_score: 0.6091 - lr: 2.0000e-04
# Epoch 56/1000
# 52/52 [==============================] - ETA: 0s - loss: 0.8805 - categorical_accuracy: 0.6226 - f1_score: 0.6058
# Epoch 56: saving model to roberta_best_model.h5
# 52/52 [==============================] - 60s 1s/step - loss: 0.8805 - categorical_accuracy: 0.6226 - f1_score: 0.6058 - val_loss: 0.8647 - val_categorical_accuracy: 0.6160 - val_f1_score: 0.6064 - lr: 2.0000e-04
# Epoch 57/1000
# 52/52 [==============================] - ETA: 0s - loss: 0.8814 - categorical_accuracy: 0.6212 - f1_score: 0.6040
# Epoch 57: saving model to roberta_best_model.h5
# 52/52 [==============================] - 60s 1s/step - loss: 0.8814 - categorical_accuracy: 0.6212 - f1_score: 0.6040 - val_loss: 0.8567 - val_categorical_accuracy: 0.6194 - val_f1_score: 0.6102 - lr: 2.0000e-04
# Epoch 58/1000
# 52/52 [==============================] - ETA: 0s - loss: 0.8820 - categorical_accuracy: 0.6266 - f1_score: 0.6107
# Epoch 58: saving model to roberta_best_model.h5
# 52/52 [==============================] - 60s 1s/step - loss: 0.8820 - categorical_accuracy: 0.6266 - f1_score: 0.6107 - val_loss: 0.8527 - val_categorical_accuracy: 0.6221 - val_f1_score: 0.6134 - lr: 2.0000e-04
# Epoch 59/1000
# 52/52 [==============================] - ETA: 0s - loss: 0.8776 - categorical_accuracy: 0.6183 - f1_score: 0.6019
# Epoch 59: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 59: saving model to roberta_best_model.h5
# 52/52 [==============================] - 60s 1s/step - loss: 0.8776 - categorical_accuracy: 0.6183 - f1_score: 0.6019 - val_loss: 0.8464 - val_categorical_accuracy: 0.6243 - val_f1_score: 0.6158 - lr: 2.0000e-04
# Epoch 60/1000
# 52/52 [==============================] - ETA: 0s - loss: 0.8723 - categorical_accuracy: 0.6244 - f1_score: 0.6061
# Epoch 60: saving model to roberta_best_model.h5
# 52/52 [==============================] - 61s 1s/step - loss: 0.8723 - categorical_accuracy: 0.6244 - f1_score: 0.6061 - val_loss: 0.8475 - val_categorical_accuracy: 0.6258 - val_f1_score: 0.6164 - lr: 4.0000e-05
# Epoch 61/1000
# 52/52 [==============================] - ETA: 0s - loss: 0.8757 - categorical_accuracy: 0.6230 - f1_score: 0.6070
# Epoch 61: saving model to roberta_best_model.h5
# 52/52 [==============================] - 60s 1s/step - loss: 0.8757 - categorical_accuracy: 0.6230 - f1_score: 0.6070 - val_loss: 0.8447 - val_categorical_accuracy: 0.6264 - val_f1_score: 0.6179 - lr: 4.0000e-05
# Epoch 62/1000
# 52/52 [==============================] - ETA: 0s - loss: 0.8655 - categorical_accuracy: 0.6323 - f1_score: 0.6173
# Epoch 62: saving model to roberta_best_model.h5
# 52/52 [==============================] - 60s 1s/step - loss: 0.8655 - categorical_accuracy: 0.6323 - f1_score: 0.6173 - val_loss: 0.8426 - val_categorical_accuracy: 0.6270 - val_f1_score: 0.6181 - lr: 4.0000e-05
# Epoch 63/1000
# 52/52 [==============================] - ETA: 0s - loss: 0.8705 - categorical_accuracy: 0.6298 - f1_score: 0.6167
# Epoch 63: saving model to roberta_best_model.h5
# 52/52 [==============================] - 60s 1s/step - loss: 0.8705 - categorical_accuracy: 0.6298 - f1_score: 0.6167 - val_loss: 0.8443 - val_categorical_accuracy: 0.6243 - val_f1_score: 0.6156 - lr: 4.0000e-05
# Epoch 64/1000
# 52/52 [==============================] - ETA: 0s - loss: 0.8691 - categorical_accuracy: 0.6310 - f1_score: 0.6177Restoring model weights from the end of the best epoch: 54.
#
# Epoch 64: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 64: saving model to roberta_best_model.h5
# 52/52 [==============================] - 61s 1s/step - loss: 0.8691 - categorical_accuracy: 0.6310 - f1_score: 0.6177 - val_loss: 0.8429 - val_categorical_accuracy: 0.6255 - val_f1_score: 0.6172 - lr: 4.0000e-05
# Epoch 64: early stopping

# %%
results = inital_model.evaluate([test_input_ids, test_attention_masks], test_labels)
print('Test accuracy:', results)
# Out:
# 62/62 [==============================] - 9s 138ms/step - loss: 0.8456 - categorical_accuracy: 0.6401 - f1_score: 0.4413
# Test accuracy: [0.8456452488899231, 0.6400818228721619, 0.4413057565689087]

# %%
# Get model predictions
predictions = inital_model.predict([test_input_ids, test_attention_masks])

# Convert predictions to class labels
predicted_labels = np.argmax(predictions, axis=1)

# Assuming test_labels are one-hot encoded, convert them to class labels
true_labels = np.argmax(test_labels, axis=1)

# Generate classification report
report = classification_report(true_labels, predicted_labels)
print(report)
# Out:
# 62/62 [==============================] - 12s 136ms/step
#               precision    recall  f1-score   support
#
#            0       0.66      0.77      0.71      1014
#            1       0.64      0.40      0.49       452
#            2       0.59      0.59      0.59       490
#
#     accuracy                           0.64      1956
#    macro avg       0.63      0.59      0.60      1956
# weighted avg       0.64      0.64      0.63      1956

# %%
def load_classification_rp_per_target(model):
    targets = test_df.Target.unique()
    metrics_df = pd.DataFrame()
    for target in targets:
        extracted_df = test_df[test_df['Target'] == target]
        input_ids, attention_masks = bert_tokenize(extracted_df['Tweet'], extracted_df['Target'].to_list())
        labels = categorized_label(extracted_df, "Stance")

        # Convert one-hot encoded labels to single integer class labels
        true_labels = np.argmax(labels, axis=1)

        # Get model predictions
        predictions = model.predict([input_ids, attention_masks])

        # Convert predictions to class labels
        predicted_labels = np.argmax(predictions, axis=1)

        # Generate a classification report
        report = classification_report(true_labels, predicted_labels, target_names=['AGAINST', 'FAVOR', 'NONE'])
        target_name = target
        # if target == 0:
        #     target_name = "Hillary Clinton"
        # if target == 1:
        #     target_name = "Legalization of Abortion"
        # if target == 2:
        #     target_name = "Atheism"
        # if target == 3:
        #     target_name = "Climate Change is a Real Concern"
        # if target == 4:
        #     target_name = "Feminist Movement"
        # if target == 5:
        #     target_name = "Donald Trump"

        print('Target: ', target_name)
        print(report)
        print("-----------------------------------------", "\n")

        # Flatten the report into a single row and add target name
        report = classification_report(true_labels, predicted_labels, target_names=['AGAINST', 'FAVOR', 'NONE'], output_dict=True)

        # Extract weighted f1, macro f1, and accuracy
        report_data = {
            'Target': target_name,
            'Weighted F1': report['weighted avg']['f1-score'],
            'Macro F1': report['macro avg']['f1-score'],
            'Accuracy': report['accuracy']
        }

        # Append to the DataFrame
        metrics_df = metrics_df.append(report_data, ignore_index=True)
    metrics_df.set_index('Target', inplace=True)

    return metrics_df

# %%
# Use the function to get the metrics DataFrame
model_metrics_df = load_classification_rp_per_target(inital_model)
model_metrics_df
# Out:
# 7/7 [==============================] - 1s 134ms/step
# Target:  Atheism
#               precision    recall  f1-score   support
#
#      AGAINST       0.75      0.90      0.82       160
#        FAVOR       0.50      0.03      0.06        32
#         NONE       0.35      0.32      0.33        28
#
#     accuracy                           0.70       220
#    macro avg       0.53      0.42      0.40       220
# weighted avg       0.66      0.70      0.65       220
#
# -----------------------------------------
# <ipython-input-16-653adaea9b0f>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 6/6 [==============================] - 1s 130ms/step
# Target:  Climate Change is a Real Concern
#               precision    recall  f1-score   support
#
#      AGAINST       0.33      0.09      0.14        11
#        FAVOR       0.79      0.91      0.85       123
#         NONE       0.50      0.34      0.41        35
#
#     accuracy                           0.74       169
#    macro avg       0.54      0.45      0.46       169
# weighted avg       0.70      0.74      0.71       169
#
# -----------------------------------------
# <ipython-input-16-653adaea9b0f>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 9/9 [==============================] - 1s 136ms/step
# Target:  Feminist Movement
#               precision    recall  f1-score   support
#
#      AGAINST       0.67      0.74      0.71       183
#        FAVOR       0.30      0.33      0.31        58
#         NONE       0.58      0.25      0.35        44
#
#     accuracy                           0.58       285
#    macro avg       0.52      0.44      0.46       285
# weighted avg       0.58      0.58      0.57       285
#
# -----------------------------------------
# <ipython-input-16-653adaea9b0f>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 10/10 [==============================] - 1s 132ms/step
# Target:  Hillary Clinton
#               precision    recall  f1-score   support
#
#      AGAINST       0.72      0.83      0.77       172
#        FAVOR       0.59      0.38      0.46        45
#         NONE       0.63      0.55      0.59        78
#
#     accuracy                           0.69       295
#    macro avg       0.65      0.59      0.61       295
# weighted avg       0.68      0.69      0.68       295
#
# -----------------------------------------
# <ipython-input-16-653adaea9b0f>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 9/9 [==============================] - 1s 134ms/step
# Target:  Legalization of Abortion
#               precision    recall  f1-score   support
#
#      AGAINST       0.73      0.91      0.81       189
#        FAVOR       0.50      0.09      0.15        46
#         NONE       0.62      0.51      0.56        45
#
#     accuracy                           0.71       280
#    macro avg       0.62      0.50      0.51       280
# weighted avg       0.68      0.71      0.66       280
#
# -----------------------------------------
# <ipython-input-16-653adaea9b0f>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 23/23 [==============================] - 3s 135ms/step
# Target:  Donald Trump
#               precision    recall  f1-score   support
#
#      AGAINST       0.52      0.63      0.57       299
#        FAVOR       0.75      0.18      0.29       148
#         NONE       0.61      0.73      0.67       260
#
#     accuracy                           0.57       707
#    macro avg       0.63      0.51      0.51       707
# weighted avg       0.60      0.57      0.55       707
#
# -----------------------------------------
# <ipython-input-16-653adaea9b0f>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
#                                   Weighted F1  Macro F1  Accuracy
# Target
# Atheism                              0.646022  0.403446  0.700000
# Climate Change is a Real Concern     0.708749  0.464973  0.739645
# Feminist Movement                    0.570944  0.455725  0.582456
# Hillary Clinton                      0.676516  0.607158  0.688136
# Legalization of Abortion             0.662137  0.506815  0.710714
# Donald Trump                         0.547472  0.509846  0.572843

# %% [markdown]
# [4] Fine Tune

# %%
for layer in inital_model.layers:
    layer.trainable = True
   # Tuning the learning rate for the optimizer
inital_model.compile(optimizer=tf.keras.optimizers.legacy.Adam(1e-7),
                  loss='categorical_crossentropy',
                  metrics=['categorical_accuracy', f1_score])

history['fine_tuned_bert'] = inital_model.fit([train_input_ids, train_attention_masks], train_labels,
                    epochs=1000,
                    validation_data=([val_input_ids, val_attention_masks], val_labels),
                    batch_size=32,
                    callbacks=callbacks2)
# Out:
# Epoch 1/1000
# WARNING:tensorflow:Gradients do not exist for variables ['tf_roberta_model_1/roberta/pooler/dense/kernel:0', 'tf_roberta_model_1/roberta/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['tf_roberta_model_1/roberta/pooler/dense/kernel:0', 'tf_roberta_model_1/roberta/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 410/410 [==============================] - ETA: 0s - loss: 0.8733 - categorical_accuracy: 0.6245 - f1_score: 0.5956
# Epoch 1: saving model to roberta_best_model.h5
# 410/410 [==============================] - 362s 831ms/step - loss: 0.8733 - categorical_accuracy: 0.6245 - f1_score: 0.5956 - val_loss: 0.8373 - val_categorical_accuracy: 0.6340 - val_f1_score: 0.6193 - lr: 1.0000e-07
# Epoch 2/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.8688 - categorical_accuracy: 0.6317 - f1_score: 0.6045
# Epoch 2: saving model to roberta_best_model.h5
# 410/410 [==============================] - 337s 823ms/step - loss: 0.8688 - categorical_accuracy: 0.6317 - f1_score: 0.6045 - val_loss: 0.8221 - val_categorical_accuracy: 0.6404 - val_f1_score: 0.6257 - lr: 1.0000e-07
# Epoch 3/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.8593 - categorical_accuracy: 0.6306 - f1_score: 0.6051
# Epoch 3: saving model to roberta_best_model.h5
# 410/410 [==============================] - 339s 827ms/step - loss: 0.8593 - categorical_accuracy: 0.6306 - f1_score: 0.6051 - val_loss: 0.8137 - val_categorical_accuracy: 0.6499 - val_f1_score: 0.6363 - lr: 1.0000e-07
# Epoch 4/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.8620 - categorical_accuracy: 0.6326 - f1_score: 0.6076
# Epoch 4: saving model to roberta_best_model.h5
# 410/410 [==============================] - 337s 822ms/step - loss: 0.8620 - categorical_accuracy: 0.6326 - f1_score: 0.6076 - val_loss: 0.8080 - val_categorical_accuracy: 0.6536 - val_f1_score: 0.6405 - lr: 1.0000e-07
# Epoch 5/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.8545 - categorical_accuracy: 0.6381 - f1_score: 0.6142
# Epoch 5: saving model to roberta_best_model.h5
# 410/410 [==============================] - 336s 819ms/step - loss: 0.8545 - categorical_accuracy: 0.6381 - f1_score: 0.6142 - val_loss: 0.8043 - val_categorical_accuracy: 0.6548 - val_f1_score: 0.6424 - lr: 1.0000e-07
# Epoch 6/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.8584 - categorical_accuracy: 0.6345 - f1_score: 0.6122
# Epoch 6: saving model to roberta_best_model.h5
# 410/410 [==============================] - 338s 824ms/step - loss: 0.8584 - categorical_accuracy: 0.6345 - f1_score: 0.6122 - val_loss: 0.7954 - val_categorical_accuracy: 0.6597 - val_f1_score: 0.6487 - lr: 1.0000e-07
# Epoch 7/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.8521 - categorical_accuracy: 0.6403 - f1_score: 0.6161
# Epoch 7: saving model to roberta_best_model.h5
# 410/410 [==============================] - 338s 824ms/step - loss: 0.8521 - categorical_accuracy: 0.6403 - f1_score: 0.6161 - val_loss: 0.7893 - val_categorical_accuracy: 0.6621 - val_f1_score: 0.6517 - lr: 1.0000e-07
# Epoch 8/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.8404 - categorical_accuracy: 0.6454 - f1_score: 0.6275
# Epoch 8: saving model to roberta_best_model.h5
# 410/410 [==============================] - 338s 823ms/step - loss: 0.8404 - categorical_accuracy: 0.6454 - f1_score: 0.6275 - val_loss: 0.7884 - val_categorical_accuracy: 0.6651 - val_f1_score: 0.6555 - lr: 1.0000e-07
# Epoch 9/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.8414 - categorical_accuracy: 0.6470 - f1_score: 0.6271
# Epoch 9: saving model to roberta_best_model.h5
# 410/410 [==============================] - 337s 822ms/step - loss: 0.8414 - categorical_accuracy: 0.6470 - f1_score: 0.6271 - val_loss: 0.7797 - val_categorical_accuracy: 0.6658 - val_f1_score: 0.6565 - lr: 1.0000e-07
# Epoch 10/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.8351 - categorical_accuracy: 0.6496 - f1_score: 0.6314
# Epoch 10: saving model to roberta_best_model.h5
# 410/410 [==============================] - 337s 822ms/step - loss: 0.8351 - categorical_accuracy: 0.6496 - f1_score: 0.6314 - val_loss: 0.7795 - val_categorical_accuracy: 0.6670 - val_f1_score: 0.6585 - lr: 1.0000e-07
# Epoch 11/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.8361 - categorical_accuracy: 0.6526 - f1_score: 0.6343
# Epoch 11: saving model to roberta_best_model.h5
# 410/410 [==============================] - 337s 823ms/step - loss: 0.8361 - categorical_accuracy: 0.6526 - f1_score: 0.6343 - val_loss: 0.7819 - val_categorical_accuracy: 0.6664 - val_f1_score: 0.6575 - lr: 1.0000e-07
# Epoch 12/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.8335 - categorical_accuracy: 0.6589 - f1_score: 0.6418
# Epoch 12: saving model to roberta_best_model.h5
# 410/410 [==============================] - 338s 824ms/step - loss: 0.8335 - categorical_accuracy: 0.6589 - f1_score: 0.6418 - val_loss: 0.7727 - val_categorical_accuracy: 0.6703 - val_f1_score: 0.6620 - lr: 1.0000e-07
# Epoch 13/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.8295 - categorical_accuracy: 0.6558 - f1_score: 0.6401
# Epoch 13: saving model to roberta_best_model.h5
# 410/410 [==============================] - 337s 821ms/step - loss: 0.8295 - categorical_accuracy: 0.6558 - f1_score: 0.6401 - val_loss: 0.7735 - val_categorical_accuracy: 0.6715 - val_f1_score: 0.6642 - lr: 1.0000e-07
# Epoch 14/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.8289 - categorical_accuracy: 0.6534 - f1_score: 0.6395
# Epoch 14: saving model to roberta_best_model.h5
# 410/410 [==============================] - 337s 823ms/step - loss: 0.8289 - categorical_accuracy: 0.6534 - f1_score: 0.6395 - val_loss: 0.7701 - val_categorical_accuracy: 0.6715 - val_f1_score: 0.6624 - lr: 1.0000e-07
# Epoch 15/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.8273 - categorical_accuracy: 0.6608 - f1_score: 0.6449
# Epoch 15: saving model to roberta_best_model.h5
# 410/410 [==============================] - 337s 822ms/step - loss: 0.8273 - categorical_accuracy: 0.6608 - f1_score: 0.6449 - val_loss: 0.7727 - val_categorical_accuracy: 0.6722 - val_f1_score: 0.6638 - lr: 1.0000e-07
# Epoch 16/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.8287 - categorical_accuracy: 0.6603 - f1_score: 0.6454
# Epoch 16: saving model to roberta_best_model.h5
# 410/410 [==============================] - 337s 822ms/step - loss: 0.8287 - categorical_accuracy: 0.6603 - f1_score: 0.6454 - val_loss: 0.7664 - val_categorical_accuracy: 0.6737 - val_f1_score: 0.6661 - lr: 1.0000e-07
# Epoch 17/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.8176 - categorical_accuracy: 0.6666 - f1_score: 0.6534
# Epoch 17: saving model to roberta_best_model.h5
# 410/410 [==============================] - 336s 820ms/step - loss: 0.8176 - categorical_accuracy: 0.6666 - f1_score: 0.6534 - val_loss: 0.7641 - val_categorical_accuracy: 0.6734 - val_f1_score: 0.6656 - lr: 1.0000e-07
# Epoch 18/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.8240 - categorical_accuracy: 0.6599 - f1_score: 0.6429
# Epoch 18: saving model to roberta_best_model.h5
# 410/410 [==============================] - 336s 819ms/step - loss: 0.8240 - categorical_accuracy: 0.6599 - f1_score: 0.6429 - val_loss: 0.7666 - val_categorical_accuracy: 0.6746 - val_f1_score: 0.6685 - lr: 1.0000e-07
# Epoch 19/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.8144 - categorical_accuracy: 0.6644 - f1_score: 0.6515
# Epoch 19: saving model to roberta_best_model.h5
# 410/410 [==============================] - 337s 823ms/step - loss: 0.8144 - categorical_accuracy: 0.6644 - f1_score: 0.6515 - val_loss: 0.7599 - val_categorical_accuracy: 0.6746 - val_f1_score: 0.6675 - lr: 1.0000e-07
# Epoch 20/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.8112 - categorical_accuracy: 0.6653 - f1_score: 0.6545
# Epoch 20: saving model to roberta_best_model.h5
# 410/410 [==============================] - 338s 823ms/step - loss: 0.8112 - categorical_accuracy: 0.6653 - f1_score: 0.6545 - val_loss: 0.7598 - val_categorical_accuracy: 0.6770 - val_f1_score: 0.6706 - lr: 1.0000e-07
# Epoch 21/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.8051 - categorical_accuracy: 0.6686 - f1_score: 0.6572
# Epoch 21: saving model to roberta_best_model.h5
# 410/410 [==============================] - 337s 821ms/step - loss: 0.8051 - categorical_accuracy: 0.6686 - f1_score: 0.6572 - val_loss: 0.7606 - val_categorical_accuracy: 0.6731 - val_f1_score: 0.6654 - lr: 1.0000e-07
# Epoch 22/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.8066 - categorical_accuracy: 0.6737 - f1_score: 0.6609
# Epoch 22: saving model to roberta_best_model.h5
# 410/410 [==============================] - 337s 823ms/step - loss: 0.8066 - categorical_accuracy: 0.6737 - f1_score: 0.6609 - val_loss: 0.7564 - val_categorical_accuracy: 0.6770 - val_f1_score: 0.6710 - lr: 1.0000e-07
# Epoch 23/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.8015 - categorical_accuracy: 0.6727 - f1_score: 0.6602
# Epoch 23: saving model to roberta_best_model.h5
# 410/410 [==============================] - 337s 822ms/step - loss: 0.8015 - categorical_accuracy: 0.6727 - f1_score: 0.6602 - val_loss: 0.7535 - val_categorical_accuracy: 0.6758 - val_f1_score: 0.6690 - lr: 1.0000e-07
# Epoch 24/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.8042 - categorical_accuracy: 0.6697 - f1_score: 0.6565
# Epoch 24: saving model to roberta_best_model.h5
# 410/410 [==============================] - 337s 823ms/step - loss: 0.8042 - categorical_accuracy: 0.6697 - f1_score: 0.6565 - val_loss: 0.7592 - val_categorical_accuracy: 0.6764 - val_f1_score: 0.6691 - lr: 1.0000e-07
# Epoch 25/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.7997 - categorical_accuracy: 0.6743 - f1_score: 0.6624
# Epoch 25: saving model to roberta_best_model.h5
# 410/410 [==============================] - 338s 823ms/step - loss: 0.7997 - categorical_accuracy: 0.6743 - f1_score: 0.6624 - val_loss: 0.7500 - val_categorical_accuracy: 0.6773 - val_f1_score: 0.6705 - lr: 1.0000e-07
# Epoch 26/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.7978 - categorical_accuracy: 0.6779 - f1_score: 0.6630
# Epoch 26: saving model to roberta_best_model.h5
# 410/410 [==============================] - 338s 826ms/step - loss: 0.7978 - categorical_accuracy: 0.6779 - f1_score: 0.6630 - val_loss: 0.7493 - val_categorical_accuracy: 0.6792 - val_f1_score: 0.6730 - lr: 1.0000e-07
# Epoch 27/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.8003 - categorical_accuracy: 0.6763 - f1_score: 0.6651
# Epoch 27: saving model to roberta_best_model.h5
# 410/410 [==============================] - 337s 822ms/step - loss: 0.8003 - categorical_accuracy: 0.6763 - f1_score: 0.6651 - val_loss: 0.7490 - val_categorical_accuracy: 0.6773 - val_f1_score: 0.6712 - lr: 1.0000e-07
# Epoch 28/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.8042 - categorical_accuracy: 0.6718 - f1_score: 0.6599
# Epoch 28: saving model to roberta_best_model.h5
# 410/410 [==============================] - 337s 821ms/step - loss: 0.8042 - categorical_accuracy: 0.6718 - f1_score: 0.6599 - val_loss: 0.7481 - val_categorical_accuracy: 0.6798 - val_f1_score: 0.6734 - lr: 1.0000e-07
# Epoch 29/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.8010 - categorical_accuracy: 0.6778 - f1_score: 0.6658
# Epoch 29: saving model to roberta_best_model.h5
# 410/410 [==============================] - 337s 823ms/step - loss: 0.8010 - categorical_accuracy: 0.6778 - f1_score: 0.6658 - val_loss: 0.7475 - val_categorical_accuracy: 0.6807 - val_f1_score: 0.6742 - lr: 1.0000e-07
# Epoch 30/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.7976 - categorical_accuracy: 0.6770 - f1_score: 0.6653
# Epoch 30: saving model to roberta_best_model.h5
# 410/410 [==============================] - 336s 820ms/step - loss: 0.7976 - categorical_accuracy: 0.6770 - f1_score: 0.6653 - val_loss: 0.7477 - val_categorical_accuracy: 0.6816 - val_f1_score: 0.6763 - lr: 1.0000e-07
# Epoch 31/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.7928 - categorical_accuracy: 0.6817 - f1_score: 0.6716
# Epoch 31: saving model to roberta_best_model.h5
# 410/410 [==============================] - 337s 821ms/step - loss: 0.7928 - categorical_accuracy: 0.6817 - f1_score: 0.6716 - val_loss: 0.7484 - val_categorical_accuracy: 0.6813 - val_f1_score: 0.6749 - lr: 1.0000e-07
# Epoch 32/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.7955 - categorical_accuracy: 0.6849 - f1_score: 0.6734
# Epoch 32: saving model to roberta_best_model.h5
# 410/410 [==============================] - 337s 822ms/step - loss: 0.7955 - categorical_accuracy: 0.6849 - f1_score: 0.6734 - val_loss: 0.7449 - val_categorical_accuracy: 0.6819 - val_f1_score: 0.6764 - lr: 1.0000e-07
# Epoch 33/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.7892 - categorical_accuracy: 0.6832 - f1_score: 0.6717
# Epoch 33: saving model to roberta_best_model.h5
# 410/410 [==============================] - 337s 821ms/step - loss: 0.7892 - categorical_accuracy: 0.6832 - f1_score: 0.6717 - val_loss: 0.7464 - val_categorical_accuracy: 0.6822 - val_f1_score: 0.6759 - lr: 1.0000e-07
# Epoch 34/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.7910 - categorical_accuracy: 0.6851 - f1_score: 0.6759
# Epoch 34: saving model to roberta_best_model.h5
# 410/410 [==============================] - 337s 822ms/step - loss: 0.7910 - categorical_accuracy: 0.6851 - f1_score: 0.6759 - val_loss: 0.7412 - val_categorical_accuracy: 0.6837 - val_f1_score: 0.6769 - lr: 1.0000e-07
# Epoch 35/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.7903 - categorical_accuracy: 0.6775 - f1_score: 0.6670
# Epoch 35: saving model to roberta_best_model.h5
# 410/410 [==============================] - 336s 821ms/step - loss: 0.7903 - categorical_accuracy: 0.6775 - f1_score: 0.6670 - val_loss: 0.7447 - val_categorical_accuracy: 0.6837 - val_f1_score: 0.6771 - lr: 1.0000e-07
# Epoch 36/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.7886 - categorical_accuracy: 0.6833 - f1_score: 0.6696
# Epoch 36: saving model to roberta_best_model.h5
# 410/410 [==============================] - 337s 822ms/step - loss: 0.7886 - categorical_accuracy: 0.6833 - f1_score: 0.6696 - val_loss: 0.7422 - val_categorical_accuracy: 0.6834 - val_f1_score: 0.6775 - lr: 1.0000e-07
# Epoch 37/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.7936 - categorical_accuracy: 0.6808 - f1_score: 0.6686
# Epoch 37: saving model to roberta_best_model.h5
# 410/410 [==============================] - 337s 822ms/step - loss: 0.7936 - categorical_accuracy: 0.6808 - f1_score: 0.6686 - val_loss: 0.7417 - val_categorical_accuracy: 0.6871 - val_f1_score: 0.6796 - lr: 1.0000e-07
# Epoch 38/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.7836 - categorical_accuracy: 0.6917 - f1_score: 0.6838
# Epoch 38: saving model to roberta_best_model.h5
# 410/410 [==============================] - 337s 822ms/step - loss: 0.7836 - categorical_accuracy: 0.6917 - f1_score: 0.6838 - val_loss: 0.7397 - val_categorical_accuracy: 0.6856 - val_f1_score: 0.6788 - lr: 1.0000e-07
# Epoch 39/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.7831 - categorical_accuracy: 0.6814 - f1_score: 0.6709
# Epoch 39: saving model to roberta_best_model.h5
# 410/410 [==============================] - 337s 822ms/step - loss: 0.7831 - categorical_accuracy: 0.6814 - f1_score: 0.6709 - val_loss: 0.7369 - val_categorical_accuracy: 0.6862 - val_f1_score: 0.6799 - lr: 1.0000e-07
# Epoch 40/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.7781 - categorical_accuracy: 0.6843 - f1_score: 0.6754
# Epoch 40: saving model to roberta_best_model.h5
# 410/410 [==============================] - 337s 821ms/step - loss: 0.7781 - categorical_accuracy: 0.6843 - f1_score: 0.6754 - val_loss: 0.7350 - val_categorical_accuracy: 0.6886 - val_f1_score: 0.6833 - lr: 1.0000e-07
# Epoch 41/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.7835 - categorical_accuracy: 0.6877 - f1_score: 0.6761
# Epoch 41: saving model to roberta_best_model.h5
# 410/410 [==============================] - 337s 823ms/step - loss: 0.7835 - categorical_accuracy: 0.6877 - f1_score: 0.6761 - val_loss: 0.7394 - val_categorical_accuracy: 0.6859 - val_f1_score: 0.6797 - lr: 1.0000e-07
# Epoch 42/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.7801 - categorical_accuracy: 0.6857 - f1_score: 0.6773
# Epoch 42: saving model to roberta_best_model.h5
# 410/410 [==============================] - 339s 827ms/step - loss: 0.7801 - categorical_accuracy: 0.6857 - f1_score: 0.6773 - val_loss: 0.7368 - val_categorical_accuracy: 0.6905 - val_f1_score: 0.6833 - lr: 1.0000e-07
# Epoch 43/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.7762 - categorical_accuracy: 0.6881 - f1_score: 0.6779
# Epoch 43: saving model to roberta_best_model.h5
# 410/410 [==============================] - 337s 822ms/step - loss: 0.7762 - categorical_accuracy: 0.6881 - f1_score: 0.6779 - val_loss: 0.7340 - val_categorical_accuracy: 0.6920 - val_f1_score: 0.6856 - lr: 1.0000e-07
# Epoch 44/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.7779 - categorical_accuracy: 0.6914 - f1_score: 0.6828
# Epoch 44: saving model to roberta_best_model.h5
# 410/410 [==============================] - 339s 827ms/step - loss: 0.7779 - categorical_accuracy: 0.6914 - f1_score: 0.6828 - val_loss: 0.7354 - val_categorical_accuracy: 0.6929 - val_f1_score: 0.6867 - lr: 1.0000e-07
# Epoch 45/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.7729 - categorical_accuracy: 0.6899 - f1_score: 0.6805
# Epoch 45: saving model to roberta_best_model.h5
# 410/410 [==============================] - 339s 826ms/step - loss: 0.7729 - categorical_accuracy: 0.6899 - f1_score: 0.6805 - val_loss: 0.7306 - val_categorical_accuracy: 0.6923 - val_f1_score: 0.6866 - lr: 1.0000e-07
# Epoch 46/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.7782 - categorical_accuracy: 0.6925 - f1_score: 0.6851
# Epoch 46: saving model to roberta_best_model.h5
# 410/410 [==============================] - 341s 832ms/step - loss: 0.7782 - categorical_accuracy: 0.6925 - f1_score: 0.6851 - val_loss: 0.7328 - val_categorical_accuracy: 0.6941 - val_f1_score: 0.6888 - lr: 1.0000e-07
# Epoch 47/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.7796 - categorical_accuracy: 0.6893 - f1_score: 0.6811
# Epoch 47: saving model to roberta_best_model.h5
# 410/410 [==============================] - 336s 821ms/step - loss: 0.7796 - categorical_accuracy: 0.6893 - f1_score: 0.6811 - val_loss: 0.7313 - val_categorical_accuracy: 0.6966 - val_f1_score: 0.6906 - lr: 1.0000e-07
# Epoch 48/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.7669 - categorical_accuracy: 0.6947 - f1_score: 0.6832
# Epoch 48: saving model to roberta_best_model.h5
# 410/410 [==============================] - 338s 823ms/step - loss: 0.7669 - categorical_accuracy: 0.6947 - f1_score: 0.6832 - val_loss: 0.7274 - val_categorical_accuracy: 0.6953 - val_f1_score: 0.6896 - lr: 1.0000e-07
# Epoch 49/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.7742 - categorical_accuracy: 0.6953 - f1_score: 0.6869
# Epoch 49: saving model to roberta_best_model.h5
# 410/410 [==============================] - 339s 828ms/step - loss: 0.7742 - categorical_accuracy: 0.6953 - f1_score: 0.6869 - val_loss: 0.7259 - val_categorical_accuracy: 0.6953 - val_f1_score: 0.6895 - lr: 1.0000e-07
# Epoch 50/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.7708 - categorical_accuracy: 0.6923 - f1_score: 0.6832
# Epoch 50: saving model to roberta_best_model.h5
# 410/410 [==============================] - 338s 825ms/step - loss: 0.7708 - categorical_accuracy: 0.6923 - f1_score: 0.6832 - val_loss: 0.7279 - val_categorical_accuracy: 0.6987 - val_f1_score: 0.6929 - lr: 1.0000e-07
# Epoch 51/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.7748 - categorical_accuracy: 0.6960 - f1_score: 0.6890
# Epoch 51: saving model to roberta_best_model.h5
# 410/410 [==============================] - 336s 820ms/step - loss: 0.7748 - categorical_accuracy: 0.6960 - f1_score: 0.6890 - val_loss: 0.7279 - val_categorical_accuracy: 0.6978 - val_f1_score: 0.6910 - lr: 1.0000e-07
# Epoch 52/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.7737 - categorical_accuracy: 0.6945 - f1_score: 0.6857
# Epoch 52: saving model to roberta_best_model.h5
# 410/410 [==============================] - 337s 823ms/step - loss: 0.7737 - categorical_accuracy: 0.6945 - f1_score: 0.6857 - val_loss: 0.7280 - val_categorical_accuracy: 0.6978 - val_f1_score: 0.6915 - lr: 1.0000e-07
# Epoch 53/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.7644 - categorical_accuracy: 0.6981 - f1_score: 0.6897
# Epoch 53: saving model to roberta_best_model.h5
# 410/410 [==============================] - 338s 824ms/step - loss: 0.7644 - categorical_accuracy: 0.6981 - f1_score: 0.6897 - val_loss: 0.7270 - val_categorical_accuracy: 0.6966 - val_f1_score: 0.6919 - lr: 1.0000e-07
# Epoch 54/1000
# 410/410 [==============================] - ETA: 0s - loss: 0.7681 - categorical_accuracy: 0.6953 - f1_score: 0.6860Restoring model weights from the end of the best epoch: 49.
#
# Epoch 54: saving model to roberta_best_model.h5
# 410/410 [==============================] - 337s 821ms/step - loss: 0.7681 - categorical_accuracy: 0.6953 - f1_score: 0.6860 - val_loss: 0.7262 - val_categorical_accuracy: 0.6996 - val_f1_score: 0.6936 - lr: 1.0000e-07
# Epoch 54: early stopping

# %%
# Use the function to get the metrics DataFrame
model_metrics_df = load_classification_rp_per_target(inital_model)
model_metrics_df
# Out:
# 7/7 [==============================] - 4s 135ms/step
# Target:  Atheism
#               precision    recall  f1-score   support
#
#      AGAINST       0.76      0.86      0.81       160
#        FAVOR       0.33      0.06      0.11        32
#         NONE       0.39      0.46      0.43        28
#
#     accuracy                           0.70       220
#    macro avg       0.50      0.46      0.45       220
# weighted avg       0.65      0.70      0.66       220
#
# -----------------------------------------
# <ipython-input-16-653adaea9b0f>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 6/6 [==============================] - 1s 131ms/step
# Target:  Climate Change is a Real Concern
#               precision    recall  f1-score   support
#
#      AGAINST       0.00      0.00      0.00        11
#        FAVOR       0.84      0.89      0.87       123
#         NONE       0.59      0.66      0.62        35
#
#     accuracy                           0.78       169
#    macro avg       0.48      0.51      0.50       169
# weighted avg       0.74      0.78      0.76       169
#
# -----------------------------------------
# <ipython-input-16-653adaea9b0f>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 9/9 [==============================] - 1s 135ms/step
# Target:  Feminist Movement
#               precision    recall  f1-score   support
#
#      AGAINST       0.72      0.61      0.66       183
#        FAVOR       0.34      0.57      0.43        58
#         NONE       0.41      0.32      0.36        44
#
#     accuracy                           0.55       285
#    macro avg       0.49      0.50      0.48       285
# weighted avg       0.59      0.55      0.56       285
#
# -----------------------------------------
# <ipython-input-16-653adaea9b0f>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 10/10 [==============================] - 1s 131ms/step
# Target:  Hillary Clinton
#               precision    recall  f1-score   support
#
#      AGAINST       0.81      0.75      0.78       172
#        FAVOR       0.67      0.53      0.59        45
#         NONE       0.67      0.86      0.75        78
#
#     accuracy                           0.75       295
#    macro avg       0.72      0.71      0.71       295
# weighted avg       0.75      0.75      0.74       295
#
# -----------------------------------------
# <ipython-input-16-653adaea9b0f>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 9/9 [==============================] - 1s 134ms/step
# Target:  Legalization of Abortion
#               precision    recall  f1-score   support
#
#      AGAINST       0.75      0.87      0.81       189
#        FAVOR       0.75      0.13      0.22        46
#         NONE       0.52      0.60      0.56        45
#
#     accuracy                           0.71       280
#    macro avg       0.67      0.53      0.53       280
# weighted avg       0.71      0.71      0.67       280
#
# -----------------------------------------
# <ipython-input-16-653adaea9b0f>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 23/23 [==============================] - 3s 135ms/step
# Target:  Donald Trump
#               precision    recall  f1-score   support
#
#      AGAINST       0.57      0.63      0.60       299
#        FAVOR       0.82      0.28      0.41       148
#         NONE       0.67      0.85      0.75       260
#
#     accuracy                           0.64       707
#    macro avg       0.69      0.59      0.59       707
# weighted avg       0.66      0.64      0.62       707
#
# -----------------------------------------
# <ipython-input-16-653adaea9b0f>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
#                                   Weighted F1  Macro F1  Accuracy
# Target
# Atheism                              0.658201  0.446959  0.695455
# Climate Change is a Real Concern     0.758352  0.495567  0.781065
# Feminist Movement                    0.564376  0.481450  0.554386
# Hillary Clinton                      0.743906  0.708286  0.745763
# Legalization of Abortion             0.670599  0.528590  0.707143
# Donald Trump                         0.616110  0.588043  0.636492

# %%
# Get model predictions
predictions = inital_model.predict([test_input_ids, test_attention_masks])

# Convert predictions to class labels
predicted_labels = np.argmax(predictions, axis=1)

# Assuming test_labels are one-hot encoded, convert them to class labels
true_labels = np.argmax(test_labels, axis=1)

# Generate classification report
report = classification_report(true_labels, predicted_labels)
print(report)
# Out:
# 62/62 [==============================] - 8s 136ms/step
#               precision    recall  f1-score   support
#
#            0       0.70      0.72      0.71      1014
#            1       0.66      0.48      0.55       452
#            2       0.62      0.75      0.68       490
#
#     accuracy                           0.67      1956
#    macro avg       0.66      0.65      0.65      1956
# weighted avg       0.67      0.67      0.67      1956

# %%
inital_model.save('roberta_model_vast_66.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
