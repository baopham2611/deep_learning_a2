# %%
# !pip install plotly
# !pip install seaborn
# !pip install matplotlib
# !pip install transformers
# !pip install tokenizers
# !pip install scikit-learn
# !pip install tensorflow
# !pip install pandas
# !pip install numpy
# !pip install keras_tuner


# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #
# <a id="data-prep"></a>
# <div style="background-color: #000D5B; color: white; text-align: center; padding: 6px 0 22px 0">
#     <h3 style="background-color: #000D5B; color: white; text-align: left">RMIT School of Computer Science and Technology</h3>
#     <br/>
#     <h1>COSC3007: Deep Learning</h1>
#     <h2>Assignment 2: Stance Twitter Sentiment Analysis and Detection </h2>
#     <h2> [2] MODELLING AND MODEL EVALUATIONS </h2>
#
# </div>

# %% [markdown]
# # Import Libs

# %%
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, BatchNormalization, Bidirectional, Flatten
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers.legacy import Adam
from sklearn.metrics import classification_report
import numpy as np

import numpy as np

# %% [markdown]
# # [1] Load Data

# %%
train_df = pd.read_csv("./drive/MyDrive/Colab Notebooks/StanceDataset/processed_train_augumented.csv", encoding = "ISO-8859-1", engine="python").drop(columns=['Unnamed: 0'])
train_df = train_df.sample(frac=1, random_state=42).reset_index(drop=True)
train_ori = train_df.copy()

test_df = pd.read_csv("./drive/MyDrive/Colab Notebooks/StanceDataset/processed_test_augumented.csv", encoding = "ISO-8859-1", engine="python").drop(columns=['Unnamed: 0'])

# %%
print(len(train_ori))
print(len(test_df))
# Out:
# 3296
# 1956

# %% [markdown]
# # [2] Prepare label and fit data

# %% [markdown]
# ## Split test and val

# %%
train_df, val_df = train_test_split(train_df, test_size=0.2, random_state=42, shuffle=True)

# %% [markdown]
# ## Tweets

# %%
from transformers import TFRobertaModel, RobertaTokenizer
import numpy as np

# Initialize the BERT tokenizer
MAX_LENGTH = 512
tokenizer = RobertaTokenizer.from_pretrained('roberta-base')
roberta_model = TFRobertaModel.from_pretrained('roberta-base')

# Assuming train_texts, val_texts, test_texts are your datasets
train_processed_tweets = train_df['Tweet'].tolist()
val_processed_tweets = val_df['Tweet'].tolist()
test_processed_tweets = test_df['Tweet'].tolist()

all_processed_tweets = train_processed_tweets + val_processed_tweets + test_processed_tweets
tokenized_tweets = [tokenizer.encode(tweet, add_special_tokens=True) for tweet in all_processed_tweets]
MAX_LENGTH = max(len(tweet) for tweet in tokenized_tweets)
MAX_LENGTH = 128

print("Maximum length across all datasets:", MAX_LENGTH)

target_names = {
    0: "Hillary Clinton",
    1: "Legalization of Abortion",
    2: "Atheism",
    3: "Climate Change is a Real Concern",
    4: "Feminist Movement",
    5: "Donald Trump",
    6: "Joe Biden",
    7: "Barack Obama",
    8: "Kamala Harris",
    9: "Bernie Sanders",
    10: "Vu",
}

def bert_tokenize(texts, targets, max_length=MAX_LENGTH):
    input_ids = []
    attention_masks = []

    for idx, text in enumerate(texts):
        targetID = targets[idx]
        target_name = target_names.get(targetID, "")
        formatted_text = f"<s> {target_name} </s></s> {text} </s>"
        encoded = tokenizer.encode_plus(
            formatted_text,
            add_special_tokens=True,
            max_length=max_length,
            truncation=True,
            padding='max_length',
            return_attention_mask=True,
            return_tensors='tf',
        )

        # Flatten the tensors and remove the extra dimension
        input_ids.append(tf.squeeze(encoded['input_ids'], axis=0))
        attention_masks.append(tf.squeeze(encoded['attention_mask'], axis=0))

    return np.array(input_ids), np.array(attention_masks)

# Assuming you have lists of preprocessed texts for training, validation, and test sets
train_input_ids, train_attention_masks = bert_tokenize(train_df['Tweet'],  train_df['Target'].to_list())
val_input_ids, val_attention_masks = bert_tokenize(val_df['Tweet'], val_df['Target'].to_list())
test_input_ids, test_attention_masks = bert_tokenize(test_df['Tweet'], test_df['Target'].to_list())

print(train_input_ids.shape)
print(val_input_ids.shape)
print(test_input_ids.shape)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:72: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/481 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFRobertaModel: ['lm_head.dense.weight', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.layer_norm.bias', 'lm_head.dense.bias', 'roberta.embeddings.position_ids']
# - This IS expected if you are initializing TFRobertaModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFRobertaModel were not initialized from the PyTorch model and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Maximum length across all datasets: 128
# (2636, 128)
# (660, 128)
# (1956, 128)

# %% [markdown]
# ## Stances

# %%
def categorized_label(df, label_name):
    label_encoder = LabelEncoder()
    encoded_labels = label_encoder.fit_transform(df[label_name])
    categorical_labels = to_categorical(encoded_labels)
    return categorical_labels

# %%
train_labels = categorized_label(train_df, "Stance")
test_labels = categorized_label(test_df, "Stance")
val_labels = categorized_label(val_df, "Stance")

# %% [markdown]
# # [3] Create Model

# %%
from keras import backend as K
from tensorflow.keras.optimizers.legacy import Adam
from hyperopt import hp
from hyperopt import hp, fmin, tpe, STATUS_OK, Trials
# import keras_tuner as kt

# %%
def f1_score_class(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))

    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    return 2 * ((precision * recall) / (precision + recall + K.epsilon()))

def f1_score(y_true, y_pred):
    # Convert predictions to one-hot format
    y_pred_one_hot = K.one_hot(K.argmax(y_pred), num_classes=3)

    # Calculate F1 score for each class
    f1s = [f1_score_class(y_true[:, i], y_pred_one_hot[:, i]) for i in range(3)]

    # Average F1 scores across all classes
    return K.mean(K.stack(f1s), axis=0)

# %% [markdown]
# Set up call backs and learning rates

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint


# Define the EarlyStopping and ReduceLROnPlateau callbacks
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=10,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=5,
    min_lr=1e-5,
    verbose=1,
)

# Define the ModelCheckpoint callback
checkpoint_path = "roberta_best_model.h5"
model_checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_path,
    save_weights_only=True,    # Only save a model if 'val_loss' has improved
    monitor='val_loss',     # Monitor 'val_loss' during training
    mode='min',             # The model is saved when 'val_loss' is minimized
    verbose=1)

# Combine all callbacks in a list
callbacks = [
    early_stopping,
    lr_scheduler,
    model_checkpoint_callback
]

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, BatchNormalization, Bidirectional, Flatten, Input, GlobalMaxPooling1D
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers.legacy import Adam
# import keras_tuner as kt
from transformers import TFRobertaModel

def build_model(drop, regr, lr):
    bert_model = TFRobertaModel.from_pretrained('roberta-base')
    bert_model.trainable = False

    # Define model input (BERT expects two inputs: input_ids and attention_mask)
    input_ids = Input(shape=(MAX_LENGTH,), dtype=tf.int32, name='input_ids')
    attention_mask = Input(shape=(MAX_LENGTH,), dtype=tf.int32, name='attention_mask')

    # Get BERT embeddings
    bert_output = bert_model(input_ids, attention_mask=attention_mask)[0]  # Use the pooled output here

    # Tuning the number of units in the first biLSTM layer
    x = Bidirectional(LSTM(units=64,  dropout=drop, recurrent_dropout=drop,return_sequences=True,kernel_regularizer=tf.keras.regularizers.l2(regr))) (bert_output)

    # x = Bidirectional(LSTM(units=64,  dropout=drop, return_sequences=True,kernel_regularizer=tf.keras.regularizers.l2(regr))) (bert_output)

    x = GlobalMaxPooling1D()(x)

    # Dense layer with tunable units
    x = Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(regr)) (x)

    # Tunable dropout rate for the second layer
    x = Dropout(drop)(x)

    # Final Layer
    x = Dense(3, activation='softmax')(x)

    # Tuning the learning rate for the optimizer
    optimizer = Adam(learning_rate=lr)
    model = Model(inputs=[input_ids, attention_mask], outputs=x)
    model.compile(loss='CategoricalCrossentropy', optimizer=optimizer, metrics=['categorical_accuracy',f1_score])
    model.summary()

    return model

# %% [markdown]
# Recreate the best model with more training time

# %%
history = {}
inital_model = build_model(0.8, 0.0005, 0.001)
history['tuned_stance_model_custom'] = inital_model.fit([train_input_ids, train_attention_masks], train_labels,
                    epochs=100,
                    validation_data=([val_input_ids, val_attention_masks], val_labels),
                    batch_size=128,
                    callbacks=callbacks,
                    shuffle = True)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:72: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFRobertaModel: ['lm_head.dense.weight', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.layer_norm.bias', 'lm_head.dense.bias', 'roberta.embeddings.position_ids']
# - This IS expected if you are initializing TFRobertaModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFRobertaModel were not initialized from the PyTorch model and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_ids (InputLayer)      [(None, 128)]                0         []
#
#  attention_mask (InputLayer  [(None, 128)]                0         []
#  )
#
#  tf_roberta_model_1 (TFRobe  TFBaseModelOutputWithPooli   1246456   ['input_ids[0][0]',
#  rtaModel)                   ngAndCrossAttentions(last_   32         'attention_mask[0][0]']
#                              hidden_state=(None, 128, 7
#                              68),
#                               pooler_output=(None, 768)
#                              , past_key_values=None, hi
#                              dden_states=None, attentio
#                              ns=None, cross_attentions=
#                              None)
#
#  bidirectional (Bidirection  (None, 128, 128)             426496    ['tf_roberta_model_1[0][0]']
#  al)
#
#  global_max_pooling1d (Glob  (None, 128)                  0         ['bidirectional[0][0]']
#  alMaxPooling1D)
#
#  dense (Dense)               (None, 128)                  16512     ['global_max_pooling1d[0][0]']
#
#  dropout_74 (Dropout)        (None, 128)                  0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 3)                    387       ['dropout_74[0][0]']
#
# ==================================================================================================
# Total params: 125089027 (477.18 MB)
# Trainable params: 443395 (1.69 MB)
# Non-trainable params: 124645632 (475.49 MB)
# __________________________________________________________________________________________________
# Epoch 1/100
# 21/21 [==============================] - ETA: 0s - loss: 1.6027 - categorical_accuracy: 0.4082 - f1_score: 0.3147
# Epoch 1: saving model to roberta_best_model.h5
# 21/21 [==============================] - 66s 2s/step - loss: 1.6027 - categorical_accuracy: 0.4082 - f1_score: 0.3147 - val_loss: 1.4886 - val_categorical_accuracy: 0.5000 - val_f1_score: 0.2269 - lr: 0.0010
# Epoch 2/100
# 21/21 [==============================] - ETA: 0s - loss: 1.4640 - categorical_accuracy: 0.4476 - f1_score: 0.2685
# Epoch 2: saving model to roberta_best_model.h5
# 21/21 [==============================] - 28s 1s/step - loss: 1.4640 - categorical_accuracy: 0.4476 - f1_score: 0.2685 - val_loss: 1.4400 - val_categorical_accuracy: 0.5000 - val_f1_score: 0.2269 - lr: 0.0010
# Epoch 3/100
# 21/21 [==============================] - ETA: 0s - loss: 1.4231 - categorical_accuracy: 0.4727 - f1_score: 0.2251
# Epoch 3: saving model to roberta_best_model.h5
# 21/21 [==============================] - 30s 1s/step - loss: 1.4231 - categorical_accuracy: 0.4727 - f1_score: 0.2251 - val_loss: 1.3898 - val_categorical_accuracy: 0.5000 - val_f1_score: 0.2269 - lr: 0.0010
# Epoch 4/100
# 21/21 [==============================] - ETA: 0s - loss: 1.3793 - categorical_accuracy: 0.4731 - f1_score: 0.2357
# Epoch 4: saving model to roberta_best_model.h5
# 21/21 [==============================] - 30s 1s/step - loss: 1.3793 - categorical_accuracy: 0.4731 - f1_score: 0.2357 - val_loss: 1.3379 - val_categorical_accuracy: 0.5000 - val_f1_score: 0.2269 - lr: 0.0010
# Epoch 5/100
# 21/21 [==============================] - ETA: 0s - loss: 1.3409 - categorical_accuracy: 0.4697 - f1_score: 0.2334
# Epoch 5: saving model to roberta_best_model.h5
# 21/21 [==============================] - 29s 1s/step - loss: 1.3409 - categorical_accuracy: 0.4697 - f1_score: 0.2334 - val_loss: 1.3070 - val_categorical_accuracy: 0.5000 - val_f1_score: 0.2269 - lr: 0.0010
# Epoch 6/100
# 21/21 [==============================] - ETA: 0s - loss: 1.3029 - categorical_accuracy: 0.4795 - f1_score: 0.2457
# Epoch 6: saving model to roberta_best_model.h5
# 21/21 [==============================] - 31s 1s/step - loss: 1.3029 - categorical_accuracy: 0.4795 - f1_score: 0.2457 - val_loss: 1.2743 - val_categorical_accuracy: 0.5000 - val_f1_score: 0.2269 - lr: 0.0010
# Epoch 7/100
# 21/21 [==============================] - ETA: 0s - loss: 1.2735 - categorical_accuracy: 0.4863 - f1_score: 0.2744
# Epoch 7: saving model to roberta_best_model.h5
# 21/21 [==============================] - 30s 1s/step - loss: 1.2735 - categorical_accuracy: 0.4863 - f1_score: 0.2744 - val_loss: 1.2401 - val_categorical_accuracy: 0.5000 - val_f1_score: 0.2269 - lr: 0.0010
# Epoch 8/100
# 21/21 [==============================] - ETA: 0s - loss: 1.2486 - categorical_accuracy: 0.4867 - f1_score: 0.2820
# Epoch 8: saving model to roberta_best_model.h5
# 21/21 [==============================] - 29s 1s/step - loss: 1.2486 - categorical_accuracy: 0.4867 - f1_score: 0.2820 - val_loss: 1.2120 - val_categorical_accuracy: 0.5379 - val_f1_score: 0.3152 - lr: 0.0010
# Epoch 9/100
# 21/21 [==============================] - ETA: 0s - loss: 1.2051 - categorical_accuracy: 0.5057 - f1_score: 0.3206
# Epoch 9: saving model to roberta_best_model.h5
# 21/21 [==============================] - 30s 1s/step - loss: 1.2051 - categorical_accuracy: 0.5057 - f1_score: 0.3206 - val_loss: 1.1894 - val_categorical_accuracy: 0.5424 - val_f1_score: 0.3214 - lr: 0.0010
# Epoch 10/100
# 21/21 [==============================] - ETA: 0s - loss: 1.1909 - categorical_accuracy: 0.5076 - f1_score: 0.3501
# Epoch 10: saving model to roberta_best_model.h5
# 21/21 [==============================] - 29s 1s/step - loss: 1.1909 - categorical_accuracy: 0.5076 - f1_score: 0.3501 - val_loss: 1.1576 - val_categorical_accuracy: 0.5424 - val_f1_score: 0.3220 - lr: 0.0010
# Epoch 11/100
# 21/21 [==============================] - ETA: 0s - loss: 1.1677 - categorical_accuracy: 0.5163 - f1_score: 0.3581
# Epoch 11: saving model to roberta_best_model.h5
# 21/21 [==============================] - 30s 1s/step - loss: 1.1677 - categorical_accuracy: 0.5163 - f1_score: 0.3581 - val_loss: 1.1236 - val_categorical_accuracy: 0.5439 - val_f1_score: 0.3255 - lr: 0.0010
# Epoch 12/100
# 21/21 [==============================] - ETA: 0s - loss: 1.1367 - categorical_accuracy: 0.5201 - f1_score: 0.3870
# Epoch 12: saving model to roberta_best_model.h5
# 21/21 [==============================] - 30s 1s/step - loss: 1.1367 - categorical_accuracy: 0.5201 - f1_score: 0.3870 - val_loss: 1.1033 - val_categorical_accuracy: 0.5485 - val_f1_score: 0.3630 - lr: 0.0010
# Epoch 13/100
# 21/21 [==============================] - ETA: 0s - loss: 1.1296 - categorical_accuracy: 0.5167 - f1_score: 0.3860
# Epoch 13: saving model to roberta_best_model.h5
# 21/21 [==============================] - 31s 1s/step - loss: 1.1296 - categorical_accuracy: 0.5167 - f1_score: 0.3860 - val_loss: 1.0874 - val_categorical_accuracy: 0.5470 - val_f1_score: 0.3300 - lr: 0.0010
# Epoch 14/100
# 21/21 [==============================] - ETA: 0s - loss: 1.1039 - categorical_accuracy: 0.5376 - f1_score: 0.4302
# Epoch 14: saving model to roberta_best_model.h5
# 21/21 [==============================] - 29s 1s/step - loss: 1.1039 - categorical_accuracy: 0.5376 - f1_score: 0.4302 - val_loss: 1.1009 - val_categorical_accuracy: 0.5333 - val_f1_score: 0.4002 - lr: 0.0010
# Epoch 15/100
# 21/21 [==============================] - ETA: 0s - loss: 1.0892 - categorical_accuracy: 0.5307 - f1_score: 0.4400
# Epoch 15: saving model to roberta_best_model.h5
# 21/21 [==============================] - 32s 2s/step - loss: 1.0892 - categorical_accuracy: 0.5307 - f1_score: 0.4400 - val_loss: 1.0458 - val_categorical_accuracy: 0.5591 - val_f1_score: 0.4361 - lr: 0.0010
# Epoch 16/100
# 21/21 [==============================] - ETA: 0s - loss: 1.0713 - categorical_accuracy: 0.5573 - f1_score: 0.4624
# Epoch 16: saving model to roberta_best_model.h5
# 21/21 [==============================] - 29s 1s/step - loss: 1.0713 - categorical_accuracy: 0.5573 - f1_score: 0.4624 - val_loss: 1.0459 - val_categorical_accuracy: 0.5667 - val_f1_score: 0.4253 - lr: 0.0010
# Epoch 17/100
# 21/21 [==============================] - ETA: 0s - loss: 1.0614 - categorical_accuracy: 0.5410 - f1_score: 0.4500
# Epoch 17: saving model to roberta_best_model.h5
# 21/21 [==============================] - 34s 2s/step - loss: 1.0614 - categorical_accuracy: 0.5410 - f1_score: 0.4500 - val_loss: 1.0156 - val_categorical_accuracy: 0.5545 - val_f1_score: 0.3752 - lr: 0.0010
# Epoch 18/100
# 21/21 [==============================] - ETA: 0s - loss: 1.0482 - categorical_accuracy: 0.5653 - f1_score: 0.4857
# Epoch 18: saving model to roberta_best_model.h5
# 21/21 [==============================] - 29s 1s/step - loss: 1.0482 - categorical_accuracy: 0.5653 - f1_score: 0.4857 - val_loss: 1.0173 - val_categorical_accuracy: 0.5924 - val_f1_score: 0.4356 - lr: 0.0010
# Epoch 19/100
# 21/21 [==============================] - ETA: 0s - loss: 1.0329 - categorical_accuracy: 0.5679 - f1_score: 0.4914
# Epoch 19: saving model to roberta_best_model.h5
# 21/21 [==============================] - 29s 1s/step - loss: 1.0329 - categorical_accuracy: 0.5679 - f1_score: 0.4914 - val_loss: 0.9973 - val_categorical_accuracy: 0.5909 - val_f1_score: 0.4865 - lr: 0.0010
# Epoch 20/100
# 21/21 [==============================] - ETA: 0s - loss: 1.0179 - categorical_accuracy: 0.5835 - f1_score: 0.5192
# Epoch 20: saving model to roberta_best_model.h5
# 21/21 [==============================] - 29s 1s/step - loss: 1.0179 - categorical_accuracy: 0.5835 - f1_score: 0.5192 - val_loss: 0.9935 - val_categorical_accuracy: 0.5955 - val_f1_score: 0.4645 - lr: 0.0010
# Epoch 21/100
# 21/21 [==============================] - ETA: 0s - loss: 1.0213 - categorical_accuracy: 0.5763 - f1_score: 0.5107
# Epoch 21: saving model to roberta_best_model.h5
# 21/21 [==============================] - 30s 1s/step - loss: 1.0213 - categorical_accuracy: 0.5763 - f1_score: 0.5107 - val_loss: 0.9795 - val_categorical_accuracy: 0.5970 - val_f1_score: 0.4648 - lr: 0.0010
# Epoch 22/100
# 21/21 [==============================] - ETA: 0s - loss: 1.0112 - categorical_accuracy: 0.5797 - f1_score: 0.5249
# Epoch 22: saving model to roberta_best_model.h5
# 21/21 [==============================] - 30s 1s/step - loss: 1.0112 - categorical_accuracy: 0.5797 - f1_score: 0.5249 - val_loss: 0.9748 - val_categorical_accuracy: 0.6136 - val_f1_score: 0.4719 - lr: 0.0010
# Epoch 23/100
# 21/21 [==============================] - ETA: 0s - loss: 1.0002 - categorical_accuracy: 0.5800 - f1_score: 0.5167
# Epoch 23: saving model to roberta_best_model.h5
# 21/21 [==============================] - 31s 2s/step - loss: 1.0002 - categorical_accuracy: 0.5800 - f1_score: 0.5167 - val_loss: 0.9469 - val_categorical_accuracy: 0.6182 - val_f1_score: 0.5823 - lr: 0.0010
# Epoch 24/100
# 21/21 [==============================] - ETA: 0s - loss: 0.9838 - categorical_accuracy: 0.6032 - f1_score: 0.5470
# Epoch 24: saving model to roberta_best_model.h5
# 21/21 [==============================] - 29s 1s/step - loss: 0.9838 - categorical_accuracy: 0.6032 - f1_score: 0.5470 - val_loss: 0.9480 - val_categorical_accuracy: 0.5909 - val_f1_score: 0.5568 - lr: 0.0010
# Epoch 25/100
# 21/21 [==============================] - ETA: 0s - loss: 0.9832 - categorical_accuracy: 0.5873 - f1_score: 0.5274
# Epoch 25: saving model to roberta_best_model.h5
# 21/21 [==============================] - 29s 1s/step - loss: 0.9832 - categorical_accuracy: 0.5873 - f1_score: 0.5274 - val_loss: 0.9620 - val_categorical_accuracy: 0.6212 - val_f1_score: 0.5333 - lr: 0.0010
# Epoch 26/100
# 21/21 [==============================] - ETA: 0s - loss: 0.9851 - categorical_accuracy: 0.5933 - f1_score: 0.5420
# Epoch 26: saving model to roberta_best_model.h5
# 21/21 [==============================] - 30s 1s/step - loss: 0.9851 - categorical_accuracy: 0.5933 - f1_score: 0.5420 - val_loss: 0.9395 - val_categorical_accuracy: 0.6197 - val_f1_score: 0.5365 - lr: 0.0010
# Epoch 27/100
# 21/21 [==============================] - ETA: 0s - loss: 0.9825 - categorical_accuracy: 0.5903 - f1_score: 0.5405
# Epoch 27: saving model to roberta_best_model.h5
# 21/21 [==============================] - 30s 1s/step - loss: 0.9825 - categorical_accuracy: 0.5903 - f1_score: 0.5405 - val_loss: 0.9407 - val_categorical_accuracy: 0.6076 - val_f1_score: 0.5189 - lr: 0.0010
# Epoch 28/100
# 21/21 [==============================] - ETA: 0s - loss: 0.9592 - categorical_accuracy: 0.6036 - f1_score: 0.5610
# Epoch 28: saving model to roberta_best_model.h5
# 21/21 [==============================] - 30s 1s/step - loss: 0.9592 - categorical_accuracy: 0.6036 - f1_score: 0.5610 - val_loss: 0.9356 - val_categorical_accuracy: 0.6182 - val_f1_score: 0.5557 - lr: 0.0010
# Epoch 29/100
# 21/21 [==============================] - ETA: 0s - loss: 0.9670 - categorical_accuracy: 0.6104 - f1_score: 0.5704
# Epoch 29: saving model to roberta_best_model.h5
# 21/21 [==============================] - 29s 1s/step - loss: 0.9670 - categorical_accuracy: 0.6104 - f1_score: 0.5704 - val_loss: 0.9109 - val_categorical_accuracy: 0.6106 - val_f1_score: 0.5351 - lr: 0.0010
# Epoch 30/100
# 21/21 [==============================] - ETA: 0s - loss: 0.9410 - categorical_accuracy: 0.6123 - f1_score: 0.5692
# Epoch 30: saving model to roberta_best_model.h5
# 21/21 [==============================] - 30s 1s/step - loss: 0.9410 - categorical_accuracy: 0.6123 - f1_score: 0.5692 - val_loss: 0.9130 - val_categorical_accuracy: 0.6394 - val_f1_score: 0.6306 - lr: 0.0010
# Epoch 31/100
# 21/21 [==============================] - ETA: 0s - loss: 0.9234 - categorical_accuracy: 0.6290 - f1_score: 0.5872
# Epoch 31: saving model to roberta_best_model.h5
# 21/21 [==============================] - 34s 2s/step - loss: 0.9234 - categorical_accuracy: 0.6290 - f1_score: 0.5872 - val_loss: 0.9167 - val_categorical_accuracy: 0.6121 - val_f1_score: 0.5449 - lr: 0.0010
# Epoch 32/100
# 21/21 [==============================] - ETA: 0s - loss: 0.9318 - categorical_accuracy: 0.6282 - f1_score: 0.5848
# Epoch 32: saving model to roberta_best_model.h5
# 21/21 [==============================] - 32s 2s/step - loss: 0.9318 - categorical_accuracy: 0.6282 - f1_score: 0.5848 - val_loss: 0.9255 - val_categorical_accuracy: 0.6242 - val_f1_score: 0.5695 - lr: 0.0010
# Epoch 33/100
# 21/21 [==============================] - ETA: 0s - loss: 0.9461 - categorical_accuracy: 0.6149 - f1_score: 0.5710
# Epoch 33: saving model to roberta_best_model.h5
# 21/21 [==============================] - 30s 1s/step - loss: 0.9461 - categorical_accuracy: 0.6149 - f1_score: 0.5710 - val_loss: 0.9048 - val_categorical_accuracy: 0.6667 - val_f1_score: 0.6664 - lr: 0.0010
# Epoch 34/100
# 21/21 [==============================] - ETA: 0s - loss: 0.9329 - categorical_accuracy: 0.6142 - f1_score: 0.5640
# Epoch 34: saving model to roberta_best_model.h5
# 21/21 [==============================] - 30s 1s/step - loss: 0.9329 - categorical_accuracy: 0.6142 - f1_score: 0.5640 - val_loss: 0.9335 - val_categorical_accuracy: 0.6288 - val_f1_score: 0.5352 - lr: 0.0010
# Epoch 35/100
# 21/21 [==============================] - ETA: 0s - loss: 0.9152 - categorical_accuracy: 0.6142 - f1_score: 0.5733
# Epoch 35: saving model to roberta_best_model.h5
# 21/21 [==============================] - 29s 1s/step - loss: 0.9152 - categorical_accuracy: 0.6142 - f1_score: 0.5733 - val_loss: 0.9579 - val_categorical_accuracy: 0.6121 - val_f1_score: 0.5283 - lr: 0.0010
# Epoch 36/100
# 21/21 [==============================] - ETA: 0s - loss: 0.9375 - categorical_accuracy: 0.6195 - f1_score: 0.5771
# Epoch 36: saving model to roberta_best_model.h5
# 21/21 [==============================] - 30s 1s/step - loss: 0.9375 - categorical_accuracy: 0.6195 - f1_score: 0.5771 - val_loss: 0.9120 - val_categorical_accuracy: 0.6273 - val_f1_score: 0.5118 - lr: 0.0010
# Epoch 37/100
# 21/21 [==============================] - ETA: 0s - loss: 0.9475 - categorical_accuracy: 0.6093 - f1_score: 0.5574
# Epoch 37: saving model to roberta_best_model.h5
# 21/21 [==============================] - 30s 1s/step - loss: 0.9475 - categorical_accuracy: 0.6093 - f1_score: 0.5574 - val_loss: 0.8789 - val_categorical_accuracy: 0.6530 - val_f1_score: 0.6346 - lr: 0.0010
# Epoch 38/100
# 21/21 [==============================] - ETA: 0s - loss: 0.9076 - categorical_accuracy: 0.6392 - f1_score: 0.6038
# Epoch 38: saving model to roberta_best_model.h5
# 21/21 [==============================] - 30s 1s/step - loss: 0.9076 - categorical_accuracy: 0.6392 - f1_score: 0.6038 - val_loss: 0.8834 - val_categorical_accuracy: 0.6303 - val_f1_score: 0.5912 - lr: 0.0010
# Epoch 39/100
# 21/21 [==============================] - ETA: 0s - loss: 0.9031 - categorical_accuracy: 0.6294 - f1_score: 0.5890
# Epoch 39: saving model to roberta_best_model.h5
# 21/21 [==============================] - 29s 1s/step - loss: 0.9031 - categorical_accuracy: 0.6294 - f1_score: 0.5890 - val_loss: 0.8646 - val_categorical_accuracy: 0.6545 - val_f1_score: 0.6256 - lr: 0.0010
# Epoch 40/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8922 - categorical_accuracy: 0.6434 - f1_score: 0.6101
# Epoch 40: saving model to roberta_best_model.h5
# 21/21 [==============================] - 37s 2s/step - loss: 0.8922 - categorical_accuracy: 0.6434 - f1_score: 0.6101 - val_loss: 0.8963 - val_categorical_accuracy: 0.6303 - val_f1_score: 0.6342 - lr: 0.0010
# Epoch 41/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8980 - categorical_accuracy: 0.6423 - f1_score: 0.6088
# Epoch 41: saving model to roberta_best_model.h5
# 21/21 [==============================] - 49s 2s/step - loss: 0.8980 - categorical_accuracy: 0.6423 - f1_score: 0.6088 - val_loss: 0.8681 - val_categorical_accuracy: 0.6515 - val_f1_score: 0.6236 - lr: 0.0010
# Epoch 42/100
# 21/21 [==============================] - ETA: 0s - loss: 0.9086 - categorical_accuracy: 0.6373 - f1_score: 0.5976
# Epoch 42: saving model to roberta_best_model.h5
# 21/21 [==============================] - 30s 1s/step - loss: 0.9086 - categorical_accuracy: 0.6373 - f1_score: 0.5976 - val_loss: 0.8625 - val_categorical_accuracy: 0.6576 - val_f1_score: 0.6119 - lr: 0.0010
# Epoch 43/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8869 - categorical_accuracy: 0.6290 - f1_score: 0.5931
# Epoch 43: saving model to roberta_best_model.h5
# 21/21 [==============================] - 29s 1s/step - loss: 0.8869 - categorical_accuracy: 0.6290 - f1_score: 0.5931 - val_loss: 0.9157 - val_categorical_accuracy: 0.6348 - val_f1_score: 0.6186 - lr: 0.0010
# Epoch 44/100
# 21/21 [==============================] - ETA: 0s - loss: 0.9046 - categorical_accuracy: 0.6404 - f1_score: 0.6042
# Epoch 44: saving model to roberta_best_model.h5
# 21/21 [==============================] - 31s 2s/step - loss: 0.9046 - categorical_accuracy: 0.6404 - f1_score: 0.6042 - val_loss: 0.8781 - val_categorical_accuracy: 0.6515 - val_f1_score: 0.6458 - lr: 0.0010
# Epoch 45/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8824 - categorical_accuracy: 0.6453 - f1_score: 0.6078
# Epoch 45: saving model to roberta_best_model.h5
# 21/21 [==============================] - 30s 1s/step - loss: 0.8824 - categorical_accuracy: 0.6453 - f1_score: 0.6078 - val_loss: 0.8594 - val_categorical_accuracy: 0.6773 - val_f1_score: 0.6453 - lr: 0.0010
# Epoch 46/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8911 - categorical_accuracy: 0.6415 - f1_score: 0.6056
# Epoch 46: saving model to roberta_best_model.h5
# 21/21 [==============================] - 29s 1s/step - loss: 0.8911 - categorical_accuracy: 0.6415 - f1_score: 0.6056 - val_loss: 0.8826 - val_categorical_accuracy: 0.6545 - val_f1_score: 0.6228 - lr: 0.0010
# Epoch 47/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8835 - categorical_accuracy: 0.6392 - f1_score: 0.6091
# Epoch 47: saving model to roberta_best_model.h5
# 21/21 [==============================] - 30s 1s/step - loss: 0.8835 - categorical_accuracy: 0.6392 - f1_score: 0.6091 - val_loss: 0.8595 - val_categorical_accuracy: 0.6652 - val_f1_score: 0.6349 - lr: 0.0010
# Epoch 48/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8890 - categorical_accuracy: 0.6426 - f1_score: 0.6062
# Epoch 48: saving model to roberta_best_model.h5
# 21/21 [==============================] - 32s 2s/step - loss: 0.8890 - categorical_accuracy: 0.6426 - f1_score: 0.6062 - val_loss: 0.8678 - val_categorical_accuracy: 0.6500 - val_f1_score: 0.6167 - lr: 0.0010
# Epoch 49/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8555 - categorical_accuracy: 0.6608 - f1_score: 0.6256
# Epoch 49: saving model to roberta_best_model.h5
# 21/21 [==============================] - 39s 2s/step - loss: 0.8555 - categorical_accuracy: 0.6608 - f1_score: 0.6256 - val_loss: 0.8438 - val_categorical_accuracy: 0.6712 - val_f1_score: 0.6478 - lr: 0.0010
# Epoch 50/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8662 - categorical_accuracy: 0.6498 - f1_score: 0.6194
# Epoch 50: saving model to roberta_best_model.h5
# 21/21 [==============================] - 34s 2s/step - loss: 0.8662 - categorical_accuracy: 0.6498 - f1_score: 0.6194 - val_loss: 0.8846 - val_categorical_accuracy: 0.6636 - val_f1_score: 0.6253 - lr: 0.0010
# Epoch 51/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8983 - categorical_accuracy: 0.6328 - f1_score: 0.5872
# Epoch 51: saving model to roberta_best_model.h5
# 21/21 [==============================] - 39s 2s/step - loss: 0.8983 - categorical_accuracy: 0.6328 - f1_score: 0.5872 - val_loss: 0.8426 - val_categorical_accuracy: 0.6697 - val_f1_score: 0.6209 - lr: 0.0010
# Epoch 52/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8834 - categorical_accuracy: 0.6483 - f1_score: 0.6124
# Epoch 52: saving model to roberta_best_model.h5
# 21/21 [==============================] - 28s 1s/step - loss: 0.8834 - categorical_accuracy: 0.6483 - f1_score: 0.6124 - val_loss: 0.8620 - val_categorical_accuracy: 0.6424 - val_f1_score: 0.6133 - lr: 0.0010
# Epoch 53/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8735 - categorical_accuracy: 0.6396 - f1_score: 0.6010
# Epoch 53: saving model to roberta_best_model.h5
# 21/21 [==============================] - 33s 2s/step - loss: 0.8735 - categorical_accuracy: 0.6396 - f1_score: 0.6010 - val_loss: 0.8619 - val_categorical_accuracy: 0.6515 - val_f1_score: 0.6200 - lr: 0.0010
# Epoch 54/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8619 - categorical_accuracy: 0.6567 - f1_score: 0.6252
# Epoch 54: saving model to roberta_best_model.h5
# 21/21 [==============================] - 34s 2s/step - loss: 0.8619 - categorical_accuracy: 0.6567 - f1_score: 0.6252 - val_loss: 0.8564 - val_categorical_accuracy: 0.6652 - val_f1_score: 0.6036 - lr: 0.0010
# Epoch 55/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8836 - categorical_accuracy: 0.6578 - f1_score: 0.6256
# Epoch 55: saving model to roberta_best_model.h5
# 21/21 [==============================] - 31s 2s/step - loss: 0.8836 - categorical_accuracy: 0.6578 - f1_score: 0.6256 - val_loss: 0.8470 - val_categorical_accuracy: 0.6545 - val_f1_score: 0.6021 - lr: 0.0010
# Epoch 56/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8564 - categorical_accuracy: 0.6681 - f1_score: 0.6380
# Epoch 56: saving model to roberta_best_model.h5
# 21/21 [==============================] - 37s 2s/step - loss: 0.8564 - categorical_accuracy: 0.6681 - f1_score: 0.6380 - val_loss: 0.8378 - val_categorical_accuracy: 0.6561 - val_f1_score: 0.6210 - lr: 0.0010
# Epoch 57/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8546 - categorical_accuracy: 0.6415 - f1_score: 0.6084
# Epoch 57: saving model to roberta_best_model.h5
# 21/21 [==============================] - 28s 1s/step - loss: 0.8546 - categorical_accuracy: 0.6415 - f1_score: 0.6084 - val_loss: 0.8663 - val_categorical_accuracy: 0.6530 - val_f1_score: 0.6137 - lr: 0.0010
# Epoch 58/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8450 - categorical_accuracy: 0.6684 - f1_score: 0.6396
# Epoch 58: saving model to roberta_best_model.h5
# 21/21 [==============================] - 28s 1s/step - loss: 0.8450 - categorical_accuracy: 0.6684 - f1_score: 0.6396 - val_loss: 0.8561 - val_categorical_accuracy: 0.6652 - val_f1_score: 0.6300 - lr: 0.0010
# Epoch 59/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8741 - categorical_accuracy: 0.6442 - f1_score: 0.6119
# Epoch 59: saving model to roberta_best_model.h5
# 21/21 [==============================] - 29s 1s/step - loss: 0.8741 - categorical_accuracy: 0.6442 - f1_score: 0.6119 - val_loss: 0.8574 - val_categorical_accuracy: 0.6652 - val_f1_score: 0.6417 - lr: 0.0010
# Epoch 60/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8511 - categorical_accuracy: 0.6593 - f1_score: 0.6335
# Epoch 60: saving model to roberta_best_model.h5
# 21/21 [==============================] - 29s 1s/step - loss: 0.8511 - categorical_accuracy: 0.6593 - f1_score: 0.6335 - val_loss: 0.8559 - val_categorical_accuracy: 0.6697 - val_f1_score: 0.6504 - lr: 0.0010
# Epoch 61/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8473 - categorical_accuracy: 0.6665 - f1_score: 0.6357
# Epoch 61: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 61: saving model to roberta_best_model.h5
# 21/21 [==============================] - 29s 1s/step - loss: 0.8473 - categorical_accuracy: 0.6665 - f1_score: 0.6357 - val_loss: 0.8464 - val_categorical_accuracy: 0.6621 - val_f1_score: 0.6302 - lr: 0.0010
# Epoch 62/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8341 - categorical_accuracy: 0.6665 - f1_score: 0.6394
# Epoch 62: saving model to roberta_best_model.h5
# 21/21 [==============================] - 34s 2s/step - loss: 0.8341 - categorical_accuracy: 0.6665 - f1_score: 0.6394 - val_loss: 0.8588 - val_categorical_accuracy: 0.6652 - val_f1_score: 0.6347 - lr: 2.0000e-04
# Epoch 63/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8219 - categorical_accuracy: 0.6825 - f1_score: 0.6603
# Epoch 63: saving model to roberta_best_model.h5
# 21/21 [==============================] - 27s 1s/step - loss: 0.8219 - categorical_accuracy: 0.6825 - f1_score: 0.6603 - val_loss: 0.8593 - val_categorical_accuracy: 0.6606 - val_f1_score: 0.6396 - lr: 2.0000e-04
# Epoch 64/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8323 - categorical_accuracy: 0.6711 - f1_score: 0.6487
# Epoch 64: saving model to roberta_best_model.h5
# 21/21 [==============================] - 30s 1s/step - loss: 0.8323 - categorical_accuracy: 0.6711 - f1_score: 0.6487 - val_loss: 0.8580 - val_categorical_accuracy: 0.6561 - val_f1_score: 0.6405 - lr: 2.0000e-04
# Epoch 65/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8140 - categorical_accuracy: 0.6859 - f1_score: 0.6621
# Epoch 65: saving model to roberta_best_model.h5
# 21/21 [==============================] - 33s 2s/step - loss: 0.8140 - categorical_accuracy: 0.6859 - f1_score: 0.6621 - val_loss: 0.8634 - val_categorical_accuracy: 0.6530 - val_f1_score: 0.6063 - lr: 2.0000e-04
# Epoch 66/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8287 - categorical_accuracy: 0.6620 - f1_score: 0.6351Restoring model weights from the end of the best epoch: 56.
#
# Epoch 66: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 66: saving model to roberta_best_model.h5
# 21/21 [==============================] - 29s 1s/step - loss: 0.8287 - categorical_accuracy: 0.6620 - f1_score: 0.6351 - val_loss: 0.8563 - val_categorical_accuracy: 0.6530 - val_f1_score: 0.6323 - lr: 2.0000e-04
# Epoch 66: early stopping

# %%
results = inital_model.evaluate([test_input_ids, test_attention_masks], test_labels)
print('Test accuracy:', results)
# Out:
# 62/62 [==============================] - 11s 183ms/step - loss: 0.9443 - categorical_accuracy: 0.5951 - f1_score: 0.4161
# Test accuracy: [0.944343626499176, 0.5950919985771179, 0.41610562801361084]

# %%
# Get model predictions
predictions = inital_model.predict([test_input_ids, test_attention_masks])

# Convert predictions to class labels
predicted_labels = np.argmax(predictions, axis=1)

# Assuming test_labels are one-hot encoded, convert them to class labels
true_labels = np.argmax(test_labels, axis=1)

# Generate classification report
report = classification_report(true_labels, predicted_labels)
print(report)
# Out:
# 62/62 [==============================] - 15s 188ms/step
#               precision    recall  f1-score   support
#
#            0       0.65      0.71      0.68      1014
#            1       0.60      0.37      0.46       452
#            2       0.49      0.55      0.52       490
#
#     accuracy                           0.60      1956
#    macro avg       0.58      0.55      0.55      1956
# weighted avg       0.60      0.60      0.59      1956

# %%
def load_classification_rp_per_target(model):
    targets = test_df.Target.unique()
    metrics_df = pd.DataFrame()
    for target in targets:
        extracted_df = test_df[test_df['Target'] == target]
        input_ids, attention_masks = bert_tokenize(extracted_df['Tweet'], extracted_df['Target'].to_list())
        labels = categorized_label(extracted_df, "Stance")

        # Convert one-hot encoded labels to single integer class labels
        true_labels = np.argmax(labels, axis=1)

        # Get model predictions
        predictions = model.predict([input_ids, attention_masks])

        # Convert predictions to class labels
        predicted_labels = np.argmax(predictions, axis=1)

        # Generate a classification report
        report = classification_report(true_labels, predicted_labels, target_names=['AGAINST', 'FAVOR', 'NONE'])
        target_name = ""
        if target == 0:
            target_name = "Hillary Clinton"
        if target == 1:
            target_name = "Legalization of Abortion"
        if target == 2:
            target_name = "Atheism"
        if target == 3:
            target_name = "Climate Change is a Real Concern"
        if target == 4:
            target_name = "Feminist Movement"
        if target == 5:
            target_name = "Donald Trump"

        print('Target: ', target_name)
        print(report)
        print("-----------------------------------------", "\n")

        # Flatten the report into a single row and add target name
        report = classification_report(true_labels, predicted_labels, target_names=['AGAINST', 'FAVOR', 'NONE'], output_dict=True)

        # Extract weighted f1, macro f1, and accuracy
        report_data = {
            'Target': target_name,
            'Weighted F1': report['weighted avg']['f1-score'],
            'Macro F1': report['macro avg']['f1-score'],
            'Accuracy': report['accuracy']
        }

        # Append to the DataFrame
        metrics_df = metrics_df.append(report_data, ignore_index=True)
    metrics_df.set_index('Target', inplace=True)

    return metrics_df

# %%
# Use the function to get the metrics DataFrame
model_metrics_df = load_classification_rp_per_target(inital_model)
model_metrics_df
# Out:
# 7/7 [==============================] - 1s 170ms/step
# Target:  Atheism
#               precision    recall  f1-score   support
#
#      AGAINST       0.77      0.89      0.82       160
#        FAVOR       0.44      0.12      0.20        32
#         NONE       0.46      0.43      0.44        28
#
#     accuracy                           0.72       220
#    macro avg       0.56      0.48      0.49       220
# weighted avg       0.68      0.72      0.68       220
#
# -----------------------------------------
# <ipython-input-16-cdaa14f0a2b9>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 6/6 [==============================] - 1s 159ms/step
# Target:  Climate Change is a Real Concern
#               precision    recall  f1-score   support
#
#      AGAINST       1.00      0.09      0.17        11
#        FAVOR       0.85      0.76      0.81       123
#         NONE       0.47      0.77      0.58        35
#
#     accuracy                           0.72       169
#    macro avg       0.77      0.54      0.52       169
# weighted avg       0.78      0.72      0.72       169
#
# -----------------------------------------
# <ipython-input-16-cdaa14f0a2b9>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 9/9 [==============================] - 2s 170ms/step
# Target:  Feminist Movement
#               precision    recall  f1-score   support
#
#      AGAINST       0.71      0.75      0.73       183
#        FAVOR       0.37      0.33      0.35        58
#         NONE       0.54      0.48      0.51        44
#
#     accuracy                           0.62       285
#    macro avg       0.54      0.52      0.53       285
# weighted avg       0.61      0.62      0.62       285
#
# -----------------------------------------
# <ipython-input-16-cdaa14f0a2b9>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 10/10 [==============================] - 2s 162ms/step
# Target:  Hillary Clinton
#               precision    recall  f1-score   support
#
#      AGAINST       0.66      0.89      0.76       172
#        FAVOR       0.54      0.29      0.38        45
#         NONE       0.72      0.36      0.48        78
#
#     accuracy                           0.66       295
#    macro avg       0.64      0.51      0.54       295
# weighted avg       0.66      0.66      0.63       295
#
# -----------------------------------------
# <ipython-input-16-cdaa14f0a2b9>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 9/9 [==============================] - 2s 178ms/step
# Target:  Legalization of Abortion
#               precision    recall  f1-score   support
#
#      AGAINST       0.79      0.68      0.73       189
#        FAVOR       0.39      0.37      0.38        46
#         NONE       0.44      0.71      0.55        45
#
#     accuracy                           0.64       280
#    macro avg       0.54      0.59      0.55       280
# weighted avg       0.67      0.64      0.64       280
#
# -----------------------------------------
# <ipython-input-16-cdaa14f0a2b9>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 23/23 [==============================] - 5s 206ms/step
# Target:  Donald Trump
#               precision    recall  f1-score   support
#
#      AGAINST       0.47      0.55      0.51       299
#        FAVOR       0.53      0.14      0.22       148
#         NONE       0.47      0.58      0.52       260
#
#     accuracy                           0.47       707
#    macro avg       0.49      0.42      0.42       707
# weighted avg       0.48      0.47      0.45       707
#
# -----------------------------------------
# <ipython-input-16-cdaa14f0a2b9>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
#                                   Weighted F1  Macro F1  Accuracy
# Target
# Atheism                              0.683630  0.487585  0.718182
# Climate Change is a Real Concern     0.718346  0.518060  0.721893
# Feminist Movement                    0.615102  0.526090  0.621053
# Hillary Clinton                      0.625651  0.537623  0.657627
# Legalization of Abortion             0.643318  0.551888  0.635714
# Donald Trump                         0.451673  0.416208  0.473833

# %% [markdown]
# [4] Fine Tune

# %%
for layer in inital_model.layers:
    layer.trainable = True
   # Tuning the learning rate for the optimizer
inital_model.compile(optimizer=tf.keras.optimizers.legacy.Adam(1e-5),
                  loss='categorical_crossentropy',
                  metrics=['categorical_accuracy', f1_score])

history['fine_tuned_bert'] = inital_model.fit([train_input_ids, train_attention_masks], train_labels,
                    epochs=30,
                    validation_data=([val_input_ids, val_attention_masks], val_labels),
                    batch_size=32,
                    callbacks=callbacks,
                    shuffle = True)
# Out:
# Epoch 1/30
# WARNING:tensorflow:Gradients do not exist for variables ['tf_roberta_model_1/roberta/pooler/dense/kernel:0', 'tf_roberta_model_1/roberta/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['tf_roberta_model_1/roberta/pooler/dense/kernel:0', 'tf_roberta_model_1/roberta/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 83/83 [==============================] - ETA: 0s - loss: 0.8650 - categorical_accuracy: 0.6476 - f1_score: 0.6057
# Epoch 1: saving model to roberta_best_model.h5
# 83/83 [==============================] - 129s 1s/step - loss: 0.8650 - categorical_accuracy: 0.6476 - f1_score: 0.6057 - val_loss: 0.8227 - val_categorical_accuracy: 0.6803 - val_f1_score: 0.6460 - lr: 1.0000e-05
# Epoch 2/30
# 83/83 [==============================] - ETA: 0s - loss: 0.7859 - categorical_accuracy: 0.7049 - f1_score: 0.6774
# Epoch 2: saving model to roberta_best_model.h5
# 83/83 [==============================] - 103s 1s/step - loss: 0.7859 - categorical_accuracy: 0.7049 - f1_score: 0.6774 - val_loss: 0.7982 - val_categorical_accuracy: 0.6833 - val_f1_score: 0.6730 - lr: 1.0000e-05
# Epoch 3/30
# 83/83 [==============================] - ETA: 0s - loss: 0.7221 - categorical_accuracy: 0.7291 - f1_score: 0.7100
# Epoch 3: saving model to roberta_best_model.h5
# 83/83 [==============================] - 101s 1s/step - loss: 0.7221 - categorical_accuracy: 0.7291 - f1_score: 0.7100 - val_loss: 0.7855 - val_categorical_accuracy: 0.6985 - val_f1_score: 0.6738 - lr: 1.0000e-05
# Epoch 4/30
# 83/83 [==============================] - ETA: 0s - loss: 0.6729 - categorical_accuracy: 0.7538 - f1_score: 0.7291
# Epoch 4: saving model to roberta_best_model.h5
# 83/83 [==============================] - 102s 1s/step - loss: 0.6729 - categorical_accuracy: 0.7538 - f1_score: 0.7291 - val_loss: 0.7698 - val_categorical_accuracy: 0.7152 - val_f1_score: 0.6945 - lr: 1.0000e-05
# Epoch 5/30
# 83/83 [==============================] - ETA: 0s - loss: 0.5974 - categorical_accuracy: 0.7978 - f1_score: 0.7852
# Epoch 5: saving model to roberta_best_model.h5
# 83/83 [==============================] - 99s 1s/step - loss: 0.5974 - categorical_accuracy: 0.7978 - f1_score: 0.7852 - val_loss: 0.7708 - val_categorical_accuracy: 0.7136 - val_f1_score: 0.6978 - lr: 1.0000e-05
# Epoch 6/30
# 83/83 [==============================] - ETA: 0s - loss: 0.5796 - categorical_accuracy: 0.8065 - f1_score: 0.7981
# Epoch 6: saving model to roberta_best_model.h5
# 83/83 [==============================] - 103s 1s/step - loss: 0.5796 - categorical_accuracy: 0.8065 - f1_score: 0.7981 - val_loss: 0.7724 - val_categorical_accuracy: 0.7333 - val_f1_score: 0.7133 - lr: 1.0000e-05
# Epoch 7/30
# 83/83 [==============================] - ETA: 0s - loss: 0.5086 - categorical_accuracy: 0.8410 - f1_score: 0.8320
# Epoch 7: saving model to roberta_best_model.h5
# 83/83 [==============================] - 97s 1s/step - loss: 0.5086 - categorical_accuracy: 0.8410 - f1_score: 0.8320 - val_loss: 0.8611 - val_categorical_accuracy: 0.7242 - val_f1_score: 0.6842 - lr: 1.0000e-05
# Epoch 8/30
# 83/83 [==============================] - ETA: 0s - loss: 0.4625 - categorical_accuracy: 0.8577 - f1_score: 0.8506
# Epoch 8: saving model to roberta_best_model.h5
# 83/83 [==============================] - 97s 1s/step - loss: 0.4625 - categorical_accuracy: 0.8577 - f1_score: 0.8506 - val_loss: 0.8608 - val_categorical_accuracy: 0.7061 - val_f1_score: 0.6904 - lr: 1.0000e-05
# Epoch 9/30
# 83/83 [==============================] - ETA: 0s - loss: 0.4208 - categorical_accuracy: 0.8816 - f1_score: 0.8747
# Epoch 9: saving model to roberta_best_model.h5
# 83/83 [==============================] - 99s 1s/step - loss: 0.4208 - categorical_accuracy: 0.8816 - f1_score: 0.8747 - val_loss: 0.8968 - val_categorical_accuracy: 0.7106 - val_f1_score: 0.6737 - lr: 1.0000e-05
# Epoch 10/30
# 83/83 [==============================] - ETA: 0s - loss: 0.3757 - categorical_accuracy: 0.9033 - f1_score: 0.8964
# Epoch 10: saving model to roberta_best_model.h5
# 83/83 [==============================] - 98s 1s/step - loss: 0.3757 - categorical_accuracy: 0.9033 - f1_score: 0.8964 - val_loss: 0.9632 - val_categorical_accuracy: 0.6985 - val_f1_score: 0.6786 - lr: 1.0000e-05
# Epoch 11/30
# 83/83 [==============================] - ETA: 0s - loss: 0.3462 - categorical_accuracy: 0.9097 - f1_score: 0.9074
# Epoch 11: saving model to roberta_best_model.h5
# 83/83 [==============================] - 99s 1s/step - loss: 0.3462 - categorical_accuracy: 0.9097 - f1_score: 0.9074 - val_loss: 0.9688 - val_categorical_accuracy: 0.7136 - val_f1_score: 0.6986 - lr: 1.0000e-05
# Epoch 12/30
# 83/83 [==============================] - ETA: 0s - loss: 0.3371 - categorical_accuracy: 0.9150 - f1_score: 0.9072
# Epoch 12: saving model to roberta_best_model.h5
# 83/83 [==============================] - 103s 1s/step - loss: 0.3371 - categorical_accuracy: 0.9150 - f1_score: 0.9072 - val_loss: 0.9754 - val_categorical_accuracy: 0.7121 - val_f1_score: 0.7064 - lr: 1.0000e-05
# Epoch 13/30
# 83/83 [==============================] - ETA: 0s - loss: 0.3106 - categorical_accuracy: 0.9264 - f1_score: 0.9234
# Epoch 13: saving model to roberta_best_model.h5
# 83/83 [==============================] - 101s 1s/step - loss: 0.3106 - categorical_accuracy: 0.9264 - f1_score: 0.9234 - val_loss: 0.9837 - val_categorical_accuracy: 0.7258 - val_f1_score: 0.7023 - lr: 1.0000e-05
# Epoch 14/30
# 83/83 [==============================] - ETA: 0s - loss: 0.2898 - categorical_accuracy: 0.9397 - f1_score: 0.9363Restoring model weights from the end of the best epoch: 4.
#
# Epoch 14: saving model to roberta_best_model.h5
# 83/83 [==============================] - 102s 1s/step - loss: 0.2898 - categorical_accuracy: 0.9397 - f1_score: 0.9363 - val_loss: 1.1435 - val_categorical_accuracy: 0.7364 - val_f1_score: 0.6902 - lr: 1.0000e-05
# Epoch 14: early stopping

# %%
# Use the function to get the metrics DataFrame
model_metrics_df = load_classification_rp_per_target(inital_model)
model_metrics_df
# Out:
# 7/7 [==============================] - 4s 174ms/step
# Target:  Atheism
#               precision    recall  f1-score   support
#
#      AGAINST       0.86      0.87      0.87       160
#        FAVOR       0.62      0.50      0.55        32
#         NONE       0.61      0.71      0.66        28
#
#     accuracy                           0.80       220
#    macro avg       0.69      0.69      0.69       220
# weighted avg       0.79      0.80      0.79       220
#
# -----------------------------------------
# <ipython-input-16-cdaa14f0a2b9>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 6/6 [==============================] - 1s 161ms/step
# Target:  Climate Change is a Real Concern
#               precision    recall  f1-score   support
#
#      AGAINST       0.00      0.00      0.00        11
#        FAVOR       0.87      0.89      0.88       123
#         NONE       0.71      0.83      0.76        35
#
#     accuracy                           0.82       169
#    macro avg       0.53      0.57      0.55       169
# weighted avg       0.78      0.82      0.80       169
#
# -----------------------------------------
# <ipython-input-16-cdaa14f0a2b9>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 9/9 [==============================] - 2s 219ms/step
# Target:  Feminist Movement
#               precision    recall  f1-score   support
#
#      AGAINST       0.80      0.67      0.73       183
#        FAVOR       0.42      0.62      0.50        58
#         NONE       0.59      0.61      0.60        44
#
#     accuracy                           0.65       285
#    macro avg       0.60      0.64      0.61       285
# weighted avg       0.69      0.65      0.66       285
#
# -----------------------------------------
# <ipython-input-16-cdaa14f0a2b9>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 10/10 [==============================] - 2s 178ms/step
# Target:  Hillary Clinton
#               precision    recall  f1-score   support
#
#      AGAINST       0.79      0.82      0.81       172
#        FAVOR       0.62      0.67      0.65        45
#         NONE       0.78      0.69      0.73        78
#
#     accuracy                           0.76       295
#    macro avg       0.73      0.73      0.73       295
# weighted avg       0.76      0.76      0.76       295
#
# -----------------------------------------
# <ipython-input-16-cdaa14f0a2b9>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 9/9 [==============================] - 2s 169ms/step
# Target:  Legalization of Abortion
#               precision    recall  f1-score   support
#
#      AGAINST       0.86      0.69      0.77       189
#        FAVOR       0.41      0.59      0.48        46
#         NONE       0.56      0.76      0.64        45
#
#     accuracy                           0.69       280
#    macro avg       0.61      0.68      0.63       280
# weighted avg       0.73      0.69      0.70       280
#
# -----------------------------------------
# <ipython-input-16-cdaa14f0a2b9>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 23/23 [==============================] - 4s 168ms/step
# Target:  Donald Trump
#               precision    recall  f1-score   support
#
#      AGAINST       0.55      0.61      0.58       299
#        FAVOR       0.64      0.61      0.62       148
#         NONE       0.64      0.57      0.60       260
#
#     accuracy                           0.60       707
#    macro avg       0.61      0.60      0.60       707
# weighted avg       0.60      0.60      0.60       707
#
# -----------------------------------------
# <ipython-input-16-cdaa14f0a2b9>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
#                                   Weighted F1  Macro F1  Accuracy
# Target
# Atheism                              0.793558  0.691168  0.795455
# Climate Change is a Real Concern     0.801096  0.548897  0.822485
# Feminist Movement                    0.663815  0.611156  0.652632
# Hillary Clinton                      0.762445  0.728523  0.762712
# Legalization of Abortion             0.699414  0.629911  0.685714
# Donald Trump                         0.597589  0.602138  0.596888

# %%
# Get model predictions
predictions = inital_model.predict([test_input_ids, test_attention_masks])

# Convert predictions to class labels
predicted_labels = np.argmax(predictions, axis=1)

# Assuming test_labels are one-hot encoded, convert them to class labels
true_labels = np.argmax(test_labels, axis=1)

# Generate classification report
report = classification_report(true_labels, predicted_labels)
print(report)
# Out:
# 62/62 [==============================] - 12s 190ms/step
#               precision    recall  f1-score   support
#
#            0       0.73      0.71      0.72      1014
#            1       0.63      0.68      0.65       452
#            2       0.65      0.64      0.64       490
#
#     accuracy                           0.68      1956
#    macro avg       0.67      0.68      0.67      1956
# weighted avg       0.69      0.68      0.69      1956

# %%
inital_model.save('roberta_model_66.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
