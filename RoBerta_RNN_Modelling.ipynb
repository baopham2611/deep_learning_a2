# %%
# !pip install plotly
# !pip install seaborn
# !pip install matplotlib
# !pip install transformers
# !pip install tokenizers
# !pip install scikit-learn
# !pip install tensorflow
# !pip install pandas
# !pip install numpy
# !pip install keras_tuner


from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #
# <a id="data-prep"></a>
# <div style="background-color: #000D5B; color: white; text-align: center; padding: 6px 0 22px 0">
#     <h3 style="background-color: #000D5B; color: white; text-align: left">RMIT School of Computer Science and Technology</h3>
#     <br/>
#     <h1>COSC3007: Deep Learning</h1>
#     <h2>Assignment 2: Stance Twitter Sentiment Analysis and Detection </h2>
#     <h2> [2] MODELLING AND MODEL EVALUATIONS </h2>
#
# </div>

# %% [markdown]
# # Import Libs

# %%
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, BatchNormalization, Bidirectional, Flatten
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers.legacy import Adam
from sklearn.metrics import classification_report
import numpy as np

import numpy as np

# %% [markdown]
# # [1] Load Data

# %%
train_df = pd.read_csv("./drive/MyDrive/Colab Notebooks/StanceDataset/processed_train.csv", encoding = "ISO-8859-1", engine="python").drop(columns=['Unnamed: 0'])
train_df = train_df.sample(frac=1, random_state=42).reset_index(drop=True)
train_df = train_df.dropna(subset=['processed_tweet'])
train_ori = train_df.copy()

test_df = pd.read_csv("./drive/MyDrive/Colab Notebooks/StanceDataset/processed_test.csv", encoding = "ISO-8859-1", engine="python").drop(columns=['Unnamed: 0'])

# %% [markdown]
# # [2] Prepare label and fit data

# %% [markdown]
# ## Split test and val

# %%
train_df, val_df = train_test_split(train_df, test_size=0.2, random_state=42, shuffle=True)

# %% [markdown]
# ## Tweets

# %%
from transformers import TFRobertaModel, RobertaTokenizer
import numpy as np

# Initialize the BERT tokenizer
MAX_LENGTH = 512
tokenizer = RobertaTokenizer.from_pretrained('roberta-base')
roberta_model = TFRobertaModel.from_pretrained('roberta-base')

# Assuming train_texts, val_texts, test_texts are your datasets
train_processed_tweets = train_df['processed_tweet'].tolist()
val_processed_tweets = val_df['processed_tweet'].tolist()
test_processed_tweets = test_df['processed_tweet'].tolist()

all_processed_tweets = train_processed_tweets + val_processed_tweets + test_processed_tweets
tokenized_tweets = [tokenizer.encode(tweet, add_special_tokens=True) for tweet in all_processed_tweets]
MAX_LENGTH = max(len(tweet) for tweet in tokenized_tweets)

print("Maximum length across all datasets:", MAX_LENGTH)


def bert_tokenize(texts, targets, max_length=MAX_LENGTH):
    input_ids = []
    attention_masks = []

    for idx, text in enumerate(texts):
        targetID = targets[idx]
        target_name = ""
        if targetID == 0:
            target_name = "Hillary Clinton"
        if targetID == 1:
            target_name = "Legalization of Abortion"
        if targetID == 2:
            target_name = "Atheism"
        if targetID == 3:
            target_name = "Climate Change is a Real Concern"
        if targetID == 4:
            target_name = "Feminist Movement"
        if targetID == 5:
            target_name = "Donald Trump"
        formatted_text = f"<s> {target_name} </s></s> {text} </s>"
        encoded = tokenizer.encode_plus(
            formatted_text,
            add_special_tokens=True,
            max_length=max_length,
            truncation=True,
            padding='max_length',
            return_attention_mask=True,
            return_tensors='tf',
        )

        # Flatten the tensors and remove the extra dimension
        input_ids.append(tf.squeeze(encoded['input_ids'], axis=0))
        attention_masks.append(tf.squeeze(encoded['attention_mask'], axis=0))

    return np.array(input_ids), np.array(attention_masks)

# Assuming you have lists of preprocessed texts for training, validation, and test sets
train_input_ids, train_attention_masks = bert_tokenize(train_df['processed_tweet'],  train_df['Target'].to_list())
val_input_ids, val_attention_masks = bert_tokenize(val_df['processed_tweet'], val_df['Target'].to_list())
test_input_ids, test_attention_masks = bert_tokenize(test_df['processed_tweet'], test_df['Target'].to_list())
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:72: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/481 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFRobertaModel: ['lm_head.layer_norm.weight', 'roberta.embeddings.position_ids', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.bias', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing TFRobertaModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFRobertaModel were not initialized from the PyTorch model and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Maximum length across all datasets: 35

# %% [markdown]
# ## Stances

# %%
def categorized_label(df, label_name):
    label_encoder = LabelEncoder()
    encoded_labels = label_encoder.fit_transform(df[label_name])
    categorical_labels = to_categorical(encoded_labels)
    return categorical_labels

# %%
train_labels = categorized_label(train_df, "Stance")
test_labels = categorized_label(test_df, "Stance")
val_labels = categorized_label(val_df, "Stance")

# %% [markdown]
# # [3] Create Model

# %%
from keras import backend as K
from tensorflow.keras.optimizers.legacy import Adam
from hyperopt import hp
from hyperopt import hp, fmin, tpe, STATUS_OK, Trials
# import keras_tuner as kt

# %%
def f1_score_class(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))

    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    return 2 * ((precision * recall) / (precision + recall + K.epsilon()))

def f1_score(y_true, y_pred):
    # Convert predictions to one-hot format
    y_pred_one_hot = K.one_hot(K.argmax(y_pred), num_classes=3)

    # Calculate F1 score for each class
    f1s = [f1_score_class(y_true[:, i], y_pred_one_hot[:, i]) for i in range(3)]

    # Average F1 scores across all classes
    return K.mean(K.stack(f1s), axis=0)

# %% [markdown]
# Set up call backs and learning rates

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint


# Define the EarlyStopping and ReduceLROnPlateau callbacks
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=10,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=5,
    min_lr=1e-5,
    verbose=1,
)

# Define the ModelCheckpoint callback
checkpoint_path = "roberta_best_model.h5"
model_checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_path,
    save_weights_only=True,    # Only save a model if 'val_loss' has improved
    monitor='val_loss',     # Monitor 'val_loss' during training
    mode='min',             # The model is saved when 'val_loss' is minimized
    verbose=1)

# Combine all callbacks in a list
callbacks = [
    early_stopping,
    lr_scheduler,
    model_checkpoint_callback
]

learning_rate = 0.001
optimizer = Adam(learning_rate=learning_rate)

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, BatchNormalization, Bidirectional, Flatten, Input
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers.legacy import Adam
# import keras_tuner as kt
from transformers import TFRobertaModel

def build_model(drop, regr, lr):
    bert_model = TFRobertaModel.from_pretrained('roberta-base')
    bert_model.trainable = False

    # Define model input (BERT expects two inputs: input_ids and attention_mask)
    input_ids = Input(shape=(MAX_LENGTH,), dtype=tf.int32, name='input_ids')
    attention_mask = Input(shape=(MAX_LENGTH,), dtype=tf.int32, name='attention_mask')

    # Get BERT embeddings
    bert_output = bert_model(input_ids, attention_mask=attention_mask)[0]  # Use the pooled output here

    # Tuning the number of units in the first biLSTM layer
    x = Bidirectional(LSTM(units=128,  dropout=drop, recurrent_dropout=drop,return_sequences=True,kernel_regularizer=tf.keras.regularizers.l2(regr))) (bert_output)

    x = Flatten() (x)

    # Dense layer with tunable units
    x = Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(regr)) (x)

    # Tunable dropout rate for the second layer
    x = Dropout(drop)(x)

    # Final Layer
    x = Dense(3, activation='softmax')(x)

    # Tuning the learning rate for the optimizer
    optimizer = Adam(learning_rate=learning_rate)
    model = Model(inputs=[input_ids, attention_mask], outputs=x)
    model.compile(loss='CategoricalCrossentropy', optimizer=optimizer, metrics=['categorical_accuracy',f1_score])
    model.summary()

    return model

# %% [markdown]
# Recreate the best model with more training time

# %%
history = {}
inital_model = build_model(0.8, 0.0005, 0.001)
history['tuned_stance_model_custom'] = inital_model.fit([train_input_ids, train_attention_masks], train_labels,
                    epochs=100,
                    validation_data=([val_input_ids, val_attention_masks], val_labels),
                    batch_size=32,
                    callbacks=callbacks,
                    shuffle = True)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:72: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFRobertaModel: ['lm_head.layer_norm.weight', 'roberta.embeddings.position_ids', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.bias', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing TFRobertaModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFRobertaModel were not initialized from the PyTorch model and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_ids (InputLayer)      [(None, 35)]                 0         []
#
#  attention_mask (InputLayer  [(None, 35)]                 0         []
#  )
#
#  tf_roberta_model_1 (TFRobe  TFBaseModelOutputWithPooli   1246456   ['input_ids[0][0]',
#  rtaModel)                   ngAndCrossAttentions(last_   32         'attention_mask[0][0]']
#                              hidden_state=(None, 35, 76
#                              8),
#                               pooler_output=(None, 768)
#                              , past_key_values=None, hi
#                              dden_states=None, attentio
#                              ns=None, cross_attentions=
#                              None)
#
#  bidirectional (Bidirection  (None, 35, 256)              918528    ['tf_roberta_model_1[0][0]']
#  al)
#
#  flatten (Flatten)           (None, 8960)                 0         ['bidirectional[0][0]']
#
#  dense (Dense)               (None, 128)                  1147008   ['flatten[0][0]']
#
#  dropout_74 (Dropout)        (None, 128)                  0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 3)                    387       ['dropout_74[0][0]']
#
# ==================================================================================================
# Total params: 126711555 (483.37 MB)
# Trainable params: 2065923 (7.88 MB)
# Non-trainable params: 124645632 (475.49 MB)
# __________________________________________________________________________________________________
# Epoch 1/100
# 73/73 [==============================] - ETA: 0s - loss: 1.8097 - categorical_accuracy: 0.4264 - f1_score: 0.3119
# Epoch 1: saving model to roberta_best_model.h5
# 73/73 [==============================] - 73s 600ms/step - loss: 1.8097 - categorical_accuracy: 0.4264 - f1_score: 0.3119 - val_loss: 1.6161 - val_categorical_accuracy: 0.5455 - val_f1_score: 0.3462 - lr: 0.0010
# Epoch 2/100
# 73/73 [==============================] - ETA: 0s - loss: 1.5496 - categorical_accuracy: 0.4891 - f1_score: 0.2982
# Epoch 2: saving model to roberta_best_model.h5
# 73/73 [==============================] - 31s 422ms/step - loss: 1.5496 - categorical_accuracy: 0.4891 - f1_score: 0.2982 - val_loss: 1.4582 - val_categorical_accuracy: 0.5111 - val_f1_score: 0.4065 - lr: 0.0010
# Epoch 3/100
# 73/73 [==============================] - ETA: 0s - loss: 1.3880 - categorical_accuracy: 0.5101 - f1_score: 0.3069
# Epoch 3: saving model to roberta_best_model.h5
# 73/73 [==============================] - 30s 418ms/step - loss: 1.3880 - categorical_accuracy: 0.5101 - f1_score: 0.3069 - val_loss: 1.2741 - val_categorical_accuracy: 0.5455 - val_f1_score: 0.3462 - lr: 0.0010
# Epoch 4/100
# 73/73 [==============================] - ETA: 0s - loss: 1.2842 - categorical_accuracy: 0.5315 - f1_score: 0.3592
# Epoch 4: saving model to roberta_best_model.h5
# 73/73 [==============================] - 29s 402ms/step - loss: 1.2842 - categorical_accuracy: 0.5315 - f1_score: 0.3592 - val_loss: 1.2068 - val_categorical_accuracy: 0.5455 - val_f1_score: 0.3462 - lr: 0.0010
# Epoch 5/100
# 73/73 [==============================] - ETA: 0s - loss: 1.2506 - categorical_accuracy: 0.5264 - f1_score: 0.3677
# Epoch 5: saving model to roberta_best_model.h5
# 73/73 [==============================] - 30s 405ms/step - loss: 1.2506 - categorical_accuracy: 0.5264 - f1_score: 0.3677 - val_loss: 1.1675 - val_categorical_accuracy: 0.5523 - val_f1_score: 0.3904 - lr: 0.0010
# Epoch 6/100
# 73/73 [==============================] - ETA: 0s - loss: 1.1924 - categorical_accuracy: 0.5384 - f1_score: 0.3836
# Epoch 6: saving model to roberta_best_model.h5
# 73/73 [==============================] - 31s 417ms/step - loss: 1.1924 - categorical_accuracy: 0.5384 - f1_score: 0.3836 - val_loss: 1.1541 - val_categorical_accuracy: 0.5489 - val_f1_score: 0.3541 - lr: 0.0010
# Epoch 7/100
# 73/73 [==============================] - ETA: 0s - loss: 1.1717 - categorical_accuracy: 0.5410 - f1_score: 0.3886
# Epoch 7: saving model to roberta_best_model.h5
# 73/73 [==============================] - 32s 442ms/step - loss: 1.1717 - categorical_accuracy: 0.5410 - f1_score: 0.3886 - val_loss: 1.1280 - val_categorical_accuracy: 0.5506 - val_f1_score: 0.3580 - lr: 0.0010
# Epoch 8/100
# 73/73 [==============================] - ETA: 0s - loss: 1.1500 - categorical_accuracy: 0.5538 - f1_score: 0.4058
# Epoch 8: saving model to roberta_best_model.h5
# 73/73 [==============================] - 31s 418ms/step - loss: 1.1500 - categorical_accuracy: 0.5538 - f1_score: 0.4058 - val_loss: 1.1206 - val_categorical_accuracy: 0.5883 - val_f1_score: 0.4780 - lr: 0.0010
# Epoch 9/100
# 73/73 [==============================] - ETA: 0s - loss: 1.1527 - categorical_accuracy: 0.5646 - f1_score: 0.4373
# Epoch 9: saving model to roberta_best_model.h5
# 73/73 [==============================] - 31s 434ms/step - loss: 1.1527 - categorical_accuracy: 0.5646 - f1_score: 0.4373 - val_loss: 1.1147 - val_categorical_accuracy: 0.5729 - val_f1_score: 0.4349 - lr: 0.0010
# Epoch 10/100
# 73/73 [==============================] - ETA: 0s - loss: 1.1414 - categorical_accuracy: 0.5641 - f1_score: 0.4402
# Epoch 10: saving model to roberta_best_model.h5
# 73/73 [==============================] - 30s 418ms/step - loss: 1.1414 - categorical_accuracy: 0.5641 - f1_score: 0.4402 - val_loss: 1.1076 - val_categorical_accuracy: 0.5729 - val_f1_score: 0.4487 - lr: 0.0010
# Epoch 11/100
# 73/73 [==============================] - ETA: 0s - loss: 1.1498 - categorical_accuracy: 0.5659 - f1_score: 0.4522
# Epoch 11: saving model to roberta_best_model.h5
# 73/73 [==============================] - 30s 412ms/step - loss: 1.1498 - categorical_accuracy: 0.5659 - f1_score: 0.4522 - val_loss: 1.1041 - val_categorical_accuracy: 0.5746 - val_f1_score: 0.4458 - lr: 0.0010
# Epoch 12/100
# 73/73 [==============================] - ETA: 0s - loss: 1.1322 - categorical_accuracy: 0.5792 - f1_score: 0.4698
# Epoch 12: saving model to roberta_best_model.h5
# 73/73 [==============================] - 30s 410ms/step - loss: 1.1322 - categorical_accuracy: 0.5792 - f1_score: 0.4698 - val_loss: 1.1520 - val_categorical_accuracy: 0.5729 - val_f1_score: 0.4378 - lr: 0.0010
# Epoch 13/100
# 73/73 [==============================] - ETA: 0s - loss: 1.1331 - categorical_accuracy: 0.5890 - f1_score: 0.4939
# Epoch 13: saving model to roberta_best_model.h5
# 73/73 [==============================] - 28s 384ms/step - loss: 1.1331 - categorical_accuracy: 0.5890 - f1_score: 0.4939 - val_loss: 1.1301 - val_categorical_accuracy: 0.5849 - val_f1_score: 0.4933 - lr: 0.0010
# Epoch 14/100
# 73/73 [==============================] - ETA: 0s - loss: 1.1269 - categorical_accuracy: 0.5950 - f1_score: 0.5058
# Epoch 14: saving model to roberta_best_model.h5
# 73/73 [==============================] - 34s 458ms/step - loss: 1.1269 - categorical_accuracy: 0.5950 - f1_score: 0.5058 - val_loss: 1.1460 - val_categorical_accuracy: 0.5918 - val_f1_score: 0.4676 - lr: 0.0010
# Epoch 15/100
# 73/73 [==============================] - ETA: 0s - loss: 1.1296 - categorical_accuracy: 0.5907 - f1_score: 0.4776
# Epoch 15: saving model to roberta_best_model.h5
# 73/73 [==============================] - 26s 363ms/step - loss: 1.1296 - categorical_accuracy: 0.5907 - f1_score: 0.4776 - val_loss: 1.2026 - val_categorical_accuracy: 0.5540 - val_f1_score: 0.5411 - lr: 0.0010
# Epoch 16/100
# 73/73 [==============================] - ETA: 0s - loss: 1.0845 - categorical_accuracy: 0.6135 - f1_score: 0.5213
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 16: saving model to roberta_best_model.h5
# 73/73 [==============================] - 28s 387ms/step - loss: 1.0845 - categorical_accuracy: 0.6135 - f1_score: 0.5213 - val_loss: 1.1324 - val_categorical_accuracy: 0.5935 - val_f1_score: 0.5138 - lr: 0.0010
# Epoch 17/100
# 73/73 [==============================] - ETA: 0s - loss: 1.0614 - categorical_accuracy: 0.6221 - f1_score: 0.5394
# Epoch 17: saving model to roberta_best_model.h5
# 73/73 [==============================] - 29s 399ms/step - loss: 1.0614 - categorical_accuracy: 0.6221 - f1_score: 0.5394 - val_loss: 1.1083 - val_categorical_accuracy: 0.6055 - val_f1_score: 0.5327 - lr: 2.0000e-04
# Epoch 18/100
# 73/73 [==============================] - ETA: 0s - loss: 1.0402 - categorical_accuracy: 0.6242 - f1_score: 0.5490
# Epoch 18: saving model to roberta_best_model.h5
# 73/73 [==============================] - 32s 447ms/step - loss: 1.0402 - categorical_accuracy: 0.6242 - f1_score: 0.5490 - val_loss: 1.0934 - val_categorical_accuracy: 0.5866 - val_f1_score: 0.5192 - lr: 2.0000e-04
# Epoch 19/100
# 73/73 [==============================] - ETA: 0s - loss: 1.0249 - categorical_accuracy: 0.6332 - f1_score: 0.5622
# Epoch 19: saving model to roberta_best_model.h5
# 73/73 [==============================] - 49s 670ms/step - loss: 1.0249 - categorical_accuracy: 0.6332 - f1_score: 0.5622 - val_loss: 1.0738 - val_categorical_accuracy: 0.6089 - val_f1_score: 0.5469 - lr: 2.0000e-04
# Epoch 20/100
# 73/73 [==============================] - ETA: 0s - loss: 1.0069 - categorical_accuracy: 0.6375 - f1_score: 0.5662
# Epoch 20: saving model to roberta_best_model.h5
# 73/73 [==============================] - 28s 388ms/step - loss: 1.0069 - categorical_accuracy: 0.6375 - f1_score: 0.5662 - val_loss: 1.0863 - val_categorical_accuracy: 0.6106 - val_f1_score: 0.5394 - lr: 2.0000e-04
# Epoch 21/100
# 73/73 [==============================] - ETA: 0s - loss: 1.0165 - categorical_accuracy: 0.6268 - f1_score: 0.5549
# Epoch 21: saving model to roberta_best_model.h5
# 73/73 [==============================] - 25s 347ms/step - loss: 1.0165 - categorical_accuracy: 0.6268 - f1_score: 0.5549 - val_loss: 1.0743 - val_categorical_accuracy: 0.5866 - val_f1_score: 0.5309 - lr: 2.0000e-04
# Epoch 22/100
# 73/73 [==============================] - ETA: 0s - loss: 0.9872 - categorical_accuracy: 0.6371 - f1_score: 0.5676
# Epoch 22: saving model to roberta_best_model.h5
# 73/73 [==============================] - 26s 350ms/step - loss: 0.9872 - categorical_accuracy: 0.6371 - f1_score: 0.5676 - val_loss: 1.0743 - val_categorical_accuracy: 0.5918 - val_f1_score: 0.5286 - lr: 2.0000e-04
# Epoch 23/100
# 73/73 [==============================] - ETA: 0s - loss: 0.9804 - categorical_accuracy: 0.6461 - f1_score: 0.5730
# Epoch 23: saving model to roberta_best_model.h5
# 73/73 [==============================] - 28s 388ms/step - loss: 0.9804 - categorical_accuracy: 0.6461 - f1_score: 0.5730 - val_loss: 1.0565 - val_categorical_accuracy: 0.6055 - val_f1_score: 0.5425 - lr: 2.0000e-04
# Epoch 24/100
# 73/73 [==============================] - ETA: 0s - loss: 0.9808 - categorical_accuracy: 0.6362 - f1_score: 0.5580
# Epoch 24: saving model to roberta_best_model.h5
# 73/73 [==============================] - 27s 373ms/step - loss: 0.9808 - categorical_accuracy: 0.6362 - f1_score: 0.5580 - val_loss: 1.0578 - val_categorical_accuracy: 0.5969 - val_f1_score: 0.5474 - lr: 2.0000e-04
# Epoch 25/100
# 73/73 [==============================] - ETA: 0s - loss: 0.9650 - categorical_accuracy: 0.6525 - f1_score: 0.5803
# Epoch 25: saving model to roberta_best_model.h5
# 73/73 [==============================] - 33s 461ms/step - loss: 0.9650 - categorical_accuracy: 0.6525 - f1_score: 0.5803 - val_loss: 1.0451 - val_categorical_accuracy: 0.6192 - val_f1_score: 0.5475 - lr: 2.0000e-04
# Epoch 26/100
# 73/73 [==============================] - ETA: 0s - loss: 0.9584 - categorical_accuracy: 0.6345 - f1_score: 0.5630
# Epoch 26: saving model to roberta_best_model.h5
# 73/73 [==============================] - 40s 544ms/step - loss: 0.9584 - categorical_accuracy: 0.6345 - f1_score: 0.5630 - val_loss: 1.0479 - val_categorical_accuracy: 0.6038 - val_f1_score: 0.5473 - lr: 2.0000e-04
# Epoch 27/100
# 73/73 [==============================] - ETA: 0s - loss: 0.9599 - categorical_accuracy: 0.6414 - f1_score: 0.5664
# Epoch 27: saving model to roberta_best_model.h5
# 73/73 [==============================] - 35s 472ms/step - loss: 0.9599 - categorical_accuracy: 0.6414 - f1_score: 0.5664 - val_loss: 1.0606 - val_categorical_accuracy: 0.6072 - val_f1_score: 0.5357 - lr: 2.0000e-04
# Epoch 28/100
# 73/73 [==============================] - ETA: 0s - loss: 0.9608 - categorical_accuracy: 0.6491 - f1_score: 0.5755
# Epoch 28: saving model to roberta_best_model.h5
# 73/73 [==============================] - 28s 383ms/step - loss: 0.9608 - categorical_accuracy: 0.6491 - f1_score: 0.5755 - val_loss: 1.0382 - val_categorical_accuracy: 0.6261 - val_f1_score: 0.5754 - lr: 2.0000e-04
# Epoch 29/100
# 73/73 [==============================] - ETA: 0s - loss: 0.9355 - categorical_accuracy: 0.6568 - f1_score: 0.5880
# Epoch 29: saving model to roberta_best_model.h5
# 73/73 [==============================] - 29s 405ms/step - loss: 0.9355 - categorical_accuracy: 0.6568 - f1_score: 0.5880 - val_loss: 1.0433 - val_categorical_accuracy: 0.6261 - val_f1_score: 0.5580 - lr: 2.0000e-04
# Epoch 30/100
# 73/73 [==============================] - ETA: 0s - loss: 0.9359 - categorical_accuracy: 0.6478 - f1_score: 0.5798
# Epoch 30: saving model to roberta_best_model.h5
# 73/73 [==============================] - 29s 396ms/step - loss: 0.9359 - categorical_accuracy: 0.6478 - f1_score: 0.5798 - val_loss: 1.0462 - val_categorical_accuracy: 0.5815 - val_f1_score: 0.5399 - lr: 2.0000e-04
# Epoch 31/100
# 73/73 [==============================] - ETA: 0s - loss: 0.9209 - categorical_accuracy: 0.6555 - f1_score: 0.5918
# Epoch 31: saving model to roberta_best_model.h5
# 73/73 [==============================] - 36s 499ms/step - loss: 0.9209 - categorical_accuracy: 0.6555 - f1_score: 0.5918 - val_loss: 1.0364 - val_categorical_accuracy: 0.6278 - val_f1_score: 0.5953 - lr: 2.0000e-04
# Epoch 32/100
# 73/73 [==============================] - ETA: 0s - loss: 0.9131 - categorical_accuracy: 0.6572 - f1_score: 0.5902
# Epoch 32: saving model to roberta_best_model.h5
# 73/73 [==============================] - 35s 489ms/step - loss: 0.9131 - categorical_accuracy: 0.6572 - f1_score: 0.5902 - val_loss: 1.0337 - val_categorical_accuracy: 0.6346 - val_f1_score: 0.5841 - lr: 2.0000e-04
# Epoch 33/100
# 73/73 [==============================] - ETA: 0s - loss: 0.9225 - categorical_accuracy: 0.6469 - f1_score: 0.5858
# Epoch 33: saving model to roberta_best_model.h5
# 73/73 [==============================] - 33s 453ms/step - loss: 0.9225 - categorical_accuracy: 0.6469 - f1_score: 0.5858 - val_loss: 1.0279 - val_categorical_accuracy: 0.6072 - val_f1_score: 0.5502 - lr: 2.0000e-04
# Epoch 34/100
# 73/73 [==============================] - ETA: 0s - loss: 0.9126 - categorical_accuracy: 0.6456 - f1_score: 0.5777
# Epoch 34: saving model to roberta_best_model.h5
# 73/73 [==============================] - 27s 375ms/step - loss: 0.9126 - categorical_accuracy: 0.6456 - f1_score: 0.5777 - val_loss: 1.0330 - val_categorical_accuracy: 0.6038 - val_f1_score: 0.5482 - lr: 2.0000e-04
# Epoch 35/100
# 73/73 [==============================] - ETA: 0s - loss: 0.9183 - categorical_accuracy: 0.6512 - f1_score: 0.5888
# Epoch 35: saving model to roberta_best_model.h5
# 73/73 [==============================] - 28s 380ms/step - loss: 0.9183 - categorical_accuracy: 0.6512 - f1_score: 0.5888 - val_loss: 1.0299 - val_categorical_accuracy: 0.6072 - val_f1_score: 0.5734 - lr: 2.0000e-04
# Epoch 36/100
# 73/73 [==============================] - ETA: 0s - loss: 0.9123 - categorical_accuracy: 0.6517 - f1_score: 0.5896
# Epoch 36: saving model to roberta_best_model.h5
# 73/73 [==============================] - 30s 407ms/step - loss: 0.9123 - categorical_accuracy: 0.6517 - f1_score: 0.5896 - val_loss: 1.0029 - val_categorical_accuracy: 0.6346 - val_f1_score: 0.5820 - lr: 2.0000e-04
# Epoch 37/100
# 73/73 [==============================] - ETA: 0s - loss: 0.8892 - categorical_accuracy: 0.6727 - f1_score: 0.6130
# Epoch 37: saving model to roberta_best_model.h5
# 73/73 [==============================] - 29s 403ms/step - loss: 0.8892 - categorical_accuracy: 0.6727 - f1_score: 0.6130 - val_loss: 1.0163 - val_categorical_accuracy: 0.6278 - val_f1_score: 0.5730 - lr: 2.0000e-04
# Epoch 38/100
# 73/73 [==============================] - ETA: 0s - loss: 0.8882 - categorical_accuracy: 0.6628 - f1_score: 0.6041
# Epoch 38: saving model to roberta_best_model.h5
# 73/73 [==============================] - 30s 412ms/step - loss: 0.8882 - categorical_accuracy: 0.6628 - f1_score: 0.6041 - val_loss: 0.9947 - val_categorical_accuracy: 0.6278 - val_f1_score: 0.5738 - lr: 2.0000e-04
# Epoch 39/100
# 73/73 [==============================] - ETA: 0s - loss: 0.8869 - categorical_accuracy: 0.6559 - f1_score: 0.5888
# Epoch 39: saving model to roberta_best_model.h5
# 73/73 [==============================] - 31s 425ms/step - loss: 0.8869 - categorical_accuracy: 0.6559 - f1_score: 0.5888 - val_loss: 1.0258 - val_categorical_accuracy: 0.6141 - val_f1_score: 0.5818 - lr: 2.0000e-04
# Epoch 40/100
# 73/73 [==============================] - ETA: 0s - loss: 0.8781 - categorical_accuracy: 0.6658 - f1_score: 0.6047
# Epoch 40: saving model to roberta_best_model.h5
# 73/73 [==============================] - 45s 618ms/step - loss: 0.8781 - categorical_accuracy: 0.6658 - f1_score: 0.6047 - val_loss: 1.0075 - val_categorical_accuracy: 0.6209 - val_f1_score: 0.5775 - lr: 2.0000e-04
# Epoch 41/100
# 73/73 [==============================] - ETA: 0s - loss: 0.8822 - categorical_accuracy: 0.6654 - f1_score: 0.5983
# Epoch 41: saving model to roberta_best_model.h5
# 73/73 [==============================] - 30s 406ms/step - loss: 0.8822 - categorical_accuracy: 0.6654 - f1_score: 0.5983 - val_loss: 1.0136 - val_categorical_accuracy: 0.6123 - val_f1_score: 0.5793 - lr: 2.0000e-04
# Epoch 42/100
# 73/73 [==============================] - ETA: 0s - loss: 0.8760 - categorical_accuracy: 0.6658 - f1_score: 0.6038
# Epoch 42: saving model to roberta_best_model.h5
# 73/73 [==============================] - 28s 380ms/step - loss: 0.8760 - categorical_accuracy: 0.6658 - f1_score: 0.6038 - val_loss: 1.0622 - val_categorical_accuracy: 0.5763 - val_f1_score: 0.5375 - lr: 2.0000e-04
# Epoch 43/100
# 73/73 [==============================] - ETA: 0s - loss: 0.8733 - categorical_accuracy: 0.6740 - f1_score: 0.6166
# Epoch 43: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 43: saving model to roberta_best_model.h5
# 73/73 [==============================] - 32s 437ms/step - loss: 0.8733 - categorical_accuracy: 0.6740 - f1_score: 0.6166 - val_loss: 0.9993 - val_categorical_accuracy: 0.6123 - val_f1_score: 0.5826 - lr: 2.0000e-04
# Epoch 44/100
# 73/73 [==============================] - ETA: 0s - loss: 0.8751 - categorical_accuracy: 0.6619 - f1_score: 0.6010
# Epoch 44: saving model to roberta_best_model.h5
# 73/73 [==============================] - 28s 387ms/step - loss: 0.8751 - categorical_accuracy: 0.6619 - f1_score: 0.6010 - val_loss: 1.0044 - val_categorical_accuracy: 0.6209 - val_f1_score: 0.5875 - lr: 4.0000e-05
# Epoch 45/100
# 73/73 [==============================] - ETA: 0s - loss: 0.8553 - categorical_accuracy: 0.6714 - f1_score: 0.6075
# Epoch 45: saving model to roberta_best_model.h5
# 73/73 [==============================] - 37s 516ms/step - loss: 0.8553 - categorical_accuracy: 0.6714 - f1_score: 0.6075 - val_loss: 1.0123 - val_categorical_accuracy: 0.6192 - val_f1_score: 0.5859 - lr: 4.0000e-05
# Epoch 46/100
# 73/73 [==============================] - ETA: 0s - loss: 0.8646 - categorical_accuracy: 0.6744 - f1_score: 0.6169
# Epoch 46: saving model to roberta_best_model.h5
# 73/73 [==============================] - 30s 410ms/step - loss: 0.8646 - categorical_accuracy: 0.6744 - f1_score: 0.6169 - val_loss: 1.0135 - val_categorical_accuracy: 0.6244 - val_f1_score: 0.5893 - lr: 4.0000e-05
# Epoch 47/100
# 73/73 [==============================] - ETA: 0s - loss: 0.8462 - categorical_accuracy: 0.6813 - f1_score: 0.6217
# Epoch 47: saving model to roberta_best_model.h5
# 73/73 [==============================] - 28s 388ms/step - loss: 0.8462 - categorical_accuracy: 0.6813 - f1_score: 0.6217 - val_loss: 1.0094 - val_categorical_accuracy: 0.6244 - val_f1_score: 0.5862 - lr: 4.0000e-05
# Epoch 48/100
# 73/73 [==============================] - ETA: 0s - loss: 0.8470 - categorical_accuracy: 0.6864 - f1_score: 0.6294Restoring model weights from the end of the best epoch: 38.
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 48: saving model to roberta_best_model.h5
# 73/73 [==============================] - 32s 440ms/step - loss: 0.8470 - categorical_accuracy: 0.6864 - f1_score: 0.6294 - val_loss: 1.0097 - val_categorical_accuracy: 0.6329 - val_f1_score: 0.6004 - lr: 4.0000e-05
# Epoch 48: early stopping

# %%
results = inital_model.evaluate([test_input_ids, test_attention_masks], test_labels)
print('Test accuracy:', results)
# Out:
# 62/62 [==============================] - 7s 112ms/step - loss: 1.0444 - categorical_accuracy: 0.5879 - f1_score: 0.3795
# Test accuracy: [1.0444172620773315, 0.5879345536231995, 0.3794795572757721]

# %%
# Get model predictions
predictions = inital_model.predict([test_input_ids, test_attention_masks])

# Convert predictions to class labels
predicted_labels = np.argmax(predictions, axis=1)

# Assuming test_labels are one-hot encoded, convert them to class labels
true_labels = np.argmax(test_labels, axis=1)

# Generate classification report
report = classification_report(true_labels, predicted_labels)
print(report)
# Out:
# 62/62 [==============================] - 8s 72ms/step
#               precision    recall  f1-score   support
#
#            0       0.64      0.75      0.69      1014
#            1       0.66      0.31      0.42       452
#            2       0.45      0.51      0.48       490
#
#     accuracy                           0.59      1956
#    macro avg       0.58      0.52      0.53      1956
# weighted avg       0.60      0.59      0.57      1956

# %%
def load_classification_rp_per_target(model):
    targets = test_df.Target.unique()
    metrics_df = pd.DataFrame()
    for target in targets:
        extracted_df = test_df[test_df['Target'] == target]
        input_ids, attention_masks = bert_tokenize(extracted_df['processed_tweet'], extracted_df['Target'].to_list())
        labels = categorized_label(extracted_df, "Stance")

        # Convert one-hot encoded labels to single integer class labels
        true_labels = np.argmax(labels, axis=1)

        # Get model predictions
        predictions = model.predict([input_ids, attention_masks])

        # Convert predictions to class labels
        predicted_labels = np.argmax(predictions, axis=1)

        # Generate a classification report
        report = classification_report(true_labels, predicted_labels, target_names=['AGAINST', 'FAVOR', 'NONE'])
        target_name = ""
        if target == 0:
            target_name = "Hillary Clinton"
        if target == 1:
            target_name = "Legalization of Abortion"
        if target == 2:
            target_name = "Atheism"
        if target == 3:
            target_name = "Climate Change is a Real Concern"
        if target == 4:
            target_name = "Feminist Movement"
        if target == 5:
            target_name = "Donald Trump"

        print('Target: ', target_name)
        print(report)
        print("-----------------------------------------", "\n")

        # Flatten the report into a single row and add target name
        report = classification_report(true_labels, predicted_labels, target_names=['AGAINST', 'FAVOR', 'NONE'], output_dict=True)

        # Extract weighted f1, macro f1, and accuracy
        report_data = {
            'Target': target_name,
            'Weighted F1': report['weighted avg']['f1-score'],
            'Macro F1': report['macro avg']['f1-score'],
            'Accuracy': report['accuracy']
        }

        # Append to the DataFrame
        metrics_df = metrics_df.append(report_data, ignore_index=True)
    metrics_df.set_index('Target', inplace=True)

    return metrics_df

# %%
# Use the function to get the metrics DataFrame
model_metrics_df = load_classification_rp_per_target(inital_model)
model_metrics_df
# Out:
# 7/7 [==============================] - 1s 142ms/step
# Target:  Atheism
#               precision    recall  f1-score   support
#
#      AGAINST       0.78      0.90      0.84       160
#        FAVOR       0.67      0.19      0.29        32
#         NONE       0.37      0.36      0.36        28
#
#     accuracy                           0.73       220
#    macro avg       0.61      0.48      0.50       220
# weighted avg       0.71      0.73      0.70       220
#
# -----------------------------------------
# <ipython-input-17-7822421f7f5a>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 6/6 [==============================] - 1s 154ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# <ipython-input-17-7822421f7f5a>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# Target:  Climate Change is a Real Concern
#               precision    recall  f1-score   support
#
#      AGAINST       0.00      0.00      0.00        11
#        FAVOR       0.87      0.85      0.86       123
#         NONE       0.57      0.80      0.67        35
#
#     accuracy                           0.78       169
#    macro avg       0.48      0.55      0.51       169
# weighted avg       0.75      0.78      0.76       169
#
# -----------------------------------------
#
# 9/9 [==============================] - 1s 155ms/step
# Target:  Feminist Movement
#               precision    recall  f1-score   support
#
#      AGAINST       0.73      0.76      0.74       183
#        FAVOR       0.29      0.28      0.28        58
#         NONE       0.58      0.50      0.54        44
#
#     accuracy                           0.62       285
#    macro avg       0.53      0.51      0.52       285
# weighted avg       0.61      0.62      0.62       285
#
# -----------------------------------------
# <ipython-input-17-7822421f7f5a>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 10/10 [==============================] - 1s 103ms/step
# Target:  Hillary Clinton
#               precision    recall  f1-score   support
#
#      AGAINST       0.63      0.91      0.74       172
#        FAVOR       0.33      0.04      0.08        45
#         NONE       0.51      0.26      0.34        78
#
#     accuracy                           0.61       295
#    macro avg       0.49      0.40      0.39       295
# weighted avg       0.55      0.61      0.54       295
#
# -----------------------------------------
# <ipython-input-17-7822421f7f5a>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 9/9 [==============================] - 1s 146ms/step
# Target:  Legalization of Abortion
#               precision    recall  f1-score   support
#
#      AGAINST       0.77      0.79      0.78       189
#        FAVOR       0.60      0.26      0.36        46
#         NONE       0.43      0.64      0.52        45
#
#     accuracy                           0.68       280
#    macro avg       0.60      0.56      0.55       280
# weighted avg       0.69      0.68      0.67       280
#
# -----------------------------------------
# <ipython-input-17-7822421f7f5a>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 23/23 [==============================] - 3s 110ms/step
# Target:  Donald Trump
#               precision    recall  f1-score   support
#
#      AGAINST       0.46      0.57      0.51       299
#        FAVOR       0.00      0.00      0.00       148
#         NONE       0.42      0.54      0.48       260
#
#     accuracy                           0.44       707
#    macro avg       0.29      0.37      0.33       707
# weighted avg       0.35      0.44      0.39       707
#
# -----------------------------------------
# <ipython-input-17-7822421f7f5a>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
#                                   Weighted F1  Macro F1  Accuracy
# Target
# Atheism                              0.697733  0.497843  0.727273
# Climate Change is a Real Concern     0.761049  0.507545  0.781065
# Feminist Movement                    0.617253  0.520201  0.621053
# Hillary Clinton                      0.536194  0.388129  0.606780
# Legalization of Abortion             0.669538  0.553866  0.678571
# Donald Trump                         0.390116  0.328159  0.441301

# %% [markdown]
# [4] Fine Tune

# %%
for layer in inital_model.layers:
    layer.trainable = True
   # Tuning the learning rate for the optimizer
inital_model.compile(optimizer=tf.keras.optimizers.legacy.Adam(1e-5),
                  loss='categorical_crossentropy',
                  metrics=['categorical_accuracy', f1_score])

history['fine_tuned_bert'] = inital_model.fit([train_input_ids, train_attention_masks], train_labels,
                    epochs=100,
                    validation_data=([val_input_ids, val_attention_masks], val_labels),
                    batch_size=32,
                    callbacks=callbacks,
                    shuffle = True)
# Out:
# Epoch 1/100
# WARNING:tensorflow:Gradients do not exist for variables ['tf_roberta_model_1/roberta/pooler/dense/kernel:0', 'tf_roberta_model_1/roberta/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['tf_roberta_model_1/roberta/pooler/dense/kernel:0', 'tf_roberta_model_1/roberta/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 73/73 [==============================] - ETA: 0s - loss: 0.8947 - categorical_accuracy: 0.6508 - f1_score: 0.5822
# Epoch 1: saving model to roberta_best_model.h5
# 73/73 [==============================] - 74s 575ms/step - loss: 0.8947 - categorical_accuracy: 0.6508 - f1_score: 0.5822 - val_loss: 1.0040 - val_categorical_accuracy: 0.6621 - val_f1_score: 0.6142 - lr: 1.0000e-05
# Epoch 2/100
# 73/73 [==============================] - ETA: 0s - loss: 0.8332 - categorical_accuracy: 0.6984 - f1_score: 0.6555
# Epoch 2: saving model to roberta_best_model.h5
# 73/73 [==============================] - 34s 463ms/step - loss: 0.8332 - categorical_accuracy: 0.6984 - f1_score: 0.6555 - val_loss: 1.0571 - val_categorical_accuracy: 0.6552 - val_f1_score: 0.5937 - lr: 1.0000e-05
# Epoch 3/100
# 73/73 [==============================] - ETA: 0s - loss: 0.7577 - categorical_accuracy: 0.7246 - f1_score: 0.6811
# Epoch 3: saving model to roberta_best_model.h5
# 73/73 [==============================] - 33s 460ms/step - loss: 0.7577 - categorical_accuracy: 0.7246 - f1_score: 0.6811 - val_loss: 1.1558 - val_categorical_accuracy: 0.6775 - val_f1_score: 0.6356 - lr: 1.0000e-05
# Epoch 4/100
# 73/73 [==============================] - ETA: 0s - loss: 0.7022 - categorical_accuracy: 0.7568 - f1_score: 0.7245
# Epoch 4: saving model to roberta_best_model.h5
# 73/73 [==============================] - 34s 465ms/step - loss: 0.7022 - categorical_accuracy: 0.7568 - f1_score: 0.7245 - val_loss: 1.1150 - val_categorical_accuracy: 0.6690 - val_f1_score: 0.6308 - lr: 1.0000e-05
# Epoch 5/100
# 73/73 [==============================] - ETA: 0s - loss: 0.6273 - categorical_accuracy: 0.7945 - f1_score: 0.7691
# Epoch 5: saving model to roberta_best_model.h5
# 73/73 [==============================] - 34s 460ms/step - loss: 0.6273 - categorical_accuracy: 0.7945 - f1_score: 0.7691 - val_loss: 1.3350 - val_categorical_accuracy: 0.6638 - val_f1_score: 0.6211 - lr: 1.0000e-05
# Epoch 6/100
# 73/73 [==============================] - ETA: 0s - loss: 0.5679 - categorical_accuracy: 0.8245 - f1_score: 0.8058
# Epoch 6: saving model to roberta_best_model.h5
# 73/73 [==============================] - 45s 615ms/step - loss: 0.5679 - categorical_accuracy: 0.8245 - f1_score: 0.8058 - val_loss: 1.3437 - val_categorical_accuracy: 0.6758 - val_f1_score: 0.6308 - lr: 1.0000e-05
# Epoch 7/100
# 73/73 [==============================] - ETA: 0s - loss: 0.4989 - categorical_accuracy: 0.8447 - f1_score: 0.8284
# Epoch 7: saving model to roberta_best_model.h5
# 73/73 [==============================] - 34s 469ms/step - loss: 0.4989 - categorical_accuracy: 0.8447 - f1_score: 0.8284 - val_loss: 1.4950 - val_categorical_accuracy: 0.6381 - val_f1_score: 0.6108 - lr: 1.0000e-05
# Epoch 8/100
# 73/73 [==============================] - ETA: 0s - loss: 0.4537 - categorical_accuracy: 0.8670 - f1_score: 0.8527
# Epoch 8: saving model to roberta_best_model.h5
# 73/73 [==============================] - 34s 466ms/step - loss: 0.4537 - categorical_accuracy: 0.8670 - f1_score: 0.8527 - val_loss: 1.6134 - val_categorical_accuracy: 0.6604 - val_f1_score: 0.6132 - lr: 1.0000e-05
# Epoch 9/100
# 73/73 [==============================] - ETA: 0s - loss: 0.4326 - categorical_accuracy: 0.8902 - f1_score: 0.8767
# Epoch 9: saving model to roberta_best_model.h5
# 73/73 [==============================] - 34s 462ms/step - loss: 0.4326 - categorical_accuracy: 0.8902 - f1_score: 0.8767 - val_loss: 1.6096 - val_categorical_accuracy: 0.6569 - val_f1_score: 0.6117 - lr: 1.0000e-05
# Epoch 10/100
# 73/73 [==============================] - ETA: 0s - loss: 0.3862 - categorical_accuracy: 0.9133 - f1_score: 0.9035
# Epoch 10: saving model to roberta_best_model.h5
# 73/73 [==============================] - 34s 465ms/step - loss: 0.3862 - categorical_accuracy: 0.9133 - f1_score: 0.9035 - val_loss: 1.8125 - val_categorical_accuracy: 0.6878 - val_f1_score: 0.6535 - lr: 1.0000e-05
# Epoch 11/100
# 73/73 [==============================] - ETA: 0s - loss: 0.3535 - categorical_accuracy: 0.9219 - f1_score: 0.9135Restoring model weights from the end of the best epoch: 1.
#
# Epoch 11: saving model to roberta_best_model.h5
# 73/73 [==============================] - 42s 572ms/step - loss: 0.3535 - categorical_accuracy: 0.9219 - f1_score: 0.9135 - val_loss: 1.7684 - val_categorical_accuracy: 0.6792 - val_f1_score: 0.6289 - lr: 1.0000e-05
# Epoch 11: early stopping

# %%
# Use the function to get the metrics DataFrame
model_metrics_df = load_classification_rp_per_target(inital_model)
model_metrics_df
# Out:
# 7/7 [==============================] - 4s 101ms/step
# Target:  Atheism
#               precision    recall  f1-score   support
#
#      AGAINST       0.85      0.87      0.86       160
#        FAVOR       0.77      0.31      0.44        32
#         NONE       0.44      0.68      0.54        28
#
#     accuracy                           0.76       220
#    macro avg       0.69      0.62      0.61       220
# weighted avg       0.78      0.76      0.76       220
#
# -----------------------------------------
# <ipython-input-17-7822421f7f5a>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 6/6 [==============================] - 1s 93ms/step
# Target:  Climate Change is a Real Concern
#               precision    recall  f1-score   support
#
#      AGAINST       0.00      0.00      0.00        11
#        FAVOR       0.88      0.82      0.85       123
#         NONE       0.56      0.86      0.67        35
#
#     accuracy                           0.78       169
#    macro avg       0.48      0.56      0.51       169
# weighted avg       0.75      0.78      0.76       169
#
# -----------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# <ipython-input-17-7822421f7f5a>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 9/9 [==============================] - 1s 97ms/step
# Target:  Feminist Movement
#               precision    recall  f1-score   support
#
#      AGAINST       0.73      0.66      0.69       183
#        FAVOR       0.31      0.38      0.34        58
#         NONE       0.49      0.57      0.53        44
#
#     accuracy                           0.59       285
#    macro avg       0.51      0.53      0.52       285
# weighted avg       0.61      0.59      0.60       285
#
# -----------------------------------------
# <ipython-input-17-7822421f7f5a>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 10/10 [==============================] - 1s 98ms/step
# Target:  Hillary Clinton
#               precision    recall  f1-score   support
#
#      AGAINST       0.70      0.77      0.73       172
#        FAVOR       0.36      0.27      0.31        45
#         NONE       0.54      0.51      0.53        78
#
#     accuracy                           0.62       295
#    macro avg       0.54      0.52      0.52       295
# weighted avg       0.61      0.62      0.61       295
#
# -----------------------------------------
# <ipython-input-17-7822421f7f5a>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 9/9 [==============================] - 1s 72ms/step
# Target:  Legalization of Abortion
#               precision    recall  f1-score   support
#
#      AGAINST       0.81      0.73      0.77       189
#        FAVOR       0.38      0.41      0.40        46
#         NONE       0.48      0.64      0.55        45
#
#     accuracy                           0.66       280
#    macro avg       0.56      0.60      0.57       280
# weighted avg       0.69      0.66      0.67       280
#
# -----------------------------------------
# <ipython-input-17-7822421f7f5a>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 23/23 [==============================] - 2s 72ms/step
# Target:  Donald Trump
#               precision    recall  f1-score   support
#
#      AGAINST       0.50      0.45      0.47       299
#        FAVOR       0.53      0.11      0.19       148
#         NONE       0.45      0.71      0.55       260
#
#     accuracy                           0.47       707
#    macro avg       0.49      0.42      0.40       707
# weighted avg       0.49      0.47      0.44       707
#
# -----------------------------------------
# <ipython-input-17-7822421f7f5a>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
#                                   Weighted F1  Macro F1  Accuracy
# Target
# Atheism                              0.756782  0.612560  0.763636
# Climate Change is a Real Concern     0.757340  0.507632  0.775148
# Feminist Movement                    0.595319  0.520569  0.585965
# Hillary Clinton                      0.613668  0.522447  0.623729
# Legalization of Abortion             0.672747  0.572339  0.664286
# Donald Trump                         0.442287  0.404424  0.473833

# %%
# Get model predictions
predictions = inital_model.predict([test_input_ids, test_attention_masks])

# Convert predictions to class labels
predicted_labels = np.argmax(predictions, axis=1)

# Assuming test_labels are one-hot encoded, convert them to class labels
true_labels = np.argmax(test_labels, axis=1)

# Generate classification report
report = classification_report(true_labels, predicted_labels)
print(report)
# Out:
# 62/62 [==============================] - 4s 72ms/step
#               precision    recall  f1-score   support
#
#            0       0.69      0.65      0.67      1014
#            1       0.58      0.40      0.47       452
#            2       0.48      0.67      0.56       490
#
#     accuracy                           0.60      1956
#    macro avg       0.58      0.57      0.57      1956
# weighted avg       0.61      0.60      0.60      1956

# %%
inital_model.save('roberta_baseline_model.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
