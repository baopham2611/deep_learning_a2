# %%
# !pip install plotly
# !pip install seaborn
# !pip install matplotlib
# !pip install transformers
# !pip install tokenizers
# !pip install scikit-learn
# !pip install tensorflow
# !pip install pandas
# !pip install numpy
# !pip install keras_tuner


# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# #
# <a id="data-prep"></a>
# <div style="background-color: #000D5B; color: white; text-align: center; padding: 6px 0 22px 0">
#     <h3 style="background-color: #000D5B; color: white; text-align: left">RMIT School of Computer Science and Technology</h3>
#     <br/>
#     <h1>COSC3007: Deep Learning</h1>
#     <h2>Assignment 2: Stance Twitter Sentiment Analysis and Detection </h2>
#     <h2> [2] MODELLING AND MODEL EVALUATIONS </h2>
#
# </div>

# %% [markdown]
# # Import Libs

# %%
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, BatchNormalization, Bidirectional, Flatten
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers.legacy import Adam
from sklearn.metrics import classification_report
import numpy as np

import numpy as np

# %% [markdown]
# # [1] Load Data

# %%
train_df = pd.read_csv("./drive/MyDrive/Colab Notebooks/StanceDataset/processed_train_balanced.csv", encoding = "ISO-8859-1", engine="python").drop(columns=['Unnamed: 0'])
train_df = train_df.sample(frac=1, random_state=42).reset_index(drop=True)
train_ori = train_df.copy()

test_df = pd.read_csv("./drive/MyDrive/Colab Notebooks/StanceDataset/processed_test_balanced.csv", encoding = "ISO-8859-1", engine="python").drop(columns=['Unnamed: 0'])

# %%
print(len(train_ori))
print(len(test_df))
# Out:
# 3789
# 1956

# %% [markdown]
# # [2] Prepare label and fit data

# %% [markdown]
# ## Split test and val

# %%
train_df, val_df = train_test_split(train_df, test_size=0.2, random_state=42, shuffle=True)

# %% [markdown]
# ## Tweets

# %%
from transformers import TFRobertaModel, RobertaTokenizer
import numpy as np

# Initialize the BERT tokenizer
MAX_LENGTH = 512
tokenizer = RobertaTokenizer.from_pretrained('roberta-base')
roberta_model = TFRobertaModel.from_pretrained('roberta-base')

# Assuming train_texts, val_texts, test_texts are your datasets
train_processed_tweets = train_df['Tweet'].tolist()
val_processed_tweets = val_df['Tweet'].tolist()
test_processed_tweets = test_df['Tweet'].tolist()

all_processed_tweets = train_processed_tweets + val_processed_tweets + test_processed_tweets
tokenized_tweets = [tokenizer.encode(tweet, add_special_tokens=True) for tweet in all_processed_tweets]
MAX_LENGTH = max(len(tweet) for tweet in tokenized_tweets)
MAX_LENGTH = 128

print("Maximum length across all datasets:", MAX_LENGTH)

target_names = {
    0: "Hillary Clinton",
    1: "Legalization of Abortion",
    2: "Atheism",
    3: "Climate Change is a Real Concern",
    4: "Feminist Movement",
    5: "Donald Trump",
    6: "Joe Biden",
    7: "Barack Obama",
    8: "Kamala Harris",
    9: "Bernie Sanders",
    10: "Vu",
}

def bert_tokenize(texts, targets, max_length=MAX_LENGTH):
    input_ids = []
    attention_masks = []

    for idx, text in enumerate(texts):
        targetID = targets[idx]
        target_name = target_names.get(targetID, "")
        formatted_text = f"<s> {target_name} </s></s> {text} </s>"
        encoded = tokenizer.encode_plus(
            formatted_text,
            add_special_tokens=True,
            max_length=max_length,
            truncation=True,
            padding='max_length',
            return_attention_mask=True,
            return_tensors='tf',
        )

        # Flatten the tensors and remove the extra dimension
        input_ids.append(tf.squeeze(encoded['input_ids'], axis=0))
        attention_masks.append(tf.squeeze(encoded['attention_mask'], axis=0))

    return np.array(input_ids), np.array(attention_masks)

# Assuming you have lists of preprocessed texts for training, validation, and test sets
train_input_ids, train_attention_masks = bert_tokenize(train_df['Tweet'],  train_df['Target'].to_list())
val_input_ids, val_attention_masks = bert_tokenize(val_df['Tweet'], val_df['Target'].to_list())
test_input_ids, test_attention_masks = bert_tokenize(test_df['Tweet'], test_df['Target'].to_list())

print(train_input_ids.shape)
print(val_input_ids.shape)
print(test_input_ids.shape)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:72: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFRobertaModel: ['lm_head.layer_norm.bias', 'lm_head.dense.bias', 'roberta.embeddings.position_ids', 'lm_head.dense.weight', 'lm_head.bias', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing TFRobertaModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFRobertaModel were not initialized from the PyTorch model and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Token indices sequence length is longer than the specified maximum sequence length for this model (677 > 512). Running this sequence through the model will result in indexing errors
# Maximum length across all datasets: 128
# (3031, 128)
# (758, 128)
# (1956, 128)

# %% [markdown]
# ## Stances

# %%
def categorized_label(df, label_name):
    label_encoder = LabelEncoder()
    encoded_labels = label_encoder.fit_transform(df[label_name])
    categorical_labels = to_categorical(encoded_labels)
    return categorical_labels

# %%
train_labels = categorized_label(train_df, "Stance")
test_labels = categorized_label(test_df, "Stance")
val_labels = categorized_label(val_df, "Stance")

# %% [markdown]
# # [3] Create Model

# %%
from keras import backend as K
from tensorflow.keras.optimizers.legacy import Adam
from hyperopt import hp
from hyperopt import hp, fmin, tpe, STATUS_OK, Trials
# import keras_tuner as kt

# %%
def f1_score_class(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))

    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    return 2 * ((precision * recall) / (precision + recall + K.epsilon()))

def f1_score(y_true, y_pred):
    # Convert predictions to one-hot format
    y_pred_one_hot = K.one_hot(K.argmax(y_pred), num_classes=3)

    # Calculate F1 score for each class
    f1s = [f1_score_class(y_true[:, i], y_pred_one_hot[:, i]) for i in range(3)]

    # Average F1 scores across all classes
    return K.mean(K.stack(f1s), axis=0)

# %% [markdown]
# Set up call backs and learning rates

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint


# Define the EarlyStopping and ReduceLROnPlateau callbacks
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=10,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=5,
    min_lr=1e-5,
    verbose=1,
)

# Define the ModelCheckpoint callback
checkpoint_path = "roberta_best_model.h5"
model_checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_path,
    save_weights_only=True,    # Only save a model if 'val_loss' has improved
    monitor='val_loss',     # Monitor 'val_loss' during training
    mode='min',             # The model is saved when 'val_loss' is minimized
    verbose=1)

# Combine all callbacks in a list
callbacks = [
    early_stopping,
    lr_scheduler,
    model_checkpoint_callback
]

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, BatchNormalization, Bidirectional, Flatten, Input, GlobalMaxPooling1D
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers.legacy import Adam
# import keras_tuner as kt
from transformers import TFRobertaModel

def build_model(drop, regr, lr):
    bert_model = TFRobertaModel.from_pretrained('roberta-base')
    bert_model.trainable = False

    # Define model input (BERT expects two inputs: input_ids and attention_mask)
    input_ids = Input(shape=(MAX_LENGTH,), dtype=tf.int32, name='input_ids')
    attention_mask = Input(shape=(MAX_LENGTH,), dtype=tf.int32, name='attention_mask')

    # Get BERT embeddings
    bert_output = bert_model(input_ids, attention_mask=attention_mask)[0]  # Use the pooled output here

    # Tuning the number of units in the first biLSTM layer
    x = Bidirectional(LSTM(units=64,  dropout=drop, recurrent_dropout=drop,return_sequences=True,kernel_regularizer=tf.keras.regularizers.l2(regr))) (bert_output)

    # x = Bidirectional(LSTM(units=64,  dropout=drop, return_sequences=True,kernel_regularizer=tf.keras.regularizers.l2(regr))) (bert_output)

    x = GlobalMaxPooling1D()(x)

    # Dense layer with tunable units
    x = Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(regr)) (x)

    # Tunable dropout rate for the second layer
    x = Dropout(drop)(x)

    # Final Layer
    x = Dense(3, activation='softmax')(x)

    # Tuning the learning rate for the optimizer
    optimizer = Adam(learning_rate=lr)
    model = Model(inputs=[input_ids, attention_mask], outputs=x)
    model.compile(loss='CategoricalCrossentropy', optimizer=optimizer, metrics=['categorical_accuracy',f1_score])
    model.summary()

    return model

# %% [markdown]
# Recreate the best model with more training time

# %%
history = {}
inital_model = build_model(0.8, 0.0005, 0.001)
history['tuned_stance_model_custom'] = inital_model.fit([train_input_ids, train_attention_masks], train_labels,
                    epochs=100,
                    validation_data=([val_input_ids, val_attention_masks], val_labels),
                    batch_size=128,
                    callbacks=callbacks,
                    shuffle = True)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:72: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFRobertaModel: ['lm_head.layer_norm.bias', 'lm_head.dense.bias', 'roberta.embeddings.position_ids', 'lm_head.dense.weight', 'lm_head.bias', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing TFRobertaModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFRobertaModel were not initialized from the PyTorch model and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_ids (InputLayer)      [(None, 128)]                0         []
#
#  attention_mask (InputLayer  [(None, 128)]                0         []
#  )
#
#  tf_roberta_model_1 (TFRobe  TFBaseModelOutputWithPooli   1246456   ['input_ids[0][0]',
#  rtaModel)                   ngAndCrossAttentions(last_   32         'attention_mask[0][0]']
#                              hidden_state=(None, 128, 7
#                              68),
#                               pooler_output=(None, 768)
#                              , past_key_values=None, hi
#                              dden_states=None, attentio
#                              ns=None, cross_attentions=
#                              None)
#
#  bidirectional (Bidirection  (None, 128, 128)             426496    ['tf_roberta_model_1[0][0]']
#  al)
#
#  global_max_pooling1d (Glob  (None, 128)                  0         ['bidirectional[0][0]']
#  alMaxPooling1D)
#
#  dense (Dense)               (None, 128)                  16512     ['global_max_pooling1d[0][0]']
#
#  dropout_74 (Dropout)        (None, 128)                  0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 3)                    387       ['dropout_74[0][0]']
#
# ==================================================================================================
# Total params: 125089027 (477.18 MB)
# Trainable params: 443395 (1.69 MB)
# Non-trainable params: 124645632 (475.49 MB)
# __________________________________________________________________________________________________
# Epoch 1/100
# 24/24 [==============================] - ETA: 0s - loss: 1.6141 - categorical_accuracy: 0.3929 - f1_score: 0.3269
# Epoch 1: saving model to roberta_best_model.h5
# 24/24 [==============================] - 59s 1s/step - loss: 1.6141 - categorical_accuracy: 0.3929 - f1_score: 0.3269 - val_loss: 1.5209 - val_categorical_accuracy: 0.2836 - val_f1_score: 0.1486 - lr: 0.0010
# Epoch 2/100
# 24/24 [==============================] - ETA: 0s - loss: 1.4746 - categorical_accuracy: 0.4437 - f1_score: 0.2558
# Epoch 2: saving model to roberta_best_model.h5
# 24/24 [==============================] - 32s 1s/step - loss: 1.4746 - categorical_accuracy: 0.4437 - f1_score: 0.2558 - val_loss: 1.4773 - val_categorical_accuracy: 0.2836 - val_f1_score: 0.1484 - lr: 0.0010
# Epoch 3/100
# 24/24 [==============================] - ETA: 0s - loss: 1.4273 - categorical_accuracy: 0.4579 - f1_score: 0.2483
# Epoch 3: saving model to roberta_best_model.h5
# 24/24 [==============================] - 31s 1s/step - loss: 1.4273 - categorical_accuracy: 0.4579 - f1_score: 0.2483 - val_loss: 1.4431 - val_categorical_accuracy: 0.2836 - val_f1_score: 0.1484 - lr: 0.0010
# Epoch 4/100
# 24/24 [==============================] - ETA: 0s - loss: 1.3880 - categorical_accuracy: 0.4536 - f1_score: 0.2544
# Epoch 4: saving model to roberta_best_model.h5
# 24/24 [==============================] - 37s 2s/step - loss: 1.3880 - categorical_accuracy: 0.4536 - f1_score: 0.2544 - val_loss: 1.3949 - val_categorical_accuracy: 0.2942 - val_f1_score: 0.1646 - lr: 0.0010
# Epoch 5/100
# 24/24 [==============================] - ETA: 0s - loss: 1.3457 - categorical_accuracy: 0.4682 - f1_score: 0.2751
# Epoch 5: saving model to roberta_best_model.h5
# 24/24 [==============================] - 33s 1s/step - loss: 1.3457 - categorical_accuracy: 0.4682 - f1_score: 0.2751 - val_loss: 1.3463 - val_categorical_accuracy: 0.4248 - val_f1_score: 0.3235 - lr: 0.0010
# Epoch 6/100
# 24/24 [==============================] - ETA: 0s - loss: 1.3070 - categorical_accuracy: 0.4652 - f1_score: 0.2819
# Epoch 6: saving model to roberta_best_model.h5
# 24/24 [==============================] - 32s 1s/step - loss: 1.3070 - categorical_accuracy: 0.4652 - f1_score: 0.2819 - val_loss: 1.3141 - val_categorical_accuracy: 0.5224 - val_f1_score: 0.3852 - lr: 0.0010
# Epoch 7/100
# 24/24 [==============================] - ETA: 0s - loss: 1.2789 - categorical_accuracy: 0.4790 - f1_score: 0.3021
# Epoch 7: saving model to roberta_best_model.h5
# 24/24 [==============================] - 31s 1s/step - loss: 1.2789 - categorical_accuracy: 0.4790 - f1_score: 0.3021 - val_loss: 1.2561 - val_categorical_accuracy: 0.5356 - val_f1_score: 0.3535 - lr: 0.0010
# Epoch 8/100
# 24/24 [==============================] - ETA: 0s - loss: 1.2469 - categorical_accuracy: 0.4833 - f1_score: 0.3284
# Epoch 8: saving model to roberta_best_model.h5
# 24/24 [==============================] - 30s 1s/step - loss: 1.2469 - categorical_accuracy: 0.4833 - f1_score: 0.3284 - val_loss: 1.2144 - val_categorical_accuracy: 0.5330 - val_f1_score: 0.3475 - lr: 0.0010
# Epoch 9/100
# 24/24 [==============================] - ETA: 0s - loss: 1.2153 - categorical_accuracy: 0.4913 - f1_score: 0.3475
# Epoch 9: saving model to roberta_best_model.h5
# 24/24 [==============================] - 31s 1s/step - loss: 1.2153 - categorical_accuracy: 0.4913 - f1_score: 0.3475 - val_loss: 1.2020 - val_categorical_accuracy: 0.5264 - val_f1_score: 0.3715 - lr: 0.0010
# Epoch 10/100
# 24/24 [==============================] - ETA: 0s - loss: 1.1964 - categorical_accuracy: 0.5061 - f1_score: 0.3803
# Epoch 10: saving model to roberta_best_model.h5
# 24/24 [==============================] - 32s 1s/step - loss: 1.1964 - categorical_accuracy: 0.5061 - f1_score: 0.3803 - val_loss: 1.1617 - val_categorical_accuracy: 0.5409 - val_f1_score: 0.3835 - lr: 0.0010
# Epoch 11/100
# 24/24 [==============================] - ETA: 0s - loss: 1.1700 - categorical_accuracy: 0.5045 - f1_score: 0.3857
# Epoch 11: saving model to roberta_best_model.h5
# 24/24 [==============================] - 35s 1s/step - loss: 1.1700 - categorical_accuracy: 0.5045 - f1_score: 0.3857 - val_loss: 1.1229 - val_categorical_accuracy: 0.5475 - val_f1_score: 0.4012 - lr: 0.0010
# Epoch 12/100
# 24/24 [==============================] - ETA: 0s - loss: 1.1475 - categorical_accuracy: 0.5120 - f1_score: 0.4103
# Epoch 12: saving model to roberta_best_model.h5
# 24/24 [==============================] - 31s 1s/step - loss: 1.1475 - categorical_accuracy: 0.5120 - f1_score: 0.4103 - val_loss: 1.1037 - val_categorical_accuracy: 0.5435 - val_f1_score: 0.4255 - lr: 0.0010
# Epoch 13/100
# 24/24 [==============================] - ETA: 0s - loss: 1.1388 - categorical_accuracy: 0.5101 - f1_score: 0.3957
# Epoch 13: saving model to roberta_best_model.h5
# 24/24 [==============================] - 31s 1s/step - loss: 1.1388 - categorical_accuracy: 0.5101 - f1_score: 0.3957 - val_loss: 1.0913 - val_categorical_accuracy: 0.5501 - val_f1_score: 0.4291 - lr: 0.0010
# Epoch 14/100
# 24/24 [==============================] - ETA: 0s - loss: 1.1281 - categorical_accuracy: 0.5216 - f1_score: 0.4344
# Epoch 14: saving model to roberta_best_model.h5
# 24/24 [==============================] - 30s 1s/step - loss: 1.1281 - categorical_accuracy: 0.5216 - f1_score: 0.4344 - val_loss: 1.0787 - val_categorical_accuracy: 0.5607 - val_f1_score: 0.4505 - lr: 0.0010
# Epoch 15/100
# 24/24 [==============================] - ETA: 0s - loss: 1.1184 - categorical_accuracy: 0.5203 - f1_score: 0.4180
# Epoch 15: saving model to roberta_best_model.h5
# 24/24 [==============================] - 30s 1s/step - loss: 1.1184 - categorical_accuracy: 0.5203 - f1_score: 0.4180 - val_loss: 1.1229 - val_categorical_accuracy: 0.5145 - val_f1_score: 0.4911 - lr: 0.0010
# Epoch 16/100
# 24/24 [==============================] - ETA: 0s - loss: 1.1078 - categorical_accuracy: 0.5180 - f1_score: 0.4170
# Epoch 16: saving model to roberta_best_model.h5
# 24/24 [==============================] - 31s 1s/step - loss: 1.1078 - categorical_accuracy: 0.5180 - f1_score: 0.4170 - val_loss: 1.0492 - val_categorical_accuracy: 0.5752 - val_f1_score: 0.4955 - lr: 0.0010
# Epoch 17/100
# 24/24 [==============================] - ETA: 0s - loss: 1.0857 - categorical_accuracy: 0.5282 - f1_score: 0.4460
# Epoch 17: saving model to roberta_best_model.h5
# 24/24 [==============================] - 31s 1s/step - loss: 1.0857 - categorical_accuracy: 0.5282 - f1_score: 0.4460 - val_loss: 1.0635 - val_categorical_accuracy: 0.5580 - val_f1_score: 0.4475 - lr: 0.0010
# Epoch 18/100
# 24/24 [==============================] - ETA: 0s - loss: 1.0791 - categorical_accuracy: 0.5388 - f1_score: 0.4556
# Epoch 18: saving model to roberta_best_model.h5
# 24/24 [==============================] - 30s 1s/step - loss: 1.0791 - categorical_accuracy: 0.5388 - f1_score: 0.4556 - val_loss: 1.0652 - val_categorical_accuracy: 0.5607 - val_f1_score: 0.4606 - lr: 0.0010
# Epoch 19/100
# 24/24 [==============================] - ETA: 0s - loss: 1.0773 - categorical_accuracy: 0.5467 - f1_score: 0.4616
# Epoch 19: saving model to roberta_best_model.h5
# 24/24 [==============================] - 31s 1s/step - loss: 1.0773 - categorical_accuracy: 0.5467 - f1_score: 0.4616 - val_loss: 1.0186 - val_categorical_accuracy: 0.6042 - val_f1_score: 0.5304 - lr: 0.0010
# Epoch 20/100
# 24/24 [==============================] - ETA: 0s - loss: 1.0496 - categorical_accuracy: 0.5605 - f1_score: 0.4925
# Epoch 20: saving model to roberta_best_model.h5
# 24/24 [==============================] - 72s 3s/step - loss: 1.0496 - categorical_accuracy: 0.5605 - f1_score: 0.4925 - val_loss: 1.0286 - val_categorical_accuracy: 0.5646 - val_f1_score: 0.4692 - lr: 0.0010
# Epoch 21/100
# 24/24 [==============================] - ETA: 0s - loss: 1.0590 - categorical_accuracy: 0.5473 - f1_score: 0.4668
# Epoch 21: saving model to roberta_best_model.h5
# 24/24 [==============================] - 31s 1s/step - loss: 1.0590 - categorical_accuracy: 0.5473 - f1_score: 0.4668 - val_loss: 1.0110 - val_categorical_accuracy: 0.5897 - val_f1_score: 0.5202 - lr: 0.0010
# Epoch 22/100
# 24/24 [==============================] - ETA: 0s - loss: 1.0467 - categorical_accuracy: 0.5536 - f1_score: 0.4771
# Epoch 22: saving model to roberta_best_model.h5
# 24/24 [==============================] - 32s 1s/step - loss: 1.0467 - categorical_accuracy: 0.5536 - f1_score: 0.4771 - val_loss: 1.0044 - val_categorical_accuracy: 0.5976 - val_f1_score: 0.5235 - lr: 0.0010
# Epoch 23/100
# 24/24 [==============================] - ETA: 0s - loss: 1.0451 - categorical_accuracy: 0.5638 - f1_score: 0.4981
# Epoch 23: saving model to roberta_best_model.h5
# 24/24 [==============================] - 31s 1s/step - loss: 1.0451 - categorical_accuracy: 0.5638 - f1_score: 0.4981 - val_loss: 0.9853 - val_categorical_accuracy: 0.6042 - val_f1_score: 0.5466 - lr: 0.0010
# Epoch 24/100
# 24/24 [==============================] - ETA: 0s - loss: 1.0382 - categorical_accuracy: 0.5668 - f1_score: 0.5020
# Epoch 24: saving model to roberta_best_model.h5
# 24/24 [==============================] - 31s 1s/step - loss: 1.0382 - categorical_accuracy: 0.5668 - f1_score: 0.5020 - val_loss: 1.0000 - val_categorical_accuracy: 0.5910 - val_f1_score: 0.5379 - lr: 0.0010
# Epoch 25/100
# 24/24 [==============================] - ETA: 0s - loss: 1.0208 - categorical_accuracy: 0.5724 - f1_score: 0.5103
# Epoch 25: saving model to roberta_best_model.h5
# 24/24 [==============================] - 32s 1s/step - loss: 1.0208 - categorical_accuracy: 0.5724 - f1_score: 0.5103 - val_loss: 0.9745 - val_categorical_accuracy: 0.6069 - val_f1_score: 0.5793 - lr: 0.0010
# Epoch 26/100
# 24/24 [==============================] - ETA: 0s - loss: 1.0102 - categorical_accuracy: 0.5876 - f1_score: 0.5369
# Epoch 26: saving model to roberta_best_model.h5
# 24/24 [==============================] - 31s 1s/step - loss: 1.0102 - categorical_accuracy: 0.5876 - f1_score: 0.5369 - val_loss: 0.9759 - val_categorical_accuracy: 0.5976 - val_f1_score: 0.4913 - lr: 0.0010
# Epoch 27/100
# 24/24 [==============================] - ETA: 0s - loss: 1.0009 - categorical_accuracy: 0.5985 - f1_score: 0.5453
# Epoch 27: saving model to roberta_best_model.h5
# 24/24 [==============================] - 31s 1s/step - loss: 1.0009 - categorical_accuracy: 0.5985 - f1_score: 0.5453 - val_loss: 0.9613 - val_categorical_accuracy: 0.6201 - val_f1_score: 0.5602 - lr: 0.0010
# Epoch 28/100
# 24/24 [==============================] - ETA: 0s - loss: 0.9836 - categorical_accuracy: 0.5965 - f1_score: 0.5404
# Epoch 28: saving model to roberta_best_model.h5
# 24/24 [==============================] - 30s 1s/step - loss: 0.9836 - categorical_accuracy: 0.5965 - f1_score: 0.5404 - val_loss: 0.9544 - val_categorical_accuracy: 0.6108 - val_f1_score: 0.5538 - lr: 0.0010
# Epoch 29/100
# 24/24 [==============================] - ETA: 0s - loss: 0.9898 - categorical_accuracy: 0.5945 - f1_score: 0.5445
# Epoch 29: saving model to roberta_best_model.h5
# 24/24 [==============================] - 30s 1s/step - loss: 0.9898 - categorical_accuracy: 0.5945 - f1_score: 0.5445 - val_loss: 0.9465 - val_categorical_accuracy: 0.6187 - val_f1_score: 0.5938 - lr: 0.0010
# Epoch 30/100
# 24/24 [==============================] - ETA: 0s - loss: 0.9808 - categorical_accuracy: 0.5919 - f1_score: 0.5462
# Epoch 30: saving model to roberta_best_model.h5
# 24/24 [==============================] - 31s 1s/step - loss: 0.9808 - categorical_accuracy: 0.5919 - f1_score: 0.5462 - val_loss: 0.9424 - val_categorical_accuracy: 0.6346 - val_f1_score: 0.6084 - lr: 0.0010
# Epoch 31/100
# 24/24 [==============================] - ETA: 0s - loss: 0.9667 - categorical_accuracy: 0.6123 - f1_score: 0.5713
# Epoch 31: saving model to roberta_best_model.h5
# 24/24 [==============================] - 31s 1s/step - loss: 0.9667 - categorical_accuracy: 0.6123 - f1_score: 0.5713 - val_loss: 0.9702 - val_categorical_accuracy: 0.5778 - val_f1_score: 0.5659 - lr: 0.0010
# Epoch 32/100
# 24/24 [==============================] - ETA: 0s - loss: 0.9727 - categorical_accuracy: 0.6051 - f1_score: 0.5495
# Epoch 32: saving model to roberta_best_model.h5
# 24/24 [==============================] - 31s 1s/step - loss: 0.9727 - categorical_accuracy: 0.6051 - f1_score: 0.5495 - val_loss: 0.9342 - val_categorical_accuracy: 0.6398 - val_f1_score: 0.6123 - lr: 0.0010
# Epoch 33/100
# 24/24 [==============================] - ETA: 0s - loss: 0.9501 - categorical_accuracy: 0.6183 - f1_score: 0.5828
# Epoch 33: saving model to roberta_best_model.h5
# 24/24 [==============================] - 37s 2s/step - loss: 0.9501 - categorical_accuracy: 0.6183 - f1_score: 0.5828 - val_loss: 0.9213 - val_categorical_accuracy: 0.6359 - val_f1_score: 0.6035 - lr: 0.0010
# Epoch 34/100
# 24/24 [==============================] - ETA: 0s - loss: 0.9630 - categorical_accuracy: 0.6107 - f1_score: 0.5707
# Epoch 34: saving model to roberta_best_model.h5
# 24/24 [==============================] - 30s 1s/step - loss: 0.9630 - categorical_accuracy: 0.6107 - f1_score: 0.5707 - val_loss: 0.9273 - val_categorical_accuracy: 0.6544 - val_f1_score: 0.6205 - lr: 0.0010
# Epoch 35/100
# 24/24 [==============================] - ETA: 0s - loss: 0.9454 - categorical_accuracy: 0.6166 - f1_score: 0.5798
# Epoch 35: saving model to roberta_best_model.h5
# 24/24 [==============================] - 31s 1s/step - loss: 0.9454 - categorical_accuracy: 0.6166 - f1_score: 0.5798 - val_loss: 0.9116 - val_categorical_accuracy: 0.6504 - val_f1_score: 0.6193 - lr: 0.0010
# Epoch 36/100
# 24/24 [==============================] - ETA: 0s - loss: 0.9436 - categorical_accuracy: 0.6219 - f1_score: 0.5765
# Epoch 36: saving model to roberta_best_model.h5
# 24/24 [==============================] - 30s 1s/step - loss: 0.9436 - categorical_accuracy: 0.6219 - f1_score: 0.5765 - val_loss: 0.9205 - val_categorical_accuracy: 0.6478 - val_f1_score: 0.6102 - lr: 0.0010
# Epoch 37/100
# 24/24 [==============================] - ETA: 0s - loss: 0.9461 - categorical_accuracy: 0.6199 - f1_score: 0.5786
# Epoch 37: saving model to roberta_best_model.h5
# 24/24 [==============================] - 32s 1s/step - loss: 0.9461 - categorical_accuracy: 0.6199 - f1_score: 0.5786 - val_loss: 0.9110 - val_categorical_accuracy: 0.6675 - val_f1_score: 0.6289 - lr: 0.0010
# Epoch 38/100
# 24/24 [==============================] - ETA: 0s - loss: 0.9373 - categorical_accuracy: 0.6272 - f1_score: 0.5846
# Epoch 38: saving model to roberta_best_model.h5
# 24/24 [==============================] - 33s 1s/step - loss: 0.9373 - categorical_accuracy: 0.6272 - f1_score: 0.5846 - val_loss: 0.9152 - val_categorical_accuracy: 0.6346 - val_f1_score: 0.5973 - lr: 0.0010
# Epoch 39/100
# 24/24 [==============================] - ETA: 0s - loss: 0.9306 - categorical_accuracy: 0.6410 - f1_score: 0.6054
# Epoch 39: saving model to roberta_best_model.h5
# 24/24 [==============================] - 37s 2s/step - loss: 0.9306 - categorical_accuracy: 0.6410 - f1_score: 0.6054 - val_loss: 0.9093 - val_categorical_accuracy: 0.6517 - val_f1_score: 0.6311 - lr: 0.0010
# Epoch 40/100
# 24/24 [==============================] - ETA: 0s - loss: 0.9370 - categorical_accuracy: 0.6344 - f1_score: 0.5979
# Epoch 40: saving model to roberta_best_model.h5
# 24/24 [==============================] - 37s 2s/step - loss: 0.9370 - categorical_accuracy: 0.6344 - f1_score: 0.5979 - val_loss: 0.8974 - val_categorical_accuracy: 0.6583 - val_f1_score: 0.6316 - lr: 0.0010
# Epoch 41/100
# 24/24 [==============================] - ETA: 0s - loss: 0.9171 - categorical_accuracy: 0.6397 - f1_score: 0.6110
# Epoch 41: saving model to roberta_best_model.h5
# 24/24 [==============================] - 30s 1s/step - loss: 0.9171 - categorical_accuracy: 0.6397 - f1_score: 0.6110 - val_loss: 0.9131 - val_categorical_accuracy: 0.6438 - val_f1_score: 0.5848 - lr: 0.0010
# Epoch 42/100
# 24/24 [==============================] - ETA: 0s - loss: 0.9283 - categorical_accuracy: 0.6298 - f1_score: 0.5980
# Epoch 42: saving model to roberta_best_model.h5
# 24/24 [==============================] - 31s 1s/step - loss: 0.9283 - categorical_accuracy: 0.6298 - f1_score: 0.5980 - val_loss: 0.8939 - val_categorical_accuracy: 0.6438 - val_f1_score: 0.6186 - lr: 0.0010
# Epoch 43/100
# 24/24 [==============================] - ETA: 0s - loss: 0.9347 - categorical_accuracy: 0.6209 - f1_score: 0.5784
# Epoch 43: saving model to roberta_best_model.h5
# 24/24 [==============================] - 31s 1s/step - loss: 0.9347 - categorical_accuracy: 0.6209 - f1_score: 0.5784 - val_loss: 0.8978 - val_categorical_accuracy: 0.6491 - val_f1_score: 0.6158 - lr: 0.0010
# Epoch 44/100
# 24/24 [==============================] - ETA: 0s - loss: 0.9271 - categorical_accuracy: 0.6443 - f1_score: 0.6073
# Epoch 44: saving model to roberta_best_model.h5
# 24/24 [==============================] - 31s 1s/step - loss: 0.9271 - categorical_accuracy: 0.6443 - f1_score: 0.6073 - val_loss: 0.9029 - val_categorical_accuracy: 0.6504 - val_f1_score: 0.6145 - lr: 0.0010
# Epoch 45/100
# 24/24 [==============================] - ETA: 0s - loss: 0.9168 - categorical_accuracy: 0.6513 - f1_score: 0.6187
# Epoch 45: saving model to roberta_best_model.h5
# 24/24 [==============================] - 31s 1s/step - loss: 0.9168 - categorical_accuracy: 0.6513 - f1_score: 0.6187 - val_loss: 0.8843 - val_categorical_accuracy: 0.6834 - val_f1_score: 0.6546 - lr: 0.0010
# Epoch 46/100
# 24/24 [==============================] - ETA: 0s - loss: 0.9088 - categorical_accuracy: 0.6463 - f1_score: 0.6145
# Epoch 46: saving model to roberta_best_model.h5
# 24/24 [==============================] - 31s 1s/step - loss: 0.9088 - categorical_accuracy: 0.6463 - f1_score: 0.6145 - val_loss: 0.9018 - val_categorical_accuracy: 0.6636 - val_f1_score: 0.6472 - lr: 0.0010
# Epoch 47/100
# 24/24 [==============================] - ETA: 0s - loss: 0.9017 - categorical_accuracy: 0.6513 - f1_score: 0.6222
# Epoch 47: saving model to roberta_best_model.h5
# 24/24 [==============================] - 32s 1s/step - loss: 0.9017 - categorical_accuracy: 0.6513 - f1_score: 0.6222 - val_loss: 0.8803 - val_categorical_accuracy: 0.6544 - val_f1_score: 0.6339 - lr: 0.0010
# Epoch 48/100
# 24/24 [==============================] - ETA: 0s - loss: 0.8941 - categorical_accuracy: 0.6513 - f1_score: 0.6215
# Epoch 48: saving model to roberta_best_model.h5
# 24/24 [==============================] - 30s 1s/step - loss: 0.8941 - categorical_accuracy: 0.6513 - f1_score: 0.6215 - val_loss: 0.8961 - val_categorical_accuracy: 0.6517 - val_f1_score: 0.6285 - lr: 0.0010
# Epoch 49/100
# 24/24 [==============================] - ETA: 0s - loss: 0.9020 - categorical_accuracy: 0.6572 - f1_score: 0.6262
# Epoch 49: saving model to roberta_best_model.h5
# 24/24 [==============================] - 30s 1s/step - loss: 0.9020 - categorical_accuracy: 0.6572 - f1_score: 0.6262 - val_loss: 0.8867 - val_categorical_accuracy: 0.6596 - val_f1_score: 0.6392 - lr: 0.0010
# Epoch 50/100
# 24/24 [==============================] - ETA: 0s - loss: 0.8997 - categorical_accuracy: 0.6473 - f1_score: 0.6174
# Epoch 50: saving model to roberta_best_model.h5
# 24/24 [==============================] - 29s 1s/step - loss: 0.8997 - categorical_accuracy: 0.6473 - f1_score: 0.6174 - val_loss: 0.8933 - val_categorical_accuracy: 0.6451 - val_f1_score: 0.6243 - lr: 0.0010
# Epoch 51/100
# 24/24 [==============================] - ETA: 0s - loss: 0.8823 - categorical_accuracy: 0.6549 - f1_score: 0.6264
# Epoch 51: saving model to roberta_best_model.h5
# 24/24 [==============================] - 29s 1s/step - loss: 0.8823 - categorical_accuracy: 0.6549 - f1_score: 0.6264 - val_loss: 0.8811 - val_categorical_accuracy: 0.6662 - val_f1_score: 0.6377 - lr: 0.0010
# Epoch 52/100
# 24/24 [==============================] - ETA: 0s - loss: 0.8799 - categorical_accuracy: 0.6519 - f1_score: 0.6274
# Epoch 52: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 52: saving model to roberta_best_model.h5
# 24/24 [==============================] - 30s 1s/step - loss: 0.8799 - categorical_accuracy: 0.6519 - f1_score: 0.6274 - val_loss: 0.9033 - val_categorical_accuracy: 0.6464 - val_f1_score: 0.6343 - lr: 0.0010
# Epoch 53/100
# 24/24 [==============================] - ETA: 0s - loss: 0.8654 - categorical_accuracy: 0.6737 - f1_score: 0.6532
# Epoch 53: saving model to roberta_best_model.h5
# 24/24 [==============================] - 30s 1s/step - loss: 0.8654 - categorical_accuracy: 0.6737 - f1_score: 0.6532 - val_loss: 0.8725 - val_categorical_accuracy: 0.6662 - val_f1_score: 0.6473 - lr: 2.0000e-04
# Epoch 54/100
# 24/24 [==============================] - ETA: 0s - loss: 0.8731 - categorical_accuracy: 0.6780 - f1_score: 0.6510
# Epoch 54: saving model to roberta_best_model.h5
# 24/24 [==============================] - 31s 1s/step - loss: 0.8731 - categorical_accuracy: 0.6780 - f1_score: 0.6510 - val_loss: 0.8754 - val_categorical_accuracy: 0.6504 - val_f1_score: 0.6345 - lr: 2.0000e-04
# Epoch 55/100
# 24/24 [==============================] - ETA: 0s - loss: 0.8578 - categorical_accuracy: 0.6727 - f1_score: 0.6530
# Epoch 55: saving model to roberta_best_model.h5
# 24/24 [==============================] - 32s 1s/step - loss: 0.8578 - categorical_accuracy: 0.6727 - f1_score: 0.6530 - val_loss: 0.8680 - val_categorical_accuracy: 0.6609 - val_f1_score: 0.6422 - lr: 2.0000e-04
# Epoch 56/100
# 24/24 [==============================] - ETA: 0s - loss: 0.8467 - categorical_accuracy: 0.6820 - f1_score: 0.6592
# Epoch 56: saving model to roberta_best_model.h5
# 24/24 [==============================] - 31s 1s/step - loss: 0.8467 - categorical_accuracy: 0.6820 - f1_score: 0.6592 - val_loss: 0.8737 - val_categorical_accuracy: 0.6662 - val_f1_score: 0.6474 - lr: 2.0000e-04
# Epoch 57/100
# 24/24 [==============================] - ETA: 0s - loss: 0.8580 - categorical_accuracy: 0.6750 - f1_score: 0.6521
# Epoch 57: saving model to roberta_best_model.h5
# 24/24 [==============================] - 31s 1s/step - loss: 0.8580 - categorical_accuracy: 0.6750 - f1_score: 0.6521 - val_loss: 0.8810 - val_categorical_accuracy: 0.6557 - val_f1_score: 0.6401 - lr: 2.0000e-04
# Epoch 58/100
# 24/24 [==============================] - ETA: 0s - loss: 0.8526 - categorical_accuracy: 0.6796 - f1_score: 0.6575
# Epoch 58: saving model to roberta_best_model.h5
# 24/24 [==============================] - 31s 1s/step - loss: 0.8526 - categorical_accuracy: 0.6796 - f1_score: 0.6575 - val_loss: 0.9020 - val_categorical_accuracy: 0.6464 - val_f1_score: 0.6321 - lr: 2.0000e-04
# Epoch 59/100
# 24/24 [==============================] - ETA: 0s - loss: 0.8549 - categorical_accuracy: 0.6777 - f1_score: 0.6471
# Epoch 59: saving model to roberta_best_model.h5
# 24/24 [==============================] - 31s 1s/step - loss: 0.8549 - categorical_accuracy: 0.6777 - f1_score: 0.6471 - val_loss: 0.8740 - val_categorical_accuracy: 0.6675 - val_f1_score: 0.6504 - lr: 2.0000e-04
# Epoch 60/100
# 24/24 [==============================] - ETA: 0s - loss: 0.8458 - categorical_accuracy: 0.6820 - f1_score: 0.6616
# Epoch 60: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 60: saving model to roberta_best_model.h5
# 24/24 [==============================] - 31s 1s/step - loss: 0.8458 - categorical_accuracy: 0.6820 - f1_score: 0.6616 - val_loss: 0.8710 - val_categorical_accuracy: 0.6557 - val_f1_score: 0.6394 - lr: 2.0000e-04
# Epoch 61/100
# 24/24 [==============================] - ETA: 0s - loss: 0.8410 - categorical_accuracy: 0.6783 - f1_score: 0.6544
# Epoch 61: saving model to roberta_best_model.h5
# 24/24 [==============================] - 30s 1s/step - loss: 0.8410 - categorical_accuracy: 0.6783 - f1_score: 0.6544 - val_loss: 0.8776 - val_categorical_accuracy: 0.6491 - val_f1_score: 0.6295 - lr: 4.0000e-05
# Epoch 62/100
# 24/24 [==============================] - ETA: 0s - loss: 0.8387 - categorical_accuracy: 0.6905 - f1_score: 0.6691
# Epoch 62: saving model to roberta_best_model.h5
# 24/24 [==============================] - 30s 1s/step - loss: 0.8387 - categorical_accuracy: 0.6905 - f1_score: 0.6691 - val_loss: 0.8680 - val_categorical_accuracy: 0.6609 - val_f1_score: 0.6420 - lr: 4.0000e-05
# Epoch 63/100
# 24/24 [==============================] - ETA: 0s - loss: 0.8422 - categorical_accuracy: 0.6829 - f1_score: 0.6604
# Epoch 63: saving model to roberta_best_model.h5
# 24/24 [==============================] - 30s 1s/step - loss: 0.8422 - categorical_accuracy: 0.6829 - f1_score: 0.6604 - val_loss: 0.8708 - val_categorical_accuracy: 0.6609 - val_f1_score: 0.6440 - lr: 4.0000e-05
# Epoch 64/100
# 24/24 [==============================] - ETA: 0s - loss: 0.8433 - categorical_accuracy: 0.6899 - f1_score: 0.6702
# Epoch 64: saving model to roberta_best_model.h5
# 24/24 [==============================] - 30s 1s/step - loss: 0.8433 - categorical_accuracy: 0.6899 - f1_score: 0.6702 - val_loss: 0.8738 - val_categorical_accuracy: 0.6544 - val_f1_score: 0.6382 - lr: 4.0000e-05
# Epoch 65/100
# 24/24 [==============================] - ETA: 0s - loss: 0.8484 - categorical_accuracy: 0.6780 - f1_score: 0.6544
# Epoch 65: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 65: saving model to roberta_best_model.h5
# 24/24 [==============================] - 31s 1s/step - loss: 0.8484 - categorical_accuracy: 0.6780 - f1_score: 0.6544 - val_loss: 0.8711 - val_categorical_accuracy: 0.6623 - val_f1_score: 0.6463 - lr: 4.0000e-05
# Epoch 66/100
# 24/24 [==============================] - ETA: 0s - loss: 0.8293 - categorical_accuracy: 0.6889 - f1_score: 0.6665
# Epoch 66: saving model to roberta_best_model.h5
# 24/24 [==============================] - 31s 1s/step - loss: 0.8293 - categorical_accuracy: 0.6889 - f1_score: 0.6665 - val_loss: 0.8742 - val_categorical_accuracy: 0.6583 - val_f1_score: 0.6419 - lr: 1.0000e-05
# Epoch 67/100
# 24/24 [==============================] - ETA: 0s - loss: 0.8411 - categorical_accuracy: 0.6846 - f1_score: 0.6656
# Epoch 67: saving model to roberta_best_model.h5
# 24/24 [==============================] - 31s 1s/step - loss: 0.8411 - categorical_accuracy: 0.6846 - f1_score: 0.6656 - val_loss: 0.8742 - val_categorical_accuracy: 0.6583 - val_f1_score: 0.6419 - lr: 1.0000e-05
# Epoch 68/100
# 24/24 [==============================] - ETA: 0s - loss: 0.8414 - categorical_accuracy: 0.6912 - f1_score: 0.6687
# Epoch 68: saving model to roberta_best_model.h5
# 24/24 [==============================] - 31s 1s/step - loss: 0.8414 - categorical_accuracy: 0.6912 - f1_score: 0.6687 - val_loss: 0.8763 - val_categorical_accuracy: 0.6544 - val_f1_score: 0.6381 - lr: 1.0000e-05
# Epoch 69/100
# 24/24 [==============================] - ETA: 0s - loss: 0.8278 - categorical_accuracy: 0.6905 - f1_score: 0.6704
# Epoch 69: saving model to roberta_best_model.h5
# 24/24 [==============================] - 31s 1s/step - loss: 0.8278 - categorical_accuracy: 0.6905 - f1_score: 0.6704 - val_loss: 0.8754 - val_categorical_accuracy: 0.6557 - val_f1_score: 0.6393 - lr: 1.0000e-05
# Epoch 70/100
# 24/24 [==============================] - ETA: 0s - loss: 0.8408 - categorical_accuracy: 0.6895 - f1_score: 0.6697
# Epoch 70: saving model to roberta_best_model.h5
# 24/24 [==============================] - 30s 1s/step - loss: 0.8408 - categorical_accuracy: 0.6895 - f1_score: 0.6697 - val_loss: 0.8762 - val_categorical_accuracy: 0.6557 - val_f1_score: 0.6391 - lr: 1.0000e-05
# Epoch 71/100
# 24/24 [==============================] - ETA: 0s - loss: 0.8196 - categorical_accuracy: 0.6872 - f1_score: 0.6691
# Epoch 71: saving model to roberta_best_model.h5
# 24/24 [==============================] - 30s 1s/step - loss: 0.8196 - categorical_accuracy: 0.6872 - f1_score: 0.6691 - val_loss: 0.8766 - val_categorical_accuracy: 0.6544 - val_f1_score: 0.6383 - lr: 1.0000e-05
# Epoch 72/100
# 24/24 [==============================] - ETA: 0s - loss: 0.8413 - categorical_accuracy: 0.6747 - f1_score: 0.6495Restoring model weights from the end of the best epoch: 62.
#
# Epoch 72: saving model to roberta_best_model.h5
# 24/24 [==============================] - 31s 1s/step - loss: 0.8413 - categorical_accuracy: 0.6747 - f1_score: 0.6495 - val_loss: 0.8775 - val_categorical_accuracy: 0.6517 - val_f1_score: 0.6355 - lr: 1.0000e-05
# Epoch 72: early stopping

# %%
results = inital_model.evaluate([test_input_ids, test_attention_masks], test_labels)
print('Test accuracy:', results)
# Out:
# 62/62 [==============================] - 11s 171ms/step - loss: 0.9431 - categorical_accuracy: 0.6028 - f1_score: 0.4612
# Test accuracy: [0.9430845975875854, 0.6027607321739197, 0.46120041608810425]

# %%
# Get model predictions
predictions = inital_model.predict([test_input_ids, test_attention_masks])

# Convert predictions to class labels
predicted_labels = np.argmax(predictions, axis=1)

# Assuming test_labels are one-hot encoded, convert them to class labels
true_labels = np.argmax(test_labels, axis=1)

# Generate classification report
report = classification_report(true_labels, predicted_labels)
print(report)
# Out:
# 62/62 [==============================] - 15s 173ms/step
#               precision    recall  f1-score   support
#
#            0       0.71      0.57      0.63      1014
#            1       0.55      0.57      0.56       452
#            2       0.51      0.70      0.59       490
#
#     accuracy                           0.60      1956
#    macro avg       0.59      0.61      0.59      1956
# weighted avg       0.62      0.60      0.61      1956

# %%
def load_classification_rp_per_target(model):
    targets = test_df.Target.unique()
    metrics_df = pd.DataFrame()
    for target in targets:
        extracted_df = test_df[test_df['Target'] == target]
        input_ids, attention_masks = bert_tokenize(extracted_df['processed_tweet'], extracted_df['Target'].to_list())
        labels = categorized_label(extracted_df, "Stance")

        # Convert one-hot encoded labels to single integer class labels
        true_labels = np.argmax(labels, axis=1)

        # Get model predictions
        predictions = model.predict([input_ids, attention_masks])

        # Convert predictions to class labels
        predicted_labels = np.argmax(predictions, axis=1)

        # Generate a classification report
        report = classification_report(true_labels, predicted_labels, target_names=['AGAINST', 'FAVOR', 'NONE'])
        target_name = ""
        if target == 0:
            target_name = "Hillary Clinton"
        if target == 1:
            target_name = "Legalization of Abortion"
        if target == 2:
            target_name = "Atheism"
        if target == 3:
            target_name = "Climate Change is a Real Concern"
        if target == 4:
            target_name = "Feminist Movement"
        if target == 5:
            target_name = "Donald Trump"

        print('Target: ', target_name)
        print(report)
        print("-----------------------------------------", "\n")

        # Flatten the report into a single row and add target name
        report = classification_report(true_labels, predicted_labels, target_names=['AGAINST', 'FAVOR', 'NONE'], output_dict=True)

        # Extract weighted f1, macro f1, and accuracy
        report_data = {
            'Target': target_name,
            'Weighted F1': report['weighted avg']['f1-score'],
            'Macro F1': report['macro avg']['f1-score'],
            'Accuracy': report['accuracy']
        }

        # Append to the DataFrame
        metrics_df = metrics_df.append(report_data, ignore_index=True)
    metrics_df.set_index('Target', inplace=True)

    return metrics_df

# %%
# Use the function to get the metrics DataFrame
model_metrics_df = load_classification_rp_per_target(inital_model)
model_metrics_df
# Out:
# 7/7 [==============================] - 1s 166ms/step
# Target:  Atheism
#               precision    recall  f1-score   support
#
#      AGAINST       0.77      0.74      0.76       160
#        FAVOR       0.28      0.25      0.26        32
#         NONE       0.33      0.43      0.38        28
#
#     accuracy                           0.63       220
#    macro avg       0.46      0.47      0.46       220
# weighted avg       0.64      0.63      0.64       220
#
# -----------------------------------------
# <ipython-input-16-7822421f7f5a>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 6/6 [==============================] - 1s 191ms/step
# Target:  Climate Change is a Real Concern
#               precision    recall  f1-score   support
#
#      AGAINST       0.00      0.00      0.00        11
#        FAVOR       0.88      0.69      0.77       123
#         NONE       0.39      0.80      0.52        35
#
#     accuracy                           0.67       169
#    macro avg       0.42      0.50      0.43       169
# weighted avg       0.72      0.67      0.67       169
#
# -----------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# <ipython-input-16-7822421f7f5a>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 9/9 [==============================] - 2s 211ms/step
# Target:  Feminist Movement
#               precision    recall  f1-score   support
#
#      AGAINST       0.72      0.63      0.67       183
#        FAVOR       0.27      0.41      0.33        58
#         NONE       0.45      0.39      0.41        44
#
#     accuracy                           0.55       285
#    macro avg       0.48      0.48      0.47       285
# weighted avg       0.59      0.55      0.56       285
#
# -----------------------------------------
# <ipython-input-16-7822421f7f5a>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 10/10 [==============================] - 2s 158ms/step
# Target:  Hillary Clinton
#               precision    recall  f1-score   support
#
#      AGAINST       0.71      0.72      0.71       172
#        FAVOR       0.29      0.38      0.33        45
#         NONE       0.40      0.32      0.35        78
#
#     accuracy                           0.56       295
#    macro avg       0.47      0.47      0.46       295
# weighted avg       0.56      0.56      0.56       295
#
# -----------------------------------------
# <ipython-input-16-7822421f7f5a>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 9/9 [==============================] - 2s 168ms/step
# Target:  Legalization of Abortion
#               precision    recall  f1-score   support
#
#      AGAINST       0.75      0.54      0.63       189
#        FAVOR       0.44      0.09      0.15        46
#         NONE       0.29      0.84      0.43        45
#
#     accuracy                           0.52       280
#    macro avg       0.49      0.49      0.40       280
# weighted avg       0.62      0.52      0.52       280
#
# -----------------------------------------
# <ipython-input-16-7822421f7f5a>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 23/23 [==============================] - 4s 163ms/step
# Target:  Donald Trump
#               precision    recall  f1-score   support
#
#      AGAINST       0.58      0.19      0.29       299
#        FAVOR       0.38      0.38      0.38       148
#         NONE       0.47      0.83      0.60       260
#
#     accuracy                           0.47       707
#    macro avg       0.48      0.47      0.42       707
# weighted avg       0.50      0.47      0.42       707
#
# -----------------------------------------
# <ipython-input-16-7822421f7f5a>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
#                                   Weighted F1  Macro F1  Accuracy
# Target
# Atheism                              0.635374  0.464284  0.631818
# Climate Change is a Real Concern     0.670788  0.432031  0.668639
# Feminist Movement                    0.562746  0.471972  0.547368
# Hillary Clinton                      0.559371  0.464859  0.559322
# Legalization of Abortion             0.517745  0.400797  0.517857
# Donald Trump                         0.424183  0.424096  0.468175

# %% [markdown]
# [4] Fine Tune

# %%
for layer in inital_model.layers:
    layer.trainable = True
   # Tuning the learning rate for the optimizer
inital_model.compile(optimizer=tf.keras.optimizers.legacy.Adam(1e-5),
                  loss='categorical_crossentropy',
                  metrics=['categorical_accuracy', f1_score])

history['fine_tuned_bert'] = inital_model.fit([train_input_ids, train_attention_masks], train_labels,
                    epochs=30,
                    validation_data=([val_input_ids, val_attention_masks], val_labels),
                    batch_size=32,
                    callbacks=callbacks,
                    shuffle = True)
# Out:
# Epoch 1/30
# WARNING:tensorflow:Gradients do not exist for variables ['tf_roberta_model_1/roberta/pooler/dense/kernel:0', 'tf_roberta_model_1/roberta/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['tf_roberta_model_1/roberta/pooler/dense/kernel:0', 'tf_roberta_model_1/roberta/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 95/95 [==============================] - ETA: 0s - loss: 0.8961 - categorical_accuracy: 0.6480 - f1_score: 0.6086
# Epoch 1: saving model to roberta_best_model.h5
# 95/95 [==============================] - 139s 1s/step - loss: 0.8961 - categorical_accuracy: 0.6480 - f1_score: 0.6086 - val_loss: 0.8335 - val_categorical_accuracy: 0.6860 - val_f1_score: 0.6607 - lr: 1.0000e-05
# Epoch 2/30
# 95/95 [==============================] - ETA: 0s - loss: 0.7742 - categorical_accuracy: 0.7212 - f1_score: 0.6871
# Epoch 2: saving model to roberta_best_model.h5
# 95/95 [==============================] - 110s 1s/step - loss: 0.7742 - categorical_accuracy: 0.7212 - f1_score: 0.6871 - val_loss: 0.8260 - val_categorical_accuracy: 0.6781 - val_f1_score: 0.6518 - lr: 1.0000e-05
# Epoch 3/30
# 95/95 [==============================] - ETA: 0s - loss: 0.7300 - categorical_accuracy: 0.7364 - f1_score: 0.7113
# Epoch 3: saving model to roberta_best_model.h5
# 95/95 [==============================] - 115s 1s/step - loss: 0.7300 - categorical_accuracy: 0.7364 - f1_score: 0.7113 - val_loss: 0.8155 - val_categorical_accuracy: 0.7111 - val_f1_score: 0.6927 - lr: 1.0000e-05
# Epoch 4/30
# 95/95 [==============================] - ETA: 0s - loss: 0.6939 - categorical_accuracy: 0.7588 - f1_score: 0.7412
# Epoch 4: saving model to roberta_best_model.h5
# 95/95 [==============================] - 112s 1s/step - loss: 0.6939 - categorical_accuracy: 0.7588 - f1_score: 0.7412 - val_loss: 0.8173 - val_categorical_accuracy: 0.7058 - val_f1_score: 0.6811 - lr: 1.0000e-05
# Epoch 5/30
# 95/95 [==============================] - ETA: 0s - loss: 0.5967 - categorical_accuracy: 0.8169 - f1_score: 0.8025
# Epoch 5: saving model to roberta_best_model.h5
# 95/95 [==============================] - 112s 1s/step - loss: 0.5967 - categorical_accuracy: 0.8169 - f1_score: 0.8025 - val_loss: 0.8027 - val_categorical_accuracy: 0.7296 - val_f1_score: 0.7043 - lr: 1.0000e-05
# Epoch 6/30
# 95/95 [==============================] - ETA: 0s - loss: 0.5302 - categorical_accuracy: 0.8406 - f1_score: 0.8275
# Epoch 6: saving model to roberta_best_model.h5
# 95/95 [==============================] - 112s 1s/step - loss: 0.5302 - categorical_accuracy: 0.8406 - f1_score: 0.8275 - val_loss: 0.8055 - val_categorical_accuracy: 0.7493 - val_f1_score: 0.7341 - lr: 1.0000e-05
# Epoch 7/30
# 95/95 [==============================] - ETA: 0s - loss: 0.4928 - categorical_accuracy: 0.8575 - f1_score: 0.8433
# Epoch 7: saving model to roberta_best_model.h5
# 95/95 [==============================] - 110s 1s/step - loss: 0.4928 - categorical_accuracy: 0.8575 - f1_score: 0.8433 - val_loss: 0.8576 - val_categorical_accuracy: 0.7388 - val_f1_score: 0.7124 - lr: 1.0000e-05
# Epoch 8/30
# 95/95 [==============================] - ETA: 0s - loss: 0.4534 - categorical_accuracy: 0.8759 - f1_score: 0.8655
# Epoch 8: saving model to roberta_best_model.h5
# 95/95 [==============================] - 110s 1s/step - loss: 0.4534 - categorical_accuracy: 0.8759 - f1_score: 0.8655 - val_loss: 0.8990 - val_categorical_accuracy: 0.7230 - val_f1_score: 0.7102 - lr: 1.0000e-05
# Epoch 9/30
# 95/95 [==============================] - ETA: 0s - loss: 0.4265 - categorical_accuracy: 0.8905 - f1_score: 0.8799
# Epoch 9: saving model to roberta_best_model.h5
# 95/95 [==============================] - 112s 1s/step - loss: 0.4265 - categorical_accuracy: 0.8905 - f1_score: 0.8799 - val_loss: 0.8332 - val_categorical_accuracy: 0.7427 - val_f1_score: 0.7263 - lr: 1.0000e-05
# Epoch 10/30
# 95/95 [==============================] - ETA: 0s - loss: 0.3481 - categorical_accuracy: 0.9172 - f1_score: 0.9107
# Epoch 10: saving model to roberta_best_model.h5
# 95/95 [==============================] - 110s 1s/step - loss: 0.3481 - categorical_accuracy: 0.9172 - f1_score: 0.9107 - val_loss: 0.9322 - val_categorical_accuracy: 0.7269 - val_f1_score: 0.7140 - lr: 1.0000e-05
# Epoch 11/30
# 95/95 [==============================] - ETA: 0s - loss: 0.3339 - categorical_accuracy: 0.9297 - f1_score: 0.9243
# Epoch 11: saving model to roberta_best_model.h5
# 95/95 [==============================] - 112s 1s/step - loss: 0.3339 - categorical_accuracy: 0.9297 - f1_score: 0.9243 - val_loss: 0.9556 - val_categorical_accuracy: 0.7309 - val_f1_score: 0.7179 - lr: 1.0000e-05
# Epoch 12/30
# 95/95 [==============================] - ETA: 0s - loss: 0.2988 - categorical_accuracy: 0.9390 - f1_score: 0.9332
# Epoch 12: saving model to roberta_best_model.h5
# 95/95 [==============================] - 110s 1s/step - loss: 0.2988 - categorical_accuracy: 0.9390 - f1_score: 0.9332 - val_loss: 0.9835 - val_categorical_accuracy: 0.7216 - val_f1_score: 0.7113 - lr: 1.0000e-05
# Epoch 13/30
# 95/95 [==============================] - ETA: 0s - loss: 0.2730 - categorical_accuracy: 0.9449 - f1_score: 0.9401
# Epoch 13: saving model to roberta_best_model.h5
# 95/95 [==============================] - 110s 1s/step - loss: 0.2730 - categorical_accuracy: 0.9449 - f1_score: 0.9401 - val_loss: 1.0630 - val_categorical_accuracy: 0.7216 - val_f1_score: 0.7116 - lr: 1.0000e-05
# Epoch 14/30
# 95/95 [==============================] - ETA: 0s - loss: 0.2709 - categorical_accuracy: 0.9535 - f1_score: 0.9480
# Epoch 14: saving model to roberta_best_model.h5
# 95/95 [==============================] - 110s 1s/step - loss: 0.2709 - categorical_accuracy: 0.9535 - f1_score: 0.9480 - val_loss: 1.0835 - val_categorical_accuracy: 0.7296 - val_f1_score: 0.7156 - lr: 1.0000e-05
# Epoch 15/30
# 95/95 [==============================] - ETA: 0s - loss: 0.2326 - categorical_accuracy: 0.9604 - f1_score: 0.9579Restoring model weights from the end of the best epoch: 5.
#
# Epoch 15: saving model to roberta_best_model.h5
# 95/95 [==============================] - 112s 1s/step - loss: 0.2326 - categorical_accuracy: 0.9604 - f1_score: 0.9579 - val_loss: 1.1296 - val_categorical_accuracy: 0.7335 - val_f1_score: 0.7105 - lr: 1.0000e-05
# Epoch 15: early stopping

# %%
# Use the function to get the metrics DataFrame
model_metrics_df = load_classification_rp_per_target(inital_model)
model_metrics_df
# Out:
# 7/7 [==============================] - 4s 169ms/step
# Target:  Atheism
#               precision    recall  f1-score   support
#
#      AGAINST       0.89      0.24      0.38       160
#        FAVOR       0.23      0.91      0.36        32
#         NONE       0.33      0.57      0.42        28
#
#     accuracy                           0.38       220
#    macro avg       0.48      0.57      0.39       220
# weighted avg       0.72      0.38      0.38       220
#
# -----------------------------------------
# <ipython-input-16-7822421f7f5a>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 6/6 [==============================] - 1s 152ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# <ipython-input-16-7822421f7f5a>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# Target:  Climate Change is a Real Concern
#               precision    recall  f1-score   support
#
#      AGAINST       0.00      0.00      0.00        11
#        FAVOR       0.84      0.91      0.87       123
#         NONE       0.69      0.69      0.69        35
#
#     accuracy                           0.80       169
#    macro avg       0.51      0.53      0.52       169
# weighted avg       0.75      0.80      0.78       169
#
# -----------------------------------------
#
# 9/9 [==============================] - 2s 166ms/step
# Target:  Feminist Movement
#               precision    recall  f1-score   support
#
#      AGAINST       0.71      0.62      0.66       183
#        FAVOR       0.28      0.34      0.31        58
#         NONE       0.44      0.55      0.49        44
#
#     accuracy                           0.55       285
#    macro avg       0.48      0.50      0.49       285
# weighted avg       0.58      0.55      0.57       285
#
# -----------------------------------------
# <ipython-input-16-7822421f7f5a>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 10/10 [==============================] - 2s 195ms/step
# Target:  Hillary Clinton
#               precision    recall  f1-score   support
#
#      AGAINST       0.79      0.46      0.58       172
#        FAVOR       0.42      0.29      0.34        45
#         NONE       0.38      0.79      0.51        78
#
#     accuracy                           0.52       295
#    macro avg       0.53      0.51      0.48       295
# weighted avg       0.62      0.52      0.53       295
#
# -----------------------------------------
# <ipython-input-16-7822421f7f5a>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 9/9 [==============================] - 2s 203ms/step
# Target:  Legalization of Abortion
#               precision    recall  f1-score   support
#
#      AGAINST       0.84      0.53      0.65       189
#        FAVOR       0.38      0.59      0.46        46
#         NONE       0.40      0.80      0.54        45
#
#     accuracy                           0.59       280
#    macro avg       0.54      0.64      0.55       280
# weighted avg       0.70      0.59      0.60       280
#
# -----------------------------------------
# <ipython-input-16-7822421f7f5a>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 23/23 [==============================] - 4s 161ms/step
# Target:  Donald Trump
#               precision    recall  f1-score   support
#
#      AGAINST       0.54      0.22      0.31       299
#        FAVOR       0.53      0.28      0.36       148
#         NONE       0.46      0.90      0.61       260
#
#     accuracy                           0.48       707
#    macro avg       0.51      0.47      0.43       707
# weighted avg       0.51      0.48      0.43       707
#
# -----------------------------------------
# <ipython-input-16-7822421f7f5a>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
#                                   Weighted F1  Macro F1  Accuracy
# Target
# Atheism                              0.384391  0.388635  0.381818
# Climate Change is a Real Concern     0.776368  0.519103  0.804734
# Feminist Movement                    0.565543  0.488199  0.554386
# Hillary Clinton                      0.526351  0.478461  0.522034
# Legalization of Abortion             0.603440  0.550858  0.585714
# Donald Trump                         0.433926  0.430006  0.483734

# %%
# Get model predictions
predictions = inital_model.predict([test_input_ids, test_attention_masks])

# Convert predictions to class labels
predicted_labels = np.argmax(predictions, axis=1)

# Assuming test_labels are one-hot encoded, convert them to class labels
true_labels = np.argmax(test_labels, axis=1)

# Generate classification report
report = classification_report(true_labels, predicted_labels)
print(report)
# Out:
# 62/62 [==============================] - 11s 183ms/step
#               precision    recall  f1-score   support
#
#            0       0.76      0.60      0.68      1014
#            1       0.57      0.69      0.63       452
#            2       0.58      0.72      0.64       490
#
#     accuracy                           0.65      1956
#    macro avg       0.64      0.67      0.65      1956
# weighted avg       0.67      0.65      0.66      1956

# %%
inital_model.save('roberta_model_balanced_66.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
