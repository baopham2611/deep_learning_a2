# %%
# !pip install plotly
# !pip install seaborn
# !pip install matplotlib
# !pip install transformers
# !pip install tokenizers
# !pip install scikit-learn
# !pip install tensorflow
# !pip install pandas
# !pip install numpy
# !pip install keras_tuner


# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# #
# <a id="data-prep"></a>
# <div style="background-color: #000D5B; color: white; text-align: center; padding: 6px 0 22px 0">
#     <h3 style="background-color: #000D5B; color: white; text-align: left">RMIT School of Computer Science and Technology</h3>
#     <br/>
#     <h1>COSC3007: Deep Learning</h1>
#     <h2>Assignment 2: Stance Twitter Sentiment Analysis and Detection </h2>
#     <h2> [2] MODELLING AND MODEL EVALUATIONS </h2>
#
# </div>

# %% [markdown]
# # Import Libs

# %%
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, BatchNormalization, Bidirectional, Flatten
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers.legacy import Adam
from sklearn.metrics import classification_report
import numpy as np

import numpy as np

# %% [markdown]
# # [1] Load Data

# %%
train_df = pd.read_csv("./drive/MyDrive/Colab Notebooks/StanceDataset/processed_train_augumented.csv", encoding = "ISO-8859-1", engine="python").drop(columns=['Unnamed: 0'])
train_df = train_df.sample(frac=1, random_state=42).reset_index(drop=True)
train_ori = train_df.copy()

test_df = pd.read_csv("./drive/MyDrive/Colab Notebooks/StanceDataset/processed_test_augumented.csv", encoding = "ISO-8859-1", engine="python").drop(columns=['Unnamed: 0'])

# %%
print(len(train_ori))
print(len(test_df))
# Out:
# 3296
# 1956

# %% [markdown]
# # [2] Prepare label and fit data

# %% [markdown]
# ## Split test and val

# %%
train_df, val_df = train_test_split(train_df, test_size=0.2, random_state=42, shuffle=True)

# %% [markdown]
# ## Tweets

# %%
from transformers import TFRobertaModel, RobertaTokenizer
import numpy as np

# Initialize the BERT tokenizer
MAX_LENGTH = 512
tokenizer = RobertaTokenizer.from_pretrained('roberta-base')
roberta_model = TFRobertaModel.from_pretrained('roberta-base')

# Assuming train_texts, val_texts, test_texts are your datasets
train_processed_tweets = train_df['Tweet'].tolist()
val_processed_tweets = val_df['Tweet'].tolist()
test_processed_tweets = test_df['Tweet'].tolist()

all_processed_tweets = train_processed_tweets + val_processed_tweets + test_processed_tweets
tokenized_tweets = [tokenizer.encode(tweet, add_special_tokens=True) for tweet in all_processed_tweets]
MAX_LENGTH = max(len(tweet) for tweet in tokenized_tweets)
MAX_LENGTH = 128

print("Maximum length across all datasets:", MAX_LENGTH)

target_names = {
    0: "Hillary Clinton",
    1: "Legalization of Abortion",
    2: "Atheism",
    3: "Climate Change is a Real Concern",
    4: "Feminist Movement",
    5: "Donald Trump",
    6: "Joe Biden",
    7: "Barack Obama",
    8: "Kamala Harris",
    9: "Bernie Sanders",
    10: "Vu",
}

def bert_tokenize(texts, targets, max_length=MAX_LENGTH):
    input_ids = []
    attention_masks = []

    for idx, text in enumerate(texts):
        targetID = targets[idx]
        target_name = target_names.get(targetID, "")
        formatted_text = f"<s> {target_name} </s></s> {text} </s>"
        encoded = tokenizer.encode_plus(
            formatted_text,
            add_special_tokens=True,
            max_length=max_length,
            truncation=True,
            padding='max_length',
            return_attention_mask=True,
            return_tensors='tf',
        )

        # Flatten the tensors and remove the extra dimension
        input_ids.append(tf.squeeze(encoded['input_ids'], axis=0))
        attention_masks.append(tf.squeeze(encoded['attention_mask'], axis=0))

    return np.array(input_ids), np.array(attention_masks)

# Assuming you have lists of preprocessed texts for training, validation, and test sets
train_input_ids, train_attention_masks = bert_tokenize(train_df['Tweet'],  train_df['Target'].to_list())
val_input_ids, val_attention_masks = bert_tokenize(val_df['Tweet'], val_df['Target'].to_list())
test_input_ids, test_attention_masks = bert_tokenize(test_df['Tweet'], test_df['Target'].to_list())

print(train_input_ids.shape)
print(val_input_ids.shape)
print(test_input_ids.shape)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:72: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFRobertaModel: ['roberta.embeddings.position_ids', 'lm_head.dense.bias', 'lm_head.bias', 'lm_head.layer_norm.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing TFRobertaModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFRobertaModel were not initialized from the PyTorch model and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Maximum length across all datasets: 128
# (2636, 128)
# (660, 128)
# (1956, 128)

# %% [markdown]
# ## Stances

# %%
def categorized_label(df, label_name):
    label_encoder = LabelEncoder()
    encoded_labels = label_encoder.fit_transform(df[label_name])
    categorical_labels = to_categorical(encoded_labels)
    return categorical_labels

# %%
train_labels = categorized_label(train_df, "Stance")
test_labels = categorized_label(test_df, "Stance")
val_labels = categorized_label(val_df, "Stance")

# %% [markdown]
# # [3] Create Model

# %%
from keras import backend as K
from tensorflow.keras.optimizers.legacy import Adam
from hyperopt import hp
from hyperopt import hp, fmin, tpe, STATUS_OK, Trials
# import keras_tuner as kt

# %%
def f1_score_class(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))

    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    return 2 * ((precision * recall) / (precision + recall + K.epsilon()))

def f1_score(y_true, y_pred):
    # Convert predictions to one-hot format
    y_pred_one_hot = K.one_hot(K.argmax(y_pred), num_classes=3)

    # Calculate F1 score for each class
    f1s = [f1_score_class(y_true[:, i], y_pred_one_hot[:, i]) for i in range(3)]

    # Average F1 scores across all classes
    return K.mean(K.stack(f1s), axis=0)

# %% [markdown]
# Set up call backs and learning rates

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint


# Define the EarlyStopping and ReduceLROnPlateau callbacks
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=10,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=5,
    min_lr=1e-5,
    verbose=1,
)

# Define the ModelCheckpoint callback
checkpoint_path = "roberta_best_model.h5"
model_checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_path,
    save_weights_only=True,    # Only save a model if 'val_loss' has improved
    monitor='val_loss',     # Monitor 'val_loss' during training
    mode='min',             # The model is saved when 'val_loss' is minimized
    verbose=1)

# Combine all callbacks in a list
callbacks = [
    early_stopping,
    lr_scheduler,
    model_checkpoint_callback
]

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, BatchNormalization, Bidirectional, Flatten, Input, GlobalMaxPooling1D
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers.legacy import Adam
# import keras_tuner as kt
from transformers import TFRobertaModel

def build_model(drop, regr, lr):
    bert_model = TFRobertaModel.from_pretrained('roberta-base')
    bert_model.trainable = False

    # Define model input (BERT expects two inputs: input_ids and attention_mask)
    input_ids = Input(shape=(MAX_LENGTH,), dtype=tf.int32, name='input_ids')
    attention_mask = Input(shape=(MAX_LENGTH,), dtype=tf.int32, name='attention_mask')

    # Get BERT embeddings
    bert_output = bert_model(input_ids, attention_mask=attention_mask)[0]  # Use the pooled output here

    # Tuning the number of units in the first biLSTM layer
    x = Bidirectional(LSTM(units=64,  dropout=drop, recurrent_dropout=drop,return_sequences=True,kernel_regularizer=tf.keras.regularizers.l2(regr))) (bert_output)

    # x = Bidirectional(LSTM(units=64,  dropout=drop, return_sequences=True,kernel_regularizer=tf.keras.regularizers.l2(regr))) (bert_output)

    x = GlobalMaxPooling1D()(x)

    # Dense layer with tunable units
    x = Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(regr)) (x)

    # Tunable dropout rate for the second layer
    x = Dropout(drop)(x)

    # Final Layer
    x = Dense(3, activation='softmax')(x)

    # Tuning the learning rate for the optimizer
    optimizer = Adam(learning_rate=lr)
    model = Model(inputs=[input_ids, attention_mask], outputs=x)
    model.compile(loss='CategoricalCrossentropy', optimizer=optimizer, metrics=['categorical_accuracy',f1_score])
    model.summary()

    return model

# %% [markdown]
# Recreate the best model with more training time

# %%
history = {}
inital_model = build_model(0.8, 0.0005, 0.001)
history['tuned_stance_model_custom'] = inital_model.fit([train_input_ids, train_attention_masks], train_labels,
                    epochs=100,
                    validation_data=([val_input_ids, val_attention_masks], val_labels),
                    batch_size=128,
                    callbacks=callbacks,
                    shuffle = True)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:72: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFRobertaModel: ['roberta.embeddings.position_ids', 'lm_head.dense.bias', 'lm_head.bias', 'lm_head.layer_norm.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing TFRobertaModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFRobertaModel were not initialized from the PyTorch model and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_ids (InputLayer)      [(None, 128)]                0         []
#
#  attention_mask (InputLayer  [(None, 128)]                0         []
#  )
#
#  tf_roberta_model_1 (TFRobe  TFBaseModelOutputWithPooli   1246456   ['input_ids[0][0]',
#  rtaModel)                   ngAndCrossAttentions(last_   32         'attention_mask[0][0]']
#                              hidden_state=(None, 128, 7
#                              68),
#                               pooler_output=(None, 768)
#                              , past_key_values=None, hi
#                              dden_states=None, attentio
#                              ns=None, cross_attentions=
#                              None)
#
#  bidirectional (Bidirection  (None, 128, 128)             426496    ['tf_roberta_model_1[0][0]']
#  al)
#
#  global_max_pooling1d (Glob  (None, 128)                  0         ['bidirectional[0][0]']
#  alMaxPooling1D)
#
#  dense (Dense)               (None, 128)                  16512     ['global_max_pooling1d[0][0]']
#
#  dropout_74 (Dropout)        (None, 128)                  0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 3)                    387       ['dropout_74[0][0]']
#
# ==================================================================================================
# Total params: 125089027 (477.18 MB)
# Trainable params: 443395 (1.69 MB)
# Non-trainable params: 124645632 (475.49 MB)
# __________________________________________________________________________________________________
# Epoch 1/100
# 21/21 [==============================] - ETA: 0s - loss: 1.6611 - categorical_accuracy: 0.4002 - f1_score: 0.3301
# Epoch 1: saving model to roberta_best_model.h5
# 21/21 [==============================] - 75s 2s/step - loss: 1.6611 - categorical_accuracy: 0.4002 - f1_score: 0.3301 - val_loss: 1.5095 - val_categorical_accuracy: 0.3530 - val_f1_score: 0.2730 - lr: 0.0010
# Epoch 2/100
# 21/21 [==============================] - ETA: 0s - loss: 1.4752 - categorical_accuracy: 0.4568 - f1_score: 0.2539
# Epoch 2: saving model to roberta_best_model.h5
# 21/21 [==============================] - 29s 1s/step - loss: 1.4752 - categorical_accuracy: 0.4568 - f1_score: 0.2539 - val_loss: 1.4643 - val_categorical_accuracy: 0.4742 - val_f1_score: 0.3130 - lr: 0.0010
# Epoch 3/100
# 21/21 [==============================] - ETA: 0s - loss: 1.4274 - categorical_accuracy: 0.4715 - f1_score: 0.2342
# Epoch 3: saving model to roberta_best_model.h5
# 21/21 [==============================] - 28s 1s/step - loss: 1.4274 - categorical_accuracy: 0.4715 - f1_score: 0.2342 - val_loss: 1.4171 - val_categorical_accuracy: 0.5121 - val_f1_score: 0.2688 - lr: 0.0010
# Epoch 4/100
# 21/21 [==============================] - ETA: 0s - loss: 1.3906 - categorical_accuracy: 0.4723 - f1_score: 0.2398
# Epoch 4: saving model to roberta_best_model.h5
# 21/21 [==============================] - 28s 1s/step - loss: 1.3906 - categorical_accuracy: 0.4723 - f1_score: 0.2398 - val_loss: 1.3746 - val_categorical_accuracy: 0.5167 - val_f1_score: 0.2695 - lr: 0.0010
# Epoch 5/100
# 21/21 [==============================] - ETA: 0s - loss: 1.3529 - categorical_accuracy: 0.4715 - f1_score: 0.2676
# Epoch 5: saving model to roberta_best_model.h5
# 21/21 [==============================] - 29s 1s/step - loss: 1.3529 - categorical_accuracy: 0.4715 - f1_score: 0.2676 - val_loss: 1.3391 - val_categorical_accuracy: 0.5303 - val_f1_score: 0.3014 - lr: 0.0010
# Epoch 6/100
# 21/21 [==============================] - ETA: 0s - loss: 1.3216 - categorical_accuracy: 0.4803 - f1_score: 0.2676
# Epoch 6: saving model to roberta_best_model.h5
# 21/21 [==============================] - 32s 2s/step - loss: 1.3216 - categorical_accuracy: 0.4803 - f1_score: 0.2676 - val_loss: 1.3169 - val_categorical_accuracy: 0.5409 - val_f1_score: 0.3495 - lr: 0.0010
# Epoch 7/100
# 21/21 [==============================] - ETA: 0s - loss: 1.2842 - categorical_accuracy: 0.4890 - f1_score: 0.3026
# Epoch 7: saving model to roberta_best_model.h5
# 21/21 [==============================] - 28s 1s/step - loss: 1.2842 - categorical_accuracy: 0.4890 - f1_score: 0.3026 - val_loss: 1.2716 - val_categorical_accuracy: 0.5439 - val_f1_score: 0.3290 - lr: 0.0010
# Epoch 8/100
# 21/21 [==============================] - ETA: 0s - loss: 1.2621 - categorical_accuracy: 0.4962 - f1_score: 0.3171
# Epoch 8: saving model to roberta_best_model.h5
# 21/21 [==============================] - 31s 2s/step - loss: 1.2621 - categorical_accuracy: 0.4962 - f1_score: 0.3171 - val_loss: 1.2632 - val_categorical_accuracy: 0.5333 - val_f1_score: 0.3675 - lr: 0.0010
# Epoch 9/100
# 21/21 [==============================] - ETA: 0s - loss: 1.2286 - categorical_accuracy: 0.5110 - f1_score: 0.3456
# Epoch 9: saving model to roberta_best_model.h5
# 21/21 [==============================] - 28s 1s/step - loss: 1.2286 - categorical_accuracy: 0.5110 - f1_score: 0.3456 - val_loss: 1.2044 - val_categorical_accuracy: 0.5424 - val_f1_score: 0.3239 - lr: 0.0010
# Epoch 10/100
# 21/21 [==============================] - ETA: 0s - loss: 1.1986 - categorical_accuracy: 0.5087 - f1_score: 0.3464
# Epoch 10: saving model to roberta_best_model.h5
# 21/21 [==============================] - 28s 1s/step - loss: 1.1986 - categorical_accuracy: 0.5087 - f1_score: 0.3464 - val_loss: 1.1856 - val_categorical_accuracy: 0.5409 - val_f1_score: 0.3791 - lr: 0.0010
# Epoch 11/100
# 21/21 [==============================] - ETA: 0s - loss: 1.1808 - categorical_accuracy: 0.5216 - f1_score: 0.3676
# Epoch 11: saving model to roberta_best_model.h5
# 21/21 [==============================] - 28s 1s/step - loss: 1.1808 - categorical_accuracy: 0.5216 - f1_score: 0.3676 - val_loss: 1.2067 - val_categorical_accuracy: 0.4697 - val_f1_score: 0.4299 - lr: 0.0010
# Epoch 12/100
# 21/21 [==============================] - ETA: 0s - loss: 1.1633 - categorical_accuracy: 0.5269 - f1_score: 0.3837
# Epoch 12: saving model to roberta_best_model.h5
# 21/21 [==============================] - 27s 1s/step - loss: 1.1633 - categorical_accuracy: 0.5269 - f1_score: 0.3837 - val_loss: 1.1878 - val_categorical_accuracy: 0.5000 - val_f1_score: 0.4364 - lr: 0.0010
# Epoch 13/100
# 21/21 [==============================] - ETA: 0s - loss: 1.1492 - categorical_accuracy: 0.5292 - f1_score: 0.3944
# Epoch 13: saving model to roberta_best_model.h5
# 21/21 [==============================] - 28s 1s/step - loss: 1.1492 - categorical_accuracy: 0.5292 - f1_score: 0.3944 - val_loss: 1.1084 - val_categorical_accuracy: 0.5470 - val_f1_score: 0.3390 - lr: 0.0010
# Epoch 14/100
# 21/21 [==============================] - ETA: 0s - loss: 1.1248 - categorical_accuracy: 0.5269 - f1_score: 0.3841
# Epoch 14: saving model to roberta_best_model.h5
# 21/21 [==============================] - 29s 1s/step - loss: 1.1248 - categorical_accuracy: 0.5269 - f1_score: 0.3841 - val_loss: 1.1021 - val_categorical_accuracy: 0.5379 - val_f1_score: 0.4245 - lr: 0.0010
# Epoch 15/100
# 21/21 [==============================] - ETA: 0s - loss: 1.1086 - categorical_accuracy: 0.5421 - f1_score: 0.3955
# Epoch 15: saving model to roberta_best_model.h5
# 21/21 [==============================] - 29s 1s/step - loss: 1.1086 - categorical_accuracy: 0.5421 - f1_score: 0.3955 - val_loss: 1.0903 - val_categorical_accuracy: 0.5379 - val_f1_score: 0.4649 - lr: 0.0010
# Epoch 16/100
# 21/21 [==============================] - ETA: 0s - loss: 1.0921 - categorical_accuracy: 0.5482 - f1_score: 0.4313
# Epoch 16: saving model to roberta_best_model.h5
# 21/21 [==============================] - 58s 3s/step - loss: 1.0921 - categorical_accuracy: 0.5482 - f1_score: 0.4313 - val_loss: 1.1012 - val_categorical_accuracy: 0.5409 - val_f1_score: 0.4824 - lr: 0.0010
# Epoch 17/100
# 21/21 [==============================] - ETA: 0s - loss: 1.0757 - categorical_accuracy: 0.5615 - f1_score: 0.4560
# Epoch 17: saving model to roberta_best_model.h5
# 21/21 [==============================] - 28s 1s/step - loss: 1.0757 - categorical_accuracy: 0.5615 - f1_score: 0.4560 - val_loss: 1.0989 - val_categorical_accuracy: 0.5439 - val_f1_score: 0.5166 - lr: 0.0010
# Epoch 18/100
# 21/21 [==============================] - ETA: 0s - loss: 1.0645 - categorical_accuracy: 0.5622 - f1_score: 0.4713
# Epoch 18: saving model to roberta_best_model.h5
# 21/21 [==============================] - 29s 1s/step - loss: 1.0645 - categorical_accuracy: 0.5622 - f1_score: 0.4713 - val_loss: 1.0292 - val_categorical_accuracy: 0.5561 - val_f1_score: 0.4071 - lr: 0.0010
# Epoch 19/100
# 21/21 [==============================] - ETA: 0s - loss: 1.0443 - categorical_accuracy: 0.5622 - f1_score: 0.4658
# Epoch 19: saving model to roberta_best_model.h5
# 21/21 [==============================] - 29s 1s/step - loss: 1.0443 - categorical_accuracy: 0.5622 - f1_score: 0.4658 - val_loss: 1.0577 - val_categorical_accuracy: 0.5424 - val_f1_score: 0.4844 - lr: 0.0010
# Epoch 20/100
# 21/21 [==============================] - ETA: 0s - loss: 1.0458 - categorical_accuracy: 0.5706 - f1_score: 0.4825
# Epoch 20: saving model to roberta_best_model.h5
# 21/21 [==============================] - 28s 1s/step - loss: 1.0458 - categorical_accuracy: 0.5706 - f1_score: 0.4825 - val_loss: 1.0778 - val_categorical_accuracy: 0.5515 - val_f1_score: 0.5228 - lr: 0.0010
# Epoch 21/100
# 21/21 [==============================] - ETA: 0s - loss: 1.0408 - categorical_accuracy: 0.5766 - f1_score: 0.5004
# Epoch 21: saving model to roberta_best_model.h5
# 21/21 [==============================] - 29s 1s/step - loss: 1.0408 - categorical_accuracy: 0.5766 - f1_score: 0.5004 - val_loss: 1.0228 - val_categorical_accuracy: 0.5712 - val_f1_score: 0.4751 - lr: 0.0010
# Epoch 22/100
# 21/21 [==============================] - ETA: 0s - loss: 1.0251 - categorical_accuracy: 0.5618 - f1_score: 0.4731
# Epoch 22: saving model to roberta_best_model.h5
# 21/21 [==============================] - 29s 1s/step - loss: 1.0251 - categorical_accuracy: 0.5618 - f1_score: 0.4731 - val_loss: 1.0178 - val_categorical_accuracy: 0.5833 - val_f1_score: 0.5460 - lr: 0.0010
# Epoch 23/100
# 21/21 [==============================] - ETA: 0s - loss: 1.0165 - categorical_accuracy: 0.5797 - f1_score: 0.4986
# Epoch 23: saving model to roberta_best_model.h5
# 21/21 [==============================] - 39s 2s/step - loss: 1.0165 - categorical_accuracy: 0.5797 - f1_score: 0.4986 - val_loss: 1.0241 - val_categorical_accuracy: 0.5803 - val_f1_score: 0.5347 - lr: 0.0010
# Epoch 24/100
# 21/21 [==============================] - ETA: 0s - loss: 0.9970 - categorical_accuracy: 0.5781 - f1_score: 0.5038
# Epoch 24: saving model to roberta_best_model.h5
# 21/21 [==============================] - 28s 1s/step - loss: 0.9970 - categorical_accuracy: 0.5781 - f1_score: 0.5038 - val_loss: 1.0196 - val_categorical_accuracy: 0.5697 - val_f1_score: 0.5063 - lr: 0.0010
# Epoch 25/100
# 21/21 [==============================] - ETA: 0s - loss: 0.9877 - categorical_accuracy: 0.5846 - f1_score: 0.5266
# Epoch 25: saving model to roberta_best_model.h5
# 21/21 [==============================] - 29s 1s/step - loss: 0.9877 - categorical_accuracy: 0.5846 - f1_score: 0.5266 - val_loss: 0.9645 - val_categorical_accuracy: 0.6106 - val_f1_score: 0.5865 - lr: 0.0010
# Epoch 26/100
# 21/21 [==============================] - ETA: 0s - loss: 0.9975 - categorical_accuracy: 0.5846 - f1_score: 0.5190
# Epoch 26: saving model to roberta_best_model.h5
# 21/21 [==============================] - 27s 1s/step - loss: 0.9975 - categorical_accuracy: 0.5846 - f1_score: 0.5190 - val_loss: 1.0134 - val_categorical_accuracy: 0.5727 - val_f1_score: 0.5304 - lr: 0.0010
# Epoch 27/100
# 21/21 [==============================] - ETA: 0s - loss: 0.9848 - categorical_accuracy: 0.5933 - f1_score: 0.5300
# Epoch 27: saving model to roberta_best_model.h5
# 21/21 [==============================] - 28s 1s/step - loss: 0.9848 - categorical_accuracy: 0.5933 - f1_score: 0.5300 - val_loss: 0.9349 - val_categorical_accuracy: 0.6303 - val_f1_score: 0.5818 - lr: 0.0010
# Epoch 28/100
# 21/21 [==============================] - ETA: 0s - loss: 0.9821 - categorical_accuracy: 0.5910 - f1_score: 0.5266
# Epoch 28: saving model to roberta_best_model.h5
# 21/21 [==============================] - 28s 1s/step - loss: 0.9821 - categorical_accuracy: 0.5910 - f1_score: 0.5266 - val_loss: 0.9459 - val_categorical_accuracy: 0.6091 - val_f1_score: 0.5402 - lr: 0.0010
# Epoch 29/100
# 21/21 [==============================] - ETA: 0s - loss: 0.9719 - categorical_accuracy: 0.6017 - f1_score: 0.5469
# Epoch 29: saving model to roberta_best_model.h5
# 21/21 [==============================] - 29s 1s/step - loss: 0.9719 - categorical_accuracy: 0.6017 - f1_score: 0.5469 - val_loss: 0.9094 - val_categorical_accuracy: 0.6333 - val_f1_score: 0.5493 - lr: 0.0010
# Epoch 30/100
# 21/21 [==============================] - ETA: 0s - loss: 0.9558 - categorical_accuracy: 0.6081 - f1_score: 0.5545
# Epoch 30: saving model to roberta_best_model.h5
# 21/21 [==============================] - 29s 1s/step - loss: 0.9558 - categorical_accuracy: 0.6081 - f1_score: 0.5545 - val_loss: 0.9722 - val_categorical_accuracy: 0.5894 - val_f1_score: 0.5316 - lr: 0.0010
# Epoch 31/100
# 21/21 [==============================] - ETA: 0s - loss: 0.9651 - categorical_accuracy: 0.6074 - f1_score: 0.5521
# Epoch 31: saving model to roberta_best_model.h5
# 21/21 [==============================] - 29s 1s/step - loss: 0.9651 - categorical_accuracy: 0.6074 - f1_score: 0.5521 - val_loss: 0.9520 - val_categorical_accuracy: 0.6197 - val_f1_score: 0.6108 - lr: 0.0010
# Epoch 32/100
# 21/21 [==============================] - ETA: 0s - loss: 0.9566 - categorical_accuracy: 0.6191 - f1_score: 0.5618
# Epoch 32: saving model to roberta_best_model.h5
# 21/21 [==============================] - 30s 1s/step - loss: 0.9566 - categorical_accuracy: 0.6191 - f1_score: 0.5618 - val_loss: 0.8904 - val_categorical_accuracy: 0.6545 - val_f1_score: 0.5823 - lr: 0.0010
# Epoch 33/100
# 21/21 [==============================] - ETA: 0s - loss: 0.9448 - categorical_accuracy: 0.6191 - f1_score: 0.5767
# Epoch 33: saving model to roberta_best_model.h5
# 21/21 [==============================] - 28s 1s/step - loss: 0.9448 - categorical_accuracy: 0.6191 - f1_score: 0.5767 - val_loss: 0.9312 - val_categorical_accuracy: 0.6136 - val_f1_score: 0.5491 - lr: 0.0010
# Epoch 34/100
# 21/21 [==============================] - ETA: 0s - loss: 0.9434 - categorical_accuracy: 0.6161 - f1_score: 0.5703
# Epoch 34: saving model to roberta_best_model.h5
# 21/21 [==============================] - 28s 1s/step - loss: 0.9434 - categorical_accuracy: 0.6161 - f1_score: 0.5703 - val_loss: 0.9320 - val_categorical_accuracy: 0.6333 - val_f1_score: 0.6416 - lr: 0.0010
# Epoch 35/100
# 21/21 [==============================] - ETA: 0s - loss: 0.9319 - categorical_accuracy: 0.6127 - f1_score: 0.5645
# Epoch 35: saving model to roberta_best_model.h5
# 21/21 [==============================] - 29s 1s/step - loss: 0.9319 - categorical_accuracy: 0.6127 - f1_score: 0.5645 - val_loss: 0.8918 - val_categorical_accuracy: 0.6288 - val_f1_score: 0.5441 - lr: 0.0010
# Epoch 36/100
# 21/21 [==============================] - ETA: 0s - loss: 0.9262 - categorical_accuracy: 0.6263 - f1_score: 0.5810
# Epoch 36: saving model to roberta_best_model.h5
# 21/21 [==============================] - 29s 1s/step - loss: 0.9262 - categorical_accuracy: 0.6263 - f1_score: 0.5810 - val_loss: 0.9042 - val_categorical_accuracy: 0.6455 - val_f1_score: 0.6259 - lr: 0.0010
# Epoch 37/100
# 21/21 [==============================] - ETA: 0s - loss: 0.9139 - categorical_accuracy: 0.6252 - f1_score: 0.5866
# Epoch 37: saving model to roberta_best_model.h5
# 21/21 [==============================] - 28s 1s/step - loss: 0.9139 - categorical_accuracy: 0.6252 - f1_score: 0.5866 - val_loss: 0.8855 - val_categorical_accuracy: 0.6530 - val_f1_score: 0.6529 - lr: 0.0010
# Epoch 38/100
# 21/21 [==============================] - ETA: 0s - loss: 0.9189 - categorical_accuracy: 0.6256 - f1_score: 0.5835
# Epoch 38: saving model to roberta_best_model.h5
# 21/21 [==============================] - 27s 1s/step - loss: 0.9189 - categorical_accuracy: 0.6256 - f1_score: 0.5835 - val_loss: 0.8953 - val_categorical_accuracy: 0.6379 - val_f1_score: 0.5330 - lr: 0.0010
# Epoch 39/100
# 21/21 [==============================] - ETA: 0s - loss: 0.9199 - categorical_accuracy: 0.6343 - f1_score: 0.5977
# Epoch 39: saving model to roberta_best_model.h5
# 21/21 [==============================] - 28s 1s/step - loss: 0.9199 - categorical_accuracy: 0.6343 - f1_score: 0.5977 - val_loss: 0.8645 - val_categorical_accuracy: 0.6591 - val_f1_score: 0.6484 - lr: 0.0010
# Epoch 40/100
# 21/21 [==============================] - ETA: 0s - loss: 0.9120 - categorical_accuracy: 0.6472 - f1_score: 0.6093
# Epoch 40: saving model to roberta_best_model.h5
# 21/21 [==============================] - 28s 1s/step - loss: 0.9120 - categorical_accuracy: 0.6472 - f1_score: 0.6093 - val_loss: 0.9125 - val_categorical_accuracy: 0.6394 - val_f1_score: 0.5710 - lr: 0.0010
# Epoch 41/100
# 21/21 [==============================] - ETA: 0s - loss: 0.9228 - categorical_accuracy: 0.6195 - f1_score: 0.5712
# Epoch 41: saving model to roberta_best_model.h5
# 21/21 [==============================] - 28s 1s/step - loss: 0.9228 - categorical_accuracy: 0.6195 - f1_score: 0.5712 - val_loss: 0.9355 - val_categorical_accuracy: 0.6273 - val_f1_score: 0.6406 - lr: 0.0010
# Epoch 42/100
# 21/21 [==============================] - ETA: 0s - loss: 0.9009 - categorical_accuracy: 0.6381 - f1_score: 0.6037
# Epoch 42: saving model to roberta_best_model.h5
# 21/21 [==============================] - 29s 1s/step - loss: 0.9009 - categorical_accuracy: 0.6381 - f1_score: 0.6037 - val_loss: 0.9181 - val_categorical_accuracy: 0.6273 - val_f1_score: 0.5598 - lr: 0.0010
# Epoch 43/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8746 - categorical_accuracy: 0.6567 - f1_score: 0.6203
# Epoch 43: saving model to roberta_best_model.h5
# 21/21 [==============================] - 29s 1s/step - loss: 0.8746 - categorical_accuracy: 0.6567 - f1_score: 0.6203 - val_loss: 0.8899 - val_categorical_accuracy: 0.6409 - val_f1_score: 0.5303 - lr: 0.0010
# Epoch 44/100
# 21/21 [==============================] - ETA: 0s - loss: 0.9235 - categorical_accuracy: 0.6332 - f1_score: 0.5895
# Epoch 44: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 44: saving model to roberta_best_model.h5
# 21/21 [==============================] - 28s 1s/step - loss: 0.9235 - categorical_accuracy: 0.6332 - f1_score: 0.5895 - val_loss: 0.8901 - val_categorical_accuracy: 0.6591 - val_f1_score: 0.6260 - lr: 0.0010
# Epoch 45/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8834 - categorical_accuracy: 0.6388 - f1_score: 0.6008
# Epoch 45: saving model to roberta_best_model.h5
# 21/21 [==============================] - 28s 1s/step - loss: 0.8834 - categorical_accuracy: 0.6388 - f1_score: 0.6008 - val_loss: 0.8699 - val_categorical_accuracy: 0.6621 - val_f1_score: 0.5753 - lr: 2.0000e-04
# Epoch 46/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8603 - categorical_accuracy: 0.6658 - f1_score: 0.6347
# Epoch 46: saving model to roberta_best_model.h5
# 21/21 [==============================] - 32s 2s/step - loss: 0.8603 - categorical_accuracy: 0.6658 - f1_score: 0.6347 - val_loss: 0.8542 - val_categorical_accuracy: 0.6667 - val_f1_score: 0.5964 - lr: 2.0000e-04
# Epoch 47/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8770 - categorical_accuracy: 0.6502 - f1_score: 0.6254
# Epoch 47: saving model to roberta_best_model.h5
# 21/21 [==============================] - 29s 1s/step - loss: 0.8770 - categorical_accuracy: 0.6502 - f1_score: 0.6254 - val_loss: 0.8568 - val_categorical_accuracy: 0.6530 - val_f1_score: 0.5772 - lr: 2.0000e-04
# Epoch 48/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8550 - categorical_accuracy: 0.6726 - f1_score: 0.6458
# Epoch 48: saving model to roberta_best_model.h5
# 21/21 [==============================] - 28s 1s/step - loss: 0.8550 - categorical_accuracy: 0.6726 - f1_score: 0.6458 - val_loss: 0.8564 - val_categorical_accuracy: 0.6636 - val_f1_score: 0.5872 - lr: 2.0000e-04
# Epoch 49/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8626 - categorical_accuracy: 0.6620 - f1_score: 0.6329
# Epoch 49: saving model to roberta_best_model.h5
# 21/21 [==============================] - 47s 2s/step - loss: 0.8626 - categorical_accuracy: 0.6620 - f1_score: 0.6329 - val_loss: 0.8500 - val_categorical_accuracy: 0.6712 - val_f1_score: 0.5906 - lr: 2.0000e-04
# Epoch 50/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8691 - categorical_accuracy: 0.6483 - f1_score: 0.6138
# Epoch 50: saving model to roberta_best_model.h5
# 21/21 [==============================] - 33s 2s/step - loss: 0.8691 - categorical_accuracy: 0.6483 - f1_score: 0.6138 - val_loss: 0.8497 - val_categorical_accuracy: 0.6682 - val_f1_score: 0.6542 - lr: 2.0000e-04
# Epoch 51/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8644 - categorical_accuracy: 0.6571 - f1_score: 0.6237
# Epoch 51: saving model to roberta_best_model.h5
# 21/21 [==============================] - 28s 1s/step - loss: 0.8644 - categorical_accuracy: 0.6571 - f1_score: 0.6237 - val_loss: 0.8473 - val_categorical_accuracy: 0.6758 - val_f1_score: 0.6350 - lr: 2.0000e-04
# Epoch 52/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8609 - categorical_accuracy: 0.6658 - f1_score: 0.6371
# Epoch 52: saving model to roberta_best_model.h5
# 21/21 [==============================] - 29s 1s/step - loss: 0.8609 - categorical_accuracy: 0.6658 - f1_score: 0.6371 - val_loss: 0.8463 - val_categorical_accuracy: 0.6697 - val_f1_score: 0.5843 - lr: 2.0000e-04
# Epoch 53/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8579 - categorical_accuracy: 0.6692 - f1_score: 0.6409
# Epoch 53: saving model to roberta_best_model.h5
# 21/21 [==============================] - 29s 1s/step - loss: 0.8579 - categorical_accuracy: 0.6692 - f1_score: 0.6409 - val_loss: 0.8583 - val_categorical_accuracy: 0.6667 - val_f1_score: 0.6402 - lr: 2.0000e-04
# Epoch 54/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8448 - categorical_accuracy: 0.6620 - f1_score: 0.6286
# Epoch 54: saving model to roberta_best_model.h5
# 21/21 [==============================] - 29s 1s/step - loss: 0.8448 - categorical_accuracy: 0.6620 - f1_score: 0.6286 - val_loss: 0.8529 - val_categorical_accuracy: 0.6712 - val_f1_score: 0.6487 - lr: 2.0000e-04
# Epoch 55/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8501 - categorical_accuracy: 0.6684 - f1_score: 0.6386
# Epoch 55: saving model to roberta_best_model.h5
# 21/21 [==============================] - 34s 2s/step - loss: 0.8501 - categorical_accuracy: 0.6684 - f1_score: 0.6386 - val_loss: 0.8494 - val_categorical_accuracy: 0.6712 - val_f1_score: 0.6527 - lr: 2.0000e-04
# Epoch 56/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8539 - categorical_accuracy: 0.6631 - f1_score: 0.6324
# Epoch 56: saving model to roberta_best_model.h5
# 21/21 [==============================] - 32s 2s/step - loss: 0.8539 - categorical_accuracy: 0.6631 - f1_score: 0.6324 - val_loss: 0.8534 - val_categorical_accuracy: 0.6652 - val_f1_score: 0.6310 - lr: 2.0000e-04
# Epoch 57/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8504 - categorical_accuracy: 0.6605 - f1_score: 0.6268
# Epoch 57: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 57: saving model to roberta_best_model.h5
# 21/21 [==============================] - 34s 2s/step - loss: 0.8504 - categorical_accuracy: 0.6605 - f1_score: 0.6268 - val_loss: 0.8508 - val_categorical_accuracy: 0.6773 - val_f1_score: 0.5964 - lr: 2.0000e-04
# Epoch 58/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8492 - categorical_accuracy: 0.6639 - f1_score: 0.6334
# Epoch 58: saving model to roberta_best_model.h5
# 21/21 [==============================] - 34s 2s/step - loss: 0.8492 - categorical_accuracy: 0.6639 - f1_score: 0.6334 - val_loss: 0.8505 - val_categorical_accuracy: 0.6697 - val_f1_score: 0.6300 - lr: 4.0000e-05
# Epoch 59/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8416 - categorical_accuracy: 0.6616 - f1_score: 0.6277
# Epoch 59: saving model to roberta_best_model.h5
# 21/21 [==============================] - 28s 1s/step - loss: 0.8416 - categorical_accuracy: 0.6616 - f1_score: 0.6277 - val_loss: 0.8481 - val_categorical_accuracy: 0.6758 - val_f1_score: 0.6393 - lr: 4.0000e-05
# Epoch 60/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8393 - categorical_accuracy: 0.6722 - f1_score: 0.6412
# Epoch 60: saving model to roberta_best_model.h5
# 21/21 [==============================] - 28s 1s/step - loss: 0.8393 - categorical_accuracy: 0.6722 - f1_score: 0.6412 - val_loss: 0.8571 - val_categorical_accuracy: 0.6621 - val_f1_score: 0.6447 - lr: 4.0000e-05
# Epoch 61/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8476 - categorical_accuracy: 0.6684 - f1_score: 0.6442
# Epoch 61: saving model to roberta_best_model.h5
# 21/21 [==============================] - 29s 1s/step - loss: 0.8476 - categorical_accuracy: 0.6684 - f1_score: 0.6442 - val_loss: 0.8476 - val_categorical_accuracy: 0.6667 - val_f1_score: 0.6510 - lr: 4.0000e-05
# Epoch 62/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8299 - categorical_accuracy: 0.6764 - f1_score: 0.6431Restoring model weights from the end of the best epoch: 52.
#
# Epoch 62: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 62: saving model to roberta_best_model.h5
# 21/21 [==============================] - 29s 1s/step - loss: 0.8299 - categorical_accuracy: 0.6764 - f1_score: 0.6431 - val_loss: 0.8496 - val_categorical_accuracy: 0.6727 - val_f1_score: 0.6606 - lr: 4.0000e-05
# Epoch 62: early stopping

# %%
results = inital_model.evaluate([test_input_ids, test_attention_masks], test_labels)
print('Test accuracy:', results)
# Out:
# 62/62 [==============================] - 11s 180ms/step - loss: 0.9628 - categorical_accuracy: 0.5997 - f1_score: 0.4386
# Test accuracy: [0.9628420472145081, 0.599693238735199, 0.4386102557182312]

# %%
# Get model predictions
predictions = inital_model.predict([test_input_ids, test_attention_masks])

# Convert predictions to class labels
predicted_labels = np.argmax(predictions, axis=1)

# Assuming test_labels are one-hot encoded, convert them to class labels
true_labels = np.argmax(test_labels, axis=1)

# Generate classification report
report = classification_report(true_labels, predicted_labels)
print(report)
# Out:
# 62/62 [==============================] - 15s 193ms/step
#               precision    recall  f1-score   support
#
#            0       0.67      0.70      0.68      1014
#            1       0.64      0.39      0.48       452
#            2       0.46      0.59      0.52       490
#
#     accuracy                           0.60      1956
#    macro avg       0.59      0.56      0.56      1956
# weighted avg       0.61      0.60      0.60      1956

# %%
def load_classification_rp_per_target(model):
    targets = test_df.Target.unique()
    metrics_df = pd.DataFrame()
    for target in targets:
        extracted_df = test_df[test_df['Target'] == target]
        input_ids, attention_masks = bert_tokenize(extracted_df['processed_tweet'], extracted_df['Target'].to_list())
        labels = categorized_label(extracted_df, "Stance")

        # Convert one-hot encoded labels to single integer class labels
        true_labels = np.argmax(labels, axis=1)

        # Get model predictions
        predictions = model.predict([input_ids, attention_masks])

        # Convert predictions to class labels
        predicted_labels = np.argmax(predictions, axis=1)

        # Generate a classification report
        report = classification_report(true_labels, predicted_labels, target_names=['AGAINST', 'FAVOR', 'NONE'])
        target_name = ""
        if target == 0:
            target_name = "Hillary Clinton"
        if target == 1:
            target_name = "Legalization of Abortion"
        if target == 2:
            target_name = "Atheism"
        if target == 3:
            target_name = "Climate Change is a Real Concern"
        if target == 4:
            target_name = "Feminist Movement"
        if target == 5:
            target_name = "Donald Trump"

        print('Target: ', target_name)
        print(report)
        print("-----------------------------------------", "\n")

        # Flatten the report into a single row and add target name
        report = classification_report(true_labels, predicted_labels, target_names=['AGAINST', 'FAVOR', 'NONE'], output_dict=True)

        # Extract weighted f1, macro f1, and accuracy
        report_data = {
            'Target': target_name,
            'Weighted F1': report['weighted avg']['f1-score'],
            'Macro F1': report['macro avg']['f1-score'],
            'Accuracy': report['accuracy']
        }

        # Append to the DataFrame
        metrics_df = metrics_df.append(report_data, ignore_index=True)
    metrics_df.set_index('Target', inplace=True)

    return metrics_df

# %%
# Use the function to get the metrics DataFrame
model_metrics_df = load_classification_rp_per_target(inital_model)
model_metrics_df
# Out:
# 7/7 [==============================] - 2s 211ms/step
# Target:  Atheism
#               precision    recall  f1-score   support
#
#      AGAINST       0.80      0.90      0.84       160
#        FAVOR       0.54      0.22      0.31        32
#         NONE       0.50      0.46      0.48        28
#
#     accuracy                           0.75       220
#    macro avg       0.61      0.53      0.55       220
# weighted avg       0.72      0.75      0.72       220
#
# -----------------------------------------
# <ipython-input-16-7822421f7f5a>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 6/6 [==============================] - 1s 170ms/step
# Target:  Climate Change is a Real Concern
#               precision    recall  f1-score   support
#
#      AGAINST       0.00      0.00      0.00        11
#        FAVOR       0.92      0.46      0.62       123
#         NONE       0.30      0.91      0.45        35
#
#     accuracy                           0.53       169
#    macro avg       0.41      0.46      0.36       169
# weighted avg       0.73      0.53      0.54       169
#
# -----------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# <ipython-input-16-7822421f7f5a>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 9/9 [==============================] - 2s 237ms/step
# Target:  Feminist Movement
#               precision    recall  f1-score   support
#
#      AGAINST       0.67      0.53      0.59       183
#        FAVOR       0.28      0.57      0.37        58
#         NONE       0.55      0.25      0.34        44
#
#     accuracy                           0.49       285
#    macro avg       0.50      0.45      0.44       285
# weighted avg       0.57      0.49      0.51       285
#
# -----------------------------------------
# <ipython-input-16-7822421f7f5a>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 10/10 [==============================] - 2s 218ms/step
# Target:  Hillary Clinton
#               precision    recall  f1-score   support
#
#      AGAINST       0.64      0.85      0.73       172
#        FAVOR       0.28      0.33      0.31        45
#         NONE       0.57      0.10      0.17        78
#
#     accuracy                           0.57       295
#    macro avg       0.50      0.43      0.40       295
# weighted avg       0.57      0.57      0.52       295
#
# -----------------------------------------
# <ipython-input-16-7822421f7f5a>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 9/9 [==============================] - 2s 175ms/step
# Target:  Legalization of Abortion
#               precision    recall  f1-score   support
#
#      AGAINST       0.68      0.74      0.71       189
#        FAVOR       0.33      0.07      0.11        46
#         NONE       0.26      0.40      0.32        45
#
#     accuracy                           0.57       280
#    macro avg       0.43      0.40      0.38       280
# weighted avg       0.56      0.57      0.55       280
#
# -----------------------------------------
# <ipython-input-16-7822421f7f5a>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 23/23 [==============================] - 4s 173ms/step
# Target:  Donald Trump
#               precision    recall  f1-score   support
#
#      AGAINST       0.43      0.47      0.45       299
#        FAVOR       0.33      0.49      0.39       148
#         NONE       0.50      0.31      0.38       260
#
#     accuracy                           0.41       707
#    macro avg       0.42      0.42      0.41       707
# weighted avg       0.43      0.41      0.41       707
#
# -----------------------------------------
# <ipython-input-16-7822421f7f5a>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
#                                   Weighted F1  Macro F1  Accuracy
# Target
# Atheism                              0.720768  0.545722  0.745455
# Climate Change is a Real Concern     0.541830  0.355640  0.526627
# Feminist Movement                    0.508310  0.435333  0.494737
# Hillary Clinton                      0.518308  0.403345  0.572881
# Legalization of Abortion             0.547822  0.378953  0.571429
# Donald Trump                         0.412522  0.407913  0.414427

# %% [markdown]
# [4] Fine Tune

# %%
for layer in inital_model.layers:
    layer.trainable = True
   # Tuning the learning rate for the optimizer
inital_model.compile(optimizer=tf.keras.optimizers.legacy.Adam(1e-5),
                  loss='categorical_crossentropy',
                  metrics=['categorical_accuracy', f1_score])

history['fine_tuned_bert'] = inital_model.fit([train_input_ids, train_attention_masks], train_labels,
                    epochs=30,
                    validation_data=([val_input_ids, val_attention_masks], val_labels),
                    batch_size=32,
                    callbacks=callbacks,
                    shuffle = True)
# Out:
# Epoch 1/30
# WARNING:tensorflow:Gradients do not exist for variables ['tf_roberta_model_1/roberta/pooler/dense/kernel:0', 'tf_roberta_model_1/roberta/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['tf_roberta_model_1/roberta/pooler/dense/kernel:0', 'tf_roberta_model_1/roberta/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 83/83 [==============================] - ETA: 0s - loss: 0.8961 - categorical_accuracy: 0.6476 - f1_score: 0.5953
# Epoch 1: saving model to roberta_best_model.h5
# 83/83 [==============================] - 155s 1s/step - loss: 0.8961 - categorical_accuracy: 0.6476 - f1_score: 0.5953 - val_loss: 0.8361 - val_categorical_accuracy: 0.6576 - val_f1_score: 0.6440 - lr: 1.0000e-05
# Epoch 2/30
# 83/83 [==============================] - ETA: 0s - loss: 0.7958 - categorical_accuracy: 0.6882 - f1_score: 0.6588
# Epoch 2: saving model to roberta_best_model.h5
# 83/83 [==============================] - 110s 1s/step - loss: 0.7958 - categorical_accuracy: 0.6882 - f1_score: 0.6588 - val_loss: 0.8591 - val_categorical_accuracy: 0.6470 - val_f1_score: 0.6248 - lr: 1.0000e-05
# Epoch 3/30
# 83/83 [==============================] - ETA: 0s - loss: 0.7177 - categorical_accuracy: 0.7367 - f1_score: 0.7119
# Epoch 3: saving model to roberta_best_model.h5
# 83/83 [==============================] - 109s 1s/step - loss: 0.7177 - categorical_accuracy: 0.7367 - f1_score: 0.7119 - val_loss: 0.7744 - val_categorical_accuracy: 0.6955 - val_f1_score: 0.6688 - lr: 1.0000e-05
# Epoch 4/30
# 83/83 [==============================] - ETA: 0s - loss: 0.6856 - categorical_accuracy: 0.7508 - f1_score: 0.7304
# Epoch 4: saving model to roberta_best_model.h5
# 83/83 [==============================] - 113s 1s/step - loss: 0.6856 - categorical_accuracy: 0.7508 - f1_score: 0.7304 - val_loss: 0.7332 - val_categorical_accuracy: 0.7227 - val_f1_score: 0.6903 - lr: 1.0000e-05
# Epoch 5/30
# 83/83 [==============================] - ETA: 0s - loss: 0.6063 - categorical_accuracy: 0.7841 - f1_score: 0.7664
# Epoch 5: saving model to roberta_best_model.h5
# 83/83 [==============================] - 119s 1s/step - loss: 0.6063 - categorical_accuracy: 0.7841 - f1_score: 0.7664 - val_loss: 0.7456 - val_categorical_accuracy: 0.7273 - val_f1_score: 0.6910 - lr: 1.0000e-05
# Epoch 6/30
# 83/83 [==============================] - ETA: 0s - loss: 0.5690 - categorical_accuracy: 0.8134 - f1_score: 0.7948
# Epoch 6: saving model to roberta_best_model.h5
# 83/83 [==============================] - 108s 1s/step - loss: 0.5690 - categorical_accuracy: 0.8134 - f1_score: 0.7948 - val_loss: 0.7827 - val_categorical_accuracy: 0.7152 - val_f1_score: 0.7031 - lr: 1.0000e-05
# Epoch 7/30
# 83/83 [==============================] - ETA: 0s - loss: 0.5073 - categorical_accuracy: 0.8403 - f1_score: 0.8274
# Epoch 7: saving model to roberta_best_model.h5
# 83/83 [==============================] - 107s 1s/step - loss: 0.5073 - categorical_accuracy: 0.8403 - f1_score: 0.8274 - val_loss: 0.8189 - val_categorical_accuracy: 0.7258 - val_f1_score: 0.7125 - lr: 1.0000e-05
# Epoch 8/30
# 83/83 [==============================] - ETA: 0s - loss: 0.4722 - categorical_accuracy: 0.8509 - f1_score: 0.8443
# Epoch 8: saving model to roberta_best_model.h5
# 83/83 [==============================] - 112s 1s/step - loss: 0.4722 - categorical_accuracy: 0.8509 - f1_score: 0.8443 - val_loss: 0.8271 - val_categorical_accuracy: 0.7121 - val_f1_score: 0.7021 - lr: 1.0000e-05
# Epoch 9/30
# 83/83 [==============================] - ETA: 0s - loss: 0.4433 - categorical_accuracy: 0.8684 - f1_score: 0.8613
# Epoch 9: saving model to roberta_best_model.h5
# 83/83 [==============================] - 106s 1s/step - loss: 0.4433 - categorical_accuracy: 0.8684 - f1_score: 0.8613 - val_loss: 0.8068 - val_categorical_accuracy: 0.7242 - val_f1_score: 0.7098 - lr: 1.0000e-05
# Epoch 10/30
# 83/83 [==============================] - ETA: 0s - loss: 0.3785 - categorical_accuracy: 0.9010 - f1_score: 0.8957
# Epoch 10: saving model to roberta_best_model.h5
# 83/83 [==============================] - 105s 1s/step - loss: 0.3785 - categorical_accuracy: 0.9010 - f1_score: 0.8957 - val_loss: 0.8599 - val_categorical_accuracy: 0.7106 - val_f1_score: 0.6990 - lr: 1.0000e-05
# Epoch 11/30
# 83/83 [==============================] - ETA: 0s - loss: 0.3650 - categorical_accuracy: 0.9006 - f1_score: 0.8981
# Epoch 11: saving model to roberta_best_model.h5
# 83/83 [==============================] - 109s 1s/step - loss: 0.3650 - categorical_accuracy: 0.9006 - f1_score: 0.8981 - val_loss: 0.9066 - val_categorical_accuracy: 0.7258 - val_f1_score: 0.7087 - lr: 1.0000e-05
# Epoch 12/30
# 83/83 [==============================] - ETA: 0s - loss: 0.3310 - categorical_accuracy: 0.9173 - f1_score: 0.9127
# Epoch 12: saving model to roberta_best_model.h5
# 83/83 [==============================] - 107s 1s/step - loss: 0.3310 - categorical_accuracy: 0.9173 - f1_score: 0.9127 - val_loss: 0.9042 - val_categorical_accuracy: 0.7182 - val_f1_score: 0.7009 - lr: 1.0000e-05
# Epoch 13/30
# 83/83 [==============================] - ETA: 0s - loss: 0.3241 - categorical_accuracy: 0.9260 - f1_score: 0.9248
# Epoch 13: saving model to roberta_best_model.h5
# 83/83 [==============================] - 106s 1s/step - loss: 0.3241 - categorical_accuracy: 0.9260 - f1_score: 0.9248 - val_loss: 0.9289 - val_categorical_accuracy: 0.7045 - val_f1_score: 0.6735 - lr: 1.0000e-05
# Epoch 14/30
# 83/83 [==============================] - ETA: 0s - loss: 0.3157 - categorical_accuracy: 0.9283 - f1_score: 0.9267Restoring model weights from the end of the best epoch: 4.
#
# Epoch 14: saving model to roberta_best_model.h5
# 83/83 [==============================] - 107s 1s/step - loss: 0.3157 - categorical_accuracy: 0.9283 - f1_score: 0.9267 - val_loss: 0.9318 - val_categorical_accuracy: 0.7152 - val_f1_score: 0.6945 - lr: 1.0000e-05
# Epoch 14: early stopping

# %%
# Use the function to get the metrics DataFrame
model_metrics_df = load_classification_rp_per_target(inital_model)
model_metrics_df
# Out:
# 7/7 [==============================] - 6s 227ms/step
# Target:  Atheism
#               precision    recall  f1-score   support
#
#      AGAINST       0.80      0.78      0.79       160
#        FAVOR       0.41      0.34      0.37        32
#         NONE       0.39      0.50      0.44        28
#
#     accuracy                           0.68       220
#    macro avg       0.53      0.54      0.53       220
# weighted avg       0.69      0.68      0.68       220
#
# -----------------------------------------
# <ipython-input-16-7822421f7f5a>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 6/6 [==============================] - 1s 211ms/step
# Target:  Climate Change is a Real Concern
#               precision    recall  f1-score   support
#
#      AGAINST       0.60      0.27      0.37        11
#        FAVOR       0.90      0.79      0.84       123
#         NONE       0.54      0.86      0.66        35
#
#     accuracy                           0.77       169
#    macro avg       0.68      0.64      0.62       169
# weighted avg       0.80      0.77      0.77       169
#
# -----------------------------------------
# <ipython-input-16-7822421f7f5a>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 9/9 [==============================] - 2s 173ms/step
# Target:  Feminist Movement
#               precision    recall  f1-score   support
#
#      AGAINST       0.70      0.78      0.74       183
#        FAVOR       0.38      0.31      0.34        58
#         NONE       0.56      0.43      0.49        44
#
#     accuracy                           0.63       285
#    macro avg       0.54      0.51      0.52       285
# weighted avg       0.61      0.63      0.62       285
#
# -----------------------------------------
# <ipython-input-16-7822421f7f5a>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 10/10 [==============================] - 2s 174ms/step
# Target:  Hillary Clinton
#               precision    recall  f1-score   support
#
#      AGAINST       0.67      0.82      0.73       172
#        FAVOR       0.43      0.13      0.20        45
#         NONE       0.41      0.36      0.38        78
#
#     accuracy                           0.59       295
#    macro avg       0.50      0.44      0.44       295
# weighted avg       0.56      0.59      0.56       295
#
# -----------------------------------------
# <ipython-input-16-7822421f7f5a>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 9/9 [==============================] - 2s 175ms/step
# Target:  Legalization of Abortion
#               precision    recall  f1-score   support
#
#      AGAINST       0.79      0.68      0.73       189
#        FAVOR       0.45      0.43      0.44        46
#         NONE       0.41      0.67      0.50        45
#
#     accuracy                           0.64       280
#    macro avg       0.55      0.59      0.56       280
# weighted avg       0.67      0.64      0.65       280
#
# -----------------------------------------
# <ipython-input-16-7822421f7f5a>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
# 23/23 [==============================] - 5s 198ms/step
# Target:  Donald Trump
#               precision    recall  f1-score   support
#
#      AGAINST       0.45      0.78      0.57       299
#        FAVOR       0.56      0.39      0.46       148
#         NONE       0.61      0.20      0.30       260
#
#     accuracy                           0.48       707
#    macro avg       0.54      0.46      0.44       707
# weighted avg       0.53      0.48      0.45       707
#
# -----------------------------------------
# <ipython-input-16-7822421f7f5a>:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   metrics_df = metrics_df.append(report_data, ignore_index=True)
#                                   Weighted F1  Macro F1  Accuracy
# Target
# Atheism                              0.683478  0.533008  0.681818
# Climate Change is a Real Concern     0.772193  0.624722  0.769231
# Feminist Movement                    0.616760  0.520851  0.628070
# Hillary Clinton                      0.559930  0.439572  0.593220
# Legalization of Abortion             0.646356  0.559330  0.635714
# Donald Trump                         0.446330  0.442170  0.483734

# %%
# Get model predictions
predictions = inital_model.predict([test_input_ids, test_attention_masks])

# Convert predictions to class labels
predicted_labels = np.argmax(predictions, axis=1)

# Assuming test_labels are one-hot encoded, convert them to class labels
true_labels = np.argmax(test_labels, axis=1)

# Generate classification report
report = classification_report(true_labels, predicted_labels)
print(report)
# Out:
# 62/62 [==============================] - 11s 178ms/step
#               precision    recall  f1-score   support
#
#            0       0.68      0.76      0.72      1014
#            1       0.67      0.55      0.60       452
#            2       0.61      0.57      0.59       490
#
#     accuracy                           0.66      1956
#    macro avg       0.65      0.62      0.64      1956
# weighted avg       0.66      0.66      0.66      1956

# %%
inital_model.save('roberta_model_66.h5')
